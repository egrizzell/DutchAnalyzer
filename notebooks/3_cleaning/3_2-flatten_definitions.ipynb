# %%
import json
from pathlib import Path
import ujson
from dutchanalyzer.config import *
from dutchanalyzer.utilities.utils import *
from dutchanalyzer.utilities.json_utils import *
from dutchanalyzer.utilities.replacement_utils import *
from dotenv import load_dotenv
import datetime
import re
from pprint import pprint
import ast
from tqdm import tqdm
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from dutchanalyzer.utilities import utils
#       6 from dutchanalyzer.utilities import json_utils
# ----> 7 from dutchanalyzer.utilities import replacement_utils
#       8 from dotenv import load_dotenv
#       9 import datetime
#
# File ~\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\src\dutchanalyzer\utilities\replacement_utils.py:5
#       3 import datetime
#       4 from pathlib import Path
# ----> 5 from dutchanalyzer.utils import safe_eval
#       6 # Pandas Utils
#       8 def summarize_df(df: pd.DataFrame, name: str = None, num_top_values=10, dsrc='EEP') -> pd.DataFrame:
#
# ModuleNotFoundError: No module named 'dutchanalyzer.utils'

# %%
NNF_file = Path(WIKT_CLEANING_DIR, 'nl','NNF.jsonl')
NEF_file = Path(WIKT_CLEANING_DIR, 'nl','NEF.jsonl')
EEF_file = Path(WIKT_CLEANING_DIR, 'en','EEF.jsonl')
ENF_file = Path(WIKT_CLEANING_DIR, 'en','ENF.jsonl')
NEF_definitions = Path(WIKT_CLEANING_DIR, 'nl','NEF_definitions.jsonl')
NNF_definitions = Path(WIKT_CLEANING_DIR, 'nl','NNF_definitions.jsonl')
ENF_definitions = Path(WIKT_CLEANING_DIR, 'en','ENF_definitions.jsonl')
EEF_definitions = Path(WIKT_CLEANING_DIR, 'en','EEF_definitions.jsonl')

# %%
today = datetime.date.today().__format__("%d-%m-%y")
current_save_folder = Path(INTERIM_DATA_DIR, 'cleaning', 'wikt', str(today))

# %% [markdown]
# ## Flatten definitions

# %%
def filter_obj(obj):
    if 'translations' in obj:
        translations = []
        for t in obj['translations']:
            lang_code = t.get('lang_code')
            if lang_code == 'en' or lang_code == 'nl':
                translations.append(t)
        obj['translations'] = translations
    if obj.get('pos', '') == 'name' or obj.get('pos', '') == 'character':
        return None
    return obj

# %%
def reformat_translations(translations_list: list):
    # formatted as returning en translations, nl translations and other translations if they exist
    en_translations = []
    nl_translations = []
    other_translations = []
    accepted_tags = ['word', 'sense', 'sense_index', 'lang', 'lang_code', 'roman', 'tags', 'code', 'note', 'english', 'translation', 'raw_tags', 'taxonomic', 'topics', 'alt']
    for translation in translations_list:
        tags = translation.get('tags')
        note = translation.get('note')
        english = translation.get('english')
        alt = translation.get('alt')
        extra_translation_keys = False
        if translation.get('lang_code') == 'en' or translation.get('code') == 'en':
            en_translations.append({ "word" : translation.get('word'), "sense": translation.get('sense')})
            if tags:
                 en_translations[-1]['tags'] = tags
            if alt:
                en_translations[-1]['alt'] = alt
            for key in translation.keys():
                if key not in accepted_tags:
                    print("word : ", translation.get('word'), " other key: ", key)
                    extra_translation_keys = True
                    break
        elif translation.get('lang_code') == 'nl' or translation.get('code') == 'nl':
            nl_translations.append({ "word" : translation.get('word'), "sense": translation.get('sense')})
            if tags:
                 nl_translations[-1]['tags'] = tags
            if alt:
                 nl_translations[- 1]['alt'] = alt   
            for key in translation.keys():
                if key not in accepted_tags:
                    print("word : ", translation.get('word'), " other key: ", key)
                    extra_translation_keys = True
                    break
        else:
            other_translations.append({ "word" : translation.get('word'), "sense": translation.get('sense')})
            if tags:
                other_translations[-1]['tags'] = tags
            if alt:
                other_translations[-1]['alt'] = alt
            for key in translation.keys():
                if key not in accepted_tags:
                    print("word : ", translation.get('word'), " other key: ", key)
                    extra_translation_keys = True
                    break
    all_translations = {'en' : en_translations, 'nl': nl_translations, 'other': other_translations}
    return all_translations, extra_translation_keys

# %%
def split_to_senses_glosses_rows(obj: dict, prev_snum=0):
    new_rows = []
    new_translations = {}
    senses = obj.get('senses')
    translations = obj.get('translations')
    forms = obj.get('forms')
    if senses:
        for i, sense in senses.items():
            if 'glosses' in sense:
                glosses = sense['glosses'] 
                for j, gloss in enumerate(glosses):
                   new_rows.append({"word": obj.get("word"), "pos": obj.get("pos"), "lang_code": obj.get("lang_code"), 'sense_code': i, 'gloss_code':j, 'gloss': gloss, "wl_code": obj.get("wl_code")})
            else:
                new_rows.append({"word": obj.get("word"), "pos": obj.get("pos"), "lang_code": obj.get("lang_code"), 'sense_code': i, 'gloss_code': -1, 'gloss': None, "wl_code": obj.get("wl_code")})
    else:
        new_rows.append({"word": obj.get("word"), "pos": obj.get("pos"), "lang_code": obj.get("lang_code"), 'sense_code': -1, 'gloss_code': -1, 'gloss': None, "wl_code": obj.get("wl_code")})    
    if translations:
        all_translations, extra_keys = reformat_translations(translations)
        for k, v in all_translations.items():
            if v:
                new_translations[f'{k}_translations'] = v
    for i in range(len(new_rows)):
        if new_translations:
            new_rows[i].update(new_translations)
        if forms:
            new_rows[i]['forms'] = forms
    return new_rows

# %% [markdown]
# ## Loading Definitions

# %%
NNF_new_defs_list = []
with open(NNF_definitions, 'r', encoding='utf-8') as f:
    for i, line in tqdm(enumerate(f)):
        
        loaded = json.loads(line)
        loaded = filter_obj(loaded)
        
        if loaded:
            NNF_new_defs_list.extend(split_to_senses_glosses_rows(loaded))
# Out:
# 611444it [00:10, 60603.60it/s]

# %%
NNF_df = pd.DataFrame(NNF_new_defs_list)
NNF_df
# Out:
#                 word   pos lang_code sense_code  gloss_code  \
# 0                 ja   adv        nl          0           0
# 1                 ja  intj        nl          0           0
# 2                 ja  intj        nl          1           0
# 3                 ja  noun        nl          0           0
# 4               neen  intj        nl          0           0
# ...              ...   ...       ...        ...         ...
# 709451  mottigaardje  noun        nl          0           0
# 709452   mottigaards  noun        nl          0           0
# 709453   bankpootjes  noun        nl          0           0
# 709454    bankpootje  noun        nl          0           0
# 709455     bankpoten  noun        nl          0           0
#
#                                                     gloss wl_code  \
# 0       duidt bevestiging, instemming, toestemming, in...     NNF
# 1                                     kreet van opwinding     NNF
# 2       nou ja: kijk zo simpel is het! dat je dat niet...     NNF
# 3                      bevestigend of instemmend antwoord     NNF
# 4       ontkenning van de gestelde vraag of gedane bew...     NNF
# ...                                                   ...     ...
# 709451  verkleinwoord enkelvoud van het zelfstandig na...     NNF
# 709452  meervoud van het zelfstandig naamwoord mottigaard     NNF
# 709453  verkleinwoord meervoud van het zelfstandig naa...     NNF
# 709454  verkleinwoord enkelvoud van het zelfstandig na...     NNF
# 709455    meervoud van het zelfstandig naamwoord bankpoot     NNF
#
#                                           en_translations  \
# 0       [{'word': 'yes', 'sense': 'duidt bevestiging o...
# 1       [{'word': 'yes', 'sense': 'kreet van opwinding'}]
# 2       [{'word': 'yes', 'sense': 'kreet van opwinding'}]
# 3       [{'word': 'yes', 'sense': 'bevestigend of inst...
# 4                        [{'word': 'no', 'sense': 'nee'}]
# ...                                                   ...
# 709451                                                NaN
# 709452                                                NaN
# 709453                                                NaN
# 709454                                                NaN
# 709455                                                NaN
#
#                            forms nl_translations
# 0                            NaN             NaN
# 1                            NaN             NaN
# 2                            NaN             NaN
# 3                            NaN             NaN
# 4                            NaN             NaN
# ...                          ...             ...
# 709451  [{'word': 'mottigaard'}]             NaN
# 709452  [{'word': 'mottigaard'}]             NaN
# 709453    [{'word': 'bankpoot'}]             NaN
# 709454    [{'word': 'bankpoot'}]             NaN
# 709455    [{'word': 'bankpoot'}]             NaN
#
# [709456 rows x 10 columns]

# %%
NNF_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 709456 entries, 0 to 709455
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   word             709456 non-null  object
#  1   pos              709456 non-null  object
#  2   lang_code        709456 non-null  object
#  3   sense_code       709456 non-null  object
#  4   gloss_code       709456 non-null  int64
#  5   gloss            708785 non-null  object
#  6   wl_code          709456 non-null  object
#  7   en_translations  54260 non-null   object
#  8   forms            665915 non-null  object
#  9   nl_translations  66 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 54.1+ MB

# %%
NNF_df.to_csv(Path(current_save_folder, 'NNF_definitions_df.csv'))

# %%
NEF_defs_list = []
with open(NEF_definitions, 'r', encoding='utf-8') as f:
    for i, line in tqdm(enumerate(f)):
        loaded = json.loads(line)
        loaded = filter_obj(loaded)
        if loaded:
            NEF_defs_list.extend(split_to_senses_glosses_rows(loaded))
# Out:
# 17441it [00:00, 207342.31it/s]

# %%
NEF_df = pd.DataFrame(NEF_defs_list)
NEF_df.to_csv(Path(current_save_folder, 'NEF_definitions_df.csv'))

# %%
EEF_defs_list = []
with open(EEF_definitions, 'r', encoding='utf-8') as f:
    for i, line in tqdm(enumerate(f)):
        
        loaded = json.loads(line)
        loaded = filter_obj(loaded)
        if loaded:
            EEF_defs_list.extend(split_to_senses_glosses_rows(loaded))
# Out:
# 1417383it [00:14, 96091.58it/s]

# %%
EEF_df = pd.DataFrame(EEF_defs_list)
EEF_df.to_csv(Path(current_save_folder, 'EEF_definitions_df.csv'))

# %%
EEF_df
# Out:
#                        word   pos lang_code sense_code  gloss_code  \
# 0                dictionary  noun        en          0           0
# 1                dictionary  noun        en          1           0
# 2                dictionary  noun        en          2           0
# 3                dictionary  noun        en          3           0
# 4                dictionary  noun        en          4           0
# ...                     ...   ...       ...        ...         ...
# 1464316           in motion   adj        en          0          -1
# 1464317              be sad  verb        en          0          -1
# 1464318  fashionable person  noun        en          0          -1
# 1464319         what a pity  intj        en          0          -1
# 1464320     USB flash drive  noun        en          0          -1
#
#                                                      gloss wl_code  \
# 0        A reference work listing words or names from o...     EEF
# 1        A reference work on a particular subject or ac...     EEF
# 2        A person or thing regarded as a repository or ...     EEF
# 3        The collection of words used or understood by ...     EEF
# 4        A synchronic dictionary of a standardised lang...     EEF
# ...                                                    ...     ...
# 1464316                                               None     EEF
# 1464317                                               None     EEF
# 1464318                                               None     EEF
# 1464319                                               None     EEF
# 1464320                                               None     EEF
#
#                                            nl_translations  \
# 0        [{'word': 'woordenboek', 'sense': 'publication...
# 1        [{'word': 'woordenboek', 'sense': 'publication...
# 2        [{'word': 'woordenboek', 'sense': 'publication...
# 3        [{'word': 'woordenboek', 'sense': 'publication...
# 4        [{'word': 'woordenboek', 'sense': 'publication...
# ...                                                    ...
# 1464316                                                NaN
# 1464317                                                NaN
# 1464318                                                NaN
# 1464319                                                NaN
# 1464320                                                NaN
#
#                                                      forms
# 0        [{'form': 'dictionaries', 'tags': ['plural']},...
# 1        [{'form': 'dictionaries', 'tags': ['plural']},...
# 2        [{'form': 'dictionaries', 'tags': ['plural']},...
# 3        [{'form': 'dictionaries', 'tags': ['plural']},...
# 4        [{'form': 'dictionaries', 'tags': ['plural']},...
# ...                                                    ...
# 1464316                                                NaN
# 1464317                                                NaN
# 1464318                                                NaN
# 1464319                                                NaN
# 1464320                                                NaN
#
# [1464321 rows x 9 columns]

# %%
ENF_defs_list = []
with open(ENF_definitions, 'r', encoding='utf-8') as f:
    for i, line in tqdm(enumerate(f)):
        
        loaded = json.loads(line)
        loaded = filter_obj(loaded)
        if loaded:
            ENF_defs_list.extend(split_to_senses_glosses_rows(loaded))
# Out:
# 140758it [00:01, 91684.04it/s]

# %%
ENF_df = pd.DataFrame(ENF_defs_list)
ENF_df.to_csv(Path(current_save_folder, 'ENF_definitions_df.csv'))

# %%
ENF_df
# Out:
#                                   word   pos lang_code sense_code  gloss_code  \
# 0                          woordenboek  noun        nl          0           0
# 1                               gratis   adj        nl          0           0
# 2                              gratuit   adj        nl          0           0
# 3                                 word  verb        nl          0           0
# 4                                 word  verb        nl          0           1
# ...                                ...   ...       ...        ...         ...
# 213288                       flikkerij  noun        nl          0           0
# 213289                      leefruimte  noun        nl          0           0
# 213290                    vluchtnummer  noun        nl          0           0
# 213291                    overnachting  noun        nl          0           0
# 213292  veel voeten in de aarde hebben  verb        nl          0           0
#
#                                                  gloss wl_code  \
# 0                                           dictionary     ENF
# 1                                 free, without charge     ENF
# 2                           gratuitous, not obliged to     ENF
# 3                                inflection of worden:     ENF
# 4             first-person singular present indicative     ENF
# ...                                                ...     ...
# 213288                                        faggotry     ENF
# 213289                                    living space     ENF
# 213290                                   flight number     ENF
# 213291                                  overnight stay     ENF
# 213292  to take some doing, to require a lot of effort     ENF
#
#                                                     forms
# 0       [{'form': 'woordenboeken', 'tags': ['plural']}...
# 1       [{'form': 'no-table-tags', 'source': 'declensi...
# 2       [{'form': 'no-table-tags', 'source': 'declensi...
# 3                                    [{'word': 'worden'}]
# 4                                    [{'word': 'worden'}]
# ...                                                   ...
# 213288                                                NaN
# 213289  [{'form': 'leefruimten', 'tags': ['plural']}, ...
# 213290    [{'form': 'vluchtnummers', 'tags': ['plural']}]
# 213291  [{'form': 'overnachtingen', 'tags': ['plural']...
# 213292  [{'form': 'veel voeten in aarde hebben', 'tags...
#
# [213293 rows x 8 columns]

# %% [markdown]
# ### Finding Words That Are Equivalent

# %%
equal_definitions_NEF = get_equal_definitions(NEF_df)

# %%
equal_definitions_NEF
# Out:
#                    word   pos lang_code sense_code  gloss_code  \
# 39            Esperanto  noun        en          0           0
# 76             Cherokee  noun        en          0           0
# 77             Cherokee  noun        en          1           0
# 108               Farsi  noun        en          0           0
# 123                 man  noun        en          0           0
# ...                 ...   ...       ...        ...         ...
# 24470  chateau migraine  noun        en          0           0
# 24662             envoi  noun        en          0           0
# 24675           minigun  noun        en          0           0
# 24861              LETS  noun        en          0           0
# 24872         hypallage  noun        en          0           0
#
#                   gloss wl_code  \
# 39            Esperanto     NEF
# 76             Cherokee     NEF
# 77             Cherokee     NEF
# 108               Farsi     NEF
# 123                 man     NEF
# ...                 ...     ...
# 24470  chateau migraine     NEF
# 24662             envoi     NEF
# 24675           minigun     NEF
# 24861              LETS     NEF
# 24872         hypallage     NEF
#
#                                                    forms en_translations
# 39                                                   NaN             NaN
# 76                                                   NaN             NaN
# 77                                                   NaN             NaN
# 108                                                  NaN             NaN
# 123                                                  NaN             NaN
# ...                                                  ...             ...
# 24470  [{'form': 'Chateau Migraine, Château Migraine,...             NaN
# 24662                                                NaN             NaN
# 24675                                                NaN             NaN
# 24861                                                NaN             NaN
# 24872                                                NaN             NaN
#
# [852 rows x 9 columns]

# %%
equal_definitions_ENF = get_equal_definitions(ENF_df)

# %%
equal_definitions_ENF
# Out:
#               word     pos lang_code sense_code  gloss_code       gloss  \
# 33         product    noun        nl          0           0     product
# 40             aam    noun        nl          0           0         aam
# 41        aardwolf    noun        nl          0           0    aardwolf
# 49            quiz    noun        nl          0           0        quiz
# 50      millennium    noun        nl          0           0  millennium
# ...            ...     ...       ...        ...         ...         ...
# 205687    hexadec-  prefix        nl          0           0    hexadec-
# 205688   heptadec-  prefix        nl          0           0   heptadec-
# 205689    octadec-  prefix        nl          0           0    octadec-
# 205690    nonadec-  prefix        nl          0           0    nonadec-
# 205691      eicos-  prefix        nl          0           0      eicos-
#
#        wl_code                                              forms
# 33         ENF  [{'form': 'producten', 'tags': ['plural']}, {'...
# 40         ENF             [{'form': 'amen', 'tags': ['plural']}]
# 41         ENF  [{'form': 'aardwolven', 'tags': ['plural']}, {...
# 49         ENF  [{'form': 'quizzen', 'tags': ['plural']}, {'fo...
# 50         ENF  [{'form': 'millennia', 'tags': ['plural']}, {'...
# ...        ...                                                ...
# 205687     ENF                                                NaN
# 205688     ENF                                                NaN
# 205689     ENF                                                NaN
# 205690     ENF                                                NaN
# 205691     ENF                                                NaN
#
# [1211 rows x 8 columns]

# %%
def get_duplicate_words(df, filter_by=['word', 'pos', 'gloss']):
    # repeated = (
    # df.groupby(['word', 'pos', 'gloss'])
    # .filter(lambda g: len(g) > 1)
    # .groupby(['word', 'pos', 'gloss'], as_index=False)
    # .agg({'gloss': list})
    #         )
    # duplicates = duplicates[duplicates['pos'] > 1]
    duplicates = df[df.duplicated(subset=filter_by, keep=False)]
    return duplicates

# %%
pd.set_option('display.width', 5000)
pd.set_option

# %%
dups_ENF = get_duplicate_words(ENF_df)
display()
# Out:
#                 word   pos lang_code sense_code  gloss_code                                              gloss wl_code                                              forms
# 3               word  verb        nl          0           0                              inflection of worden:     ENF                               [{'word': 'worden'}]
# 5               word  verb        nl          1           0                              inflection of worden:     ENF                               [{'word': 'worden'}]
# 7               word  verb        nl          2           0                              inflection of worden:     ENF                               [{'word': 'worden'}]
# 9               pond  noun        nl          0           0   unit of mass, often broadly similar to 500 grams     ENF  [{'form': 'ponden', 'tags': ['plural']}, {'for...
# 11              pond  noun        nl          1           0   unit of mass, often broadly similar to 500 grams     ENF  [{'form': 'ponden', 'tags': ['plural']}, {'for...
# ...              ...   ...       ...        ...         ...                                                ...     ...                                                ...
# 213271  gemotiveerde  verb        nl          1           0                         inflection of gemotiveerd:     ENF                          [{'word': 'gemotiveerd'}]
# 213273  gemotiveerde  verb        nl          2           0                         inflection of gemotiveerd:     ENF                          [{'word': 'gemotiveerd'}]
# 213275      zwaarste   adj        nl          0           0  inflection of zwaarst, the superlative degree ...     ENF  [{'word': 'zwaarst', 'extra': 'the superlative...
# 213277      zwaarste   adj        nl          1           0  inflection of zwaarst, the superlative degree ...     ENF  [{'word': 'zwaarst', 'extra': 'the superlative...
# 213279      zwaarste   adj        nl          2           0  inflection of zwaarst, the superlative degree ...     ENF  [{'word': 'zwaarst', 'extra': 'the superlative...
#
# [45242 rows x 8 columns]

# %%
ENF_df = pd.read_csv(Path(current_save_folder, 'ENF_definitions_df.csv'), index_col=0)

# %%
ENF_df
# Out:
#                                   word   pos lang_code  sense_code  \
# 0                          woordenboek  noun        nl           0
# 1                               gratis   adj        nl           0
# 2                              gratuit   adj        nl           0
# 3                                 word  verb        nl           0
# 4                                 word  verb        nl           0
# ...                                ...   ...       ...         ...
# 213288                       flikkerij  noun        nl           0
# 213289                      leefruimte  noun        nl           0
# 213290                    vluchtnummer  noun        nl           0
# 213291                    overnachting  noun        nl           0
# 213292  veel voeten in de aarde hebben  verb        nl           0
#
#         gloss_code                                           gloss wl_code  \
# 0                0                                      dictionary     ENF
# 1                0                            free, without charge     ENF
# 2                0                      gratuitous, not obliged to     ENF
# 3                0                           inflection of worden:     ENF
# 4                1        first-person singular present indicative     ENF
# ...            ...                                             ...     ...
# 213288           0                                        faggotry     ENF
# 213289           0                                    living space     ENF
# 213290           0                                   flight number     ENF
# 213291           0                                  overnight stay     ENF
# 213292           0  to take some doing, to require a lot of effort     ENF
#
#                                                     forms
# 0       [{'form': 'woordenboeken', 'tags': ['plural']}...
# 1       [{'form': 'no-table-tags', 'source': 'declensi...
# 2       [{'form': 'no-table-tags', 'source': 'declensi...
# 3                                    [{'word': 'worden'}]
# 4                                    [{'word': 'worden'}]
# ...                                                   ...
# 213288                                                NaN
# 213289  [{'form': 'leefruimten', 'tags': ['plural']}, ...
# 213290    [{'form': 'vluchtnummers', 'tags': ['plural']}]
# 213291  [{'form': 'overnachtingen', 'tags': ['plural']...
# 213292  [{'form': 'veel voeten in aarde hebben', 'tags...
#
# [213293 rows x 8 columns]

# %%
ENF_defs_list_no_change = []
with open(ENF_definitions, 'r', encoding='utf-8') as f:
    for i, line in tqdm(enumerate(f)):
        
        loaded = json.loads(line)
        loaded = filter_obj(loaded)
        if loaded:
            ENF_defs_list_no_change.append(loaded)
# Out:
# 140758it [00:02, 55413.00it/s]

# %%
ENF_defs_list_no_change
# Out:
# [{'word': 'woordenboek',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['dictionary']}},
#   'forms': [{'form': 'woordenboeken', 'tags': ['plural']},
#    {'form': 'woordenboekje', 'tags': ['diminutive', 'neuter']},
#    {'form': 'woordboek', 'tags': ['alternative', 'obsolete']},
#    {'form': 'woordboeck', 'tags': ['alternative', 'obsolete']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'af',
#     'args': {'1': 'nl',
#      '2': 'woord',
#      't1': 'word',
#      '3': '-en-',
#      '4': 'boek',
#      't3': 'book'},
#     'expansion': 'woord (“word”) + -en- + boek (“book”)'},
#    {'name': 'cal',
#     'args': {'1': 'nl', '2': 'LL.', 'nocap': '1', '3': 'vocābulārium'},
#     'expansion': 'calque of Late Latin vocābulārium'},
#    {'name': 'cog',
#     'args': {'1': 'en', '2': 'wordbook'},
#     'expansion': 'English wordbook'}]},
#  {'word': 'gratis',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['free, without charge']}},
#   'forms': [{'form': 'no-table-tags',
#     'source': 'declension',
#     'tags': ['table-tags']},
#    {'form': 'nl-decl-adj',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'gratis',
#     'tags': ['adverbial', 'positive', 'predicative'],
#     'source': 'declension'},
#    {'form': 'gratis',
#     'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'gratis',
#     'tags': ['indefinite', 'neuter', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'gratis',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'gratis',
#     'tags': ['definite', 'positive'],
#     'source': 'declension'},
#    {'form': 'gratis',
#     'tags': ['partitive', 'positive'],
#     'source': 'declension'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'la', '3': 'grātīs'},
#     'expansion': 'Latin grātīs'}]},
#  {'word': 'gratuit',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['gratuitous, not obliged to']}},
#   'forms': [{'form': 'no-table-tags',
#     'source': 'declension',
#     'tags': ['table-tags']},
#    {'form': 'nl-decl-adj',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'gratuit',
#     'tags': ['adverbial', 'positive', 'predicative'],
#     'source': 'declension'},
#    {'form': 'gratuite',
#     'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'gratuit',
#     'tags': ['indefinite', 'neuter', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'gratuite',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'gratuite',
#     'tags': ['definite', 'positive'],
#     'source': 'declension'},
#    {'form': 'gratuits',
#     'tags': ['partitive', 'positive'],
#     'source': 'declension'},
#    {'form': 'gratuite', 'tags': ['alternative']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'fr', '3': 'gratuit'},
#     'expansion': 'French gratuit'}]},
#  {'word': 'word',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['inflection of worden:',
#      'first-person singular present indicative'],
#     'forms': [{'word': 'worden'}]},
#    '1': {'glosses': ['inflection of worden:',
#      'second-person singular present indicative'],
#     'forms': [{'word': 'worden'}]},
#    '2': {'glosses': ['inflection of worden:', 'imperative'],
#     'forms': [{'word': 'worden'}]}},
#   'forms': [{'word': 'worden'}],
#   'wl_code': 'ENF'},
#  {'word': 'pond',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['unit of mass, often broadly similar to 500 grams',
#      'metric pound (500 grams)']},
#    '1': {'glosses': ['unit of mass, often broadly similar to 500 grams',
#      'pound (453.6 grams)']},
#    '2': {'glosses': ['unit of mass, often broadly similar to 500 grams',
#      'pound, any of several local units, with a range between 420 and 500 grammes, divided into 16 historical ounces']},
#    '3': {'glosses': ['unit of mass, often broadly similar to 500 grams',
#      'kilogram']},
#    '4': {'glosses': ['one of several monetary units',
#      'British pound, pound sterling (currency)']},
#    '5': {'glosses': ['one of several monetary units', 'Egyptian pound']},
#    '6': {'glosses': ['one of several monetary units', 'Flemish pound']}},
#   'forms': [{'form': 'ponden', 'tags': ['plural']},
#    {'form': 'pondje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'pont'},
#     'expansion': 'Middle Dutch pont'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'punt'},
#     'expansion': 'Old Dutch punt'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*pund'},
#     'expansion': 'Proto-West Germanic *pund'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*pundą', 't': 'pound, weight'},
#     'expansion': 'Proto-Germanic *pundą (“pound, weight”)'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'la', '3': 'pondō'},
#     'expansion': 'Latin pondō'}]},
#  {'word': 'pies',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['alternative form of pis; pee, piss']}},
#   'wl_code': 'ENF'},
#  {'word': 'raven',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['to (hold a) rave, to party wildly']}},
#   'forms': [{'form': 'weak', 'source': 'conjugation', 'tags': ['table-tags']},
#    {'form': 'nl-conj-wk',
#     'source': 'conjugation',
#     'tags': ['inflection-template']},
#    {'form': 'raven', 'tags': ['infinitive'], 'source': 'conjugation'},
#    {'form': 'raven', 'tags': ['gerund', 'neuter'], 'source': 'conjugation'},
#    {'form': 'rave',
#     'tags': ['first-person', 'present', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravede',
#     'tags': ['first-person', 'past', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravet',
#     'tags': ['present', 'second-person', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'rave',
#     'tags': ['present', 'second-person', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravede',
#     'tags': ['past', 'second-person', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravet',
#     'tags': ['formal', 'present', 'second-person', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravede',
#     'tags': ['formal', 'past', 'second-person', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravet',
#     'tags': ['Flanders', 'colloquial', 'present', 'second-person', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravet',
#     'tags': ['archaic',
#      'formal',
#      'majestic',
#      'present',
#      'second-person',
#      'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravede',
#     'tags': ['Flanders', 'colloquial', 'past', 'second-person', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravede',
#     'tags': ['archaic',
#      'formal',
#      'majestic',
#      'past',
#      'second-person',
#      'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravet',
#     'tags': ['present', 'singular', 'third-person'],
#     'source': 'conjugation'},
#    {'form': 'ravede',
#     'tags': ['past', 'singular', 'third-person'],
#     'source': 'conjugation'},
#    {'form': 'raven', 'tags': ['plural', 'present'], 'source': 'conjugation'},
#    {'form': 'raveden', 'tags': ['past', 'plural'], 'source': 'conjugation'},
#    {'form': 'rave',
#     'tags': ['archaic', 'present', 'singular', 'subjunctive'],
#     'source': 'conjugation'},
#    {'form': 'ravede',
#     'tags': ['archaic', 'past', 'singular', 'subjunctive'],
#     'source': 'conjugation'},
#    {'form': 'raven',
#     'tags': ['archaic', 'plural', 'present', 'subjunctive'],
#     'source': 'conjugation'},
#    {'form': 'raveden',
#     'tags': ['archaic', 'past', 'plural', 'subjunctive'],
#     'source': 'conjugation'},
#    {'form': 'rave',
#     'tags': ['imperative', 'present', 'singular'],
#     'source': 'conjugation'},
#    {'form': 'ravet',
#     'tags': ['archaic', 'imperative', 'plural', 'present'],
#     'source': 'conjugation'},
#    {'form': 'ravend',
#     'tags': ['participle', 'present'],
#     'source': 'conjugation'},
#    {'form': 'geraved',
#     'tags': ['participle', 'past'],
#     'source': 'conjugation'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'en', '3': 'rave'},
#     'expansion': 'English rave'},
#    {'name': 'surf',
#     'args': {'1': 'nl', '2': 'rave', '3': '-en', 'id2': 'denominative'},
#     'expansion': 'By surface analysis, rave + -en'}]},
#  {'word': 'raven',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['obsolete form of raaf']}},
#   'forms': [{'form': 'ravens', 'tags': ['plural']},
#    {'form': 'ravenen', 'tags': ['plural']},
#    {'form': 'raventje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'glossary',
#     'args': {'1': 'rebracketing'},
#     'expansion': 'rebracketing'}]},
#  {'word': 'raven',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['plural of raaf'],
#     'forms': [{'word': 'raaf'}]}},
#   'forms': [{'word': 'raaf'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'nonlemma',
#     'args': {},
#     'expansion': 'See the etymology of the corresponding lemma form.'}]},
#  {'word': 'dialect',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['dialect (language variety)']},
#    '1': {'glosses': ['non-standard dialect; vernacular']}},
#   'forms': [{'form': 'dialecten', 'tags': ['plural']},
#    {'form': 'dialectje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'der',
#     'args': {'1': 'nl', '2': 'frm', '3': 'dialecte'},
#     'expansion': 'Middle French dialecte'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'la', '3': 'dialectos'},
#     'expansion': 'Latin dialectos'},
#    {'name': 'der',
#     'args': {'1': 'nl',
#      '2': 'grc',
#      '3': 'διάλεκτος',
#      '4': '',
#      '5': 'conversation, the language of a country or a place or a nation, the local idiom which derives from a dominant language'},
#     'expansion': 'Ancient Greek διάλεκτος (diálektos, “conversation, the language of a country or a place or a nation, the local idiom which derives from a dominant language”)'}]},
#  {'word': 'trade',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['singular past subjunctive of treden'],
#     'forms': [{'word': 'treden'}]}},
#   'forms': [{'word': 'treden'}],
#   'wl_code': 'ENF'},
#  {'word': 'patronage',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['patronage (act of providing approval and support)']}},
#   'forms': [{'form': 'patronages', 'tags': ['plural']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'suf',
#     'args': {'1': 'nl', '2': 'patroon', '3': 'age'},
#     'expansion': 'patroon + -age'},
#    {'name': 'cog',
#     'args': {'1': 'en', '2': 'patronage'},
#     'expansion': 'English patronage'}]},
#  {'word': 'deal',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['deal, a transaction or arrangement']},
#    '1': {'glosses': ['a deal, a bargain (a favourable transaction)']}},
#   'forms': [{'form': 'deals', 'tags': ['plural']},
#    {'form': 'dealtje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'ubor',
#     'args': {'1': 'nl', '2': 'en', '3': 'deal'},
#     'expansion': 'Unadapted borrowing from English deal'}]},
#  {'word': 'product',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['product']}},
#   'forms': [{'form': 'producten', 'tags': ['plural']},
#    {'form': 'productje', 'tags': ['diminutive', 'neuter']},
#    {'form': 'produkt', 'tags': ['alternative']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'root',
#     'args': {'1': 'nl', '2': 'ine-pro', '3': '*dewk-'},
#     'expansion': ''},
#    {'name': 'bor',
#     'args': {'1': 'nl', '2': 'la', '3': 'prōductum'},
#     'expansion': 'Latin prōductum'}]},
#  {'word': 'name',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['singular past subjunctive of nemen'],
#     'forms': [{'word': 'nemen'}]}},
#   'forms': [{'word': 'nemen'}],
#   'wl_code': 'ENF'},
#  {'word': 'name',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['dative singular of naam'],
#     'forms': [{'word': 'naam'}]},
#    '1': {'glosses': ['obsolete form of naam']}},
#   'forms': [{'word': 'naam'}],
#   'wl_code': 'ENF'},
#  {'word': 'fa',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['fa (fourth diatonic (or sixth chromatic) musical note)']},
#    '1': {'glosses': ['F (the musical clef or key)']}},
#   'forms': [{'form': "fa's", 'tags': ['plural']},
#    {'form': 'faatje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'la', '3': 'fa'},
#     'expansion': 'Latin fa'}]},
#  {'word': 'a-',
#   'pos': 'prefix',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['a-: not, without, opposite of']}},
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'der',
#     'args': {'1': 'nl', '2': 'grc', '3': 'ἀ-'},
#     'expansion': 'Ancient Greek ἀ- (a-)'}]},
#  {'word': 'aam',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['aam']}},
#   'forms': [{'form': 'amen', 'tags': ['plural']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'ame'},
#     'expansion': 'Middle Dutch ame'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'LL.', '3': 'ama'},
#     'expansion': 'Late Latin ama'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'grc', '3': 'ἄμη', '4': '', '5': 'bucket'},
#     'expansion': 'Ancient Greek ἄμη (ámē, “bucket”)'}]},
#  {'word': 'aardwolf',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['aardwolf']}},
#   'forms': [{'form': 'aardwolven', 'tags': ['plural']},
#    {'form': 'aardwolfje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'af', '3': 'aardwolf'},
#     'expansion': 'Afrikaans aardwolf'},
#    {'name': 'com',
#     'args': {'1': 'nl', '2': 'aard', '3': 'wolf'},
#     'expansion': 'aard + wolf'}]},
#  {'word': 'abacus',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['abacus (arithmetic calculation device, usually with beads on rods)']},
#    '1': {'glosses': ["abacus (upper portion of a column's capital)"]}},
#   'forms': [{'form': 'abaci', 'tags': ['plural']},
#    {'form': 'abacussen', 'tags': ['plural']},
#    {'form': 'abacusje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'la', '3': 'abacus'},
#     'expansion': 'Latin abacus'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'grc', '3': 'ἄβαξ'},
#     'expansion': 'Ancient Greek ἄβαξ (ábax)'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'sem', '3': '-'},
#     'expansion': 'Semitic'}]},
#  {'word': 'abattoir',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['abattoir, slaughterhouse']}},
#   'forms': [{'form': 'abattoirs', 'tags': ['plural']},
#    {'form': 'abattoirtje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'root',
#     'args': {'1': 'nl', '2': 'ine-pro', '3': '*bʰedʰ-'},
#     'expansion': ''},
#    {'name': 'bor',
#     'args': {'1': 'nl', '2': 'fr', '3': 'abattoir'},
#     'expansion': 'French abattoir'}]},
#  {'word': 'abject',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['reprehensible, despicable, abject']}},
#   'forms': [{'form': 'abjecter', 'tags': ['comparative']},
#    {'form': 'abjectst', 'tags': ['superlative']},
#    {'form': 'no-table-tags', 'source': 'declension', 'tags': ['table-tags']},
#    {'form': 'nl-decl-adj',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'abject',
#     'tags': ['adverbial', 'positive', 'predicative'],
#     'source': 'declension'},
#    {'form': 'abjecter',
#     'tags': ['adverbial', 'comparative', 'predicative'],
#     'source': 'declension'},
#    {'form': 'het abjectst',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'het abjectste',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abjecte',
#     'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'abjectere',
#     'tags': ['comparative', 'feminine', 'indefinite', 'masculine', 'singular'],
#     'source': 'declension'},
#    {'form': 'abjectste',
#     'tags': ['feminine', 'indefinite', 'masculine', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abject',
#     'tags': ['indefinite', 'neuter', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'abjecter',
#     'tags': ['comparative', 'indefinite', 'neuter', 'singular'],
#     'source': 'declension'},
#    {'form': 'abjectste',
#     'tags': ['indefinite', 'neuter', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abjecte',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'abjectere',
#     'tags': ['comparative', 'indefinite', 'plural'],
#     'source': 'declension'},
#    {'form': 'abjectste',
#     'tags': ['indefinite', 'plural', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abjecte',
#     'tags': ['definite', 'positive'],
#     'source': 'declension'},
#    {'form': 'abjectere',
#     'tags': ['comparative', 'definite'],
#     'source': 'declension'},
#    {'form': 'abjectste',
#     'tags': ['definite', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abjects',
#     'tags': ['partitive', 'positive'],
#     'source': 'declension'},
#    {'form': 'abjecters',
#     'tags': ['comparative', 'partitive'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['partitive', 'superlative'],
#     'source': 'declension'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'fr', '3': 'abject'},
#     'expansion': 'French abject'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'la', '3': 'abiectus'},
#     'expansion': 'Latin abiectus'}]},
#  {'word': 'abrupt',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['abrupt (sudden)']}},
#   'forms': [{'form': 'abrupter', 'tags': ['comparative']},
#    {'form': 'abruptst', 'tags': ['superlative']},
#    {'form': 'no-table-tags', 'source': 'declension', 'tags': ['table-tags']},
#    {'form': 'nl-decl-adj',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'abrupt',
#     'tags': ['adverbial', 'positive', 'predicative'],
#     'source': 'declension'},
#    {'form': 'abrupter',
#     'tags': ['adverbial', 'comparative', 'predicative'],
#     'source': 'declension'},
#    {'form': 'het abruptst',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'het abruptste',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abrupte',
#     'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'abruptere',
#     'tags': ['comparative', 'feminine', 'indefinite', 'masculine', 'singular'],
#     'source': 'declension'},
#    {'form': 'abruptste',
#     'tags': ['feminine', 'indefinite', 'masculine', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abrupt',
#     'tags': ['indefinite', 'neuter', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'abrupter',
#     'tags': ['comparative', 'indefinite', 'neuter', 'singular'],
#     'source': 'declension'},
#    {'form': 'abruptste',
#     'tags': ['indefinite', 'neuter', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abrupte',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'abruptere',
#     'tags': ['comparative', 'indefinite', 'plural'],
#     'source': 'declension'},
#    {'form': 'abruptste',
#     'tags': ['indefinite', 'plural', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abrupte',
#     'tags': ['definite', 'positive'],
#     'source': 'declension'},
#    {'form': 'abruptere',
#     'tags': ['comparative', 'definite'],
#     'source': 'declension'},
#    {'form': 'abruptste',
#     'tags': ['definite', 'superlative'],
#     'source': 'declension'},
#    {'form': 'abrupts',
#     'tags': ['partitive', 'positive'],
#     'source': 'declension'},
#    {'form': 'abrupters',
#     'tags': ['comparative', 'partitive'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['partitive', 'superlative'],
#     'source': 'declension'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'fr', '3': 'abrupt'},
#     'expansion': 'French abrupt'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'la', '3': 'abruptus'},
#     'expansion': 'Latin abruptus'}]},
#  {'word': 'on',
#   'pos': 'adv',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['rarely used as shorthand for oneven (odd), the prefix on- means not (corresponds to English un-)']}},
#   'wl_code': 'ENF'},
#  {'word': 'kun',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['second-person singular present indicative of kunnen'],
#     'forms': [{'word': 'kunnen'}]}},
#   'forms': [{'word': 'kunnen'}],
#   'wl_code': 'ENF'},
#  {'word': 'quiz',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['quiz']}},
#   'forms': [{'form': 'quizzen', 'tags': ['plural']},
#    {'form': 'quizje', 'tags': ['diminutive', 'neuter']},
#    {'form': 'kwis', 'tags': ['alternative']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor+',
#     'args': {'1': 'nl', '2': 'en', '3': 'quiz'},
#     'expansion': 'Borrowed from English quiz'}]},
#  {'word': 'millennium',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['millennium']}},
#   'forms': [{'form': 'millennia', 'tags': ['plural']},
#    {'form': 'millenniumpje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'la', '3': 'mīllennium'},
#     'expansion': 'Latin mīllennium'}]},
#  {'word': 'week',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['week, period of seven days']}},
#   'forms': [{'form': 'weken', 'tags': ['plural']},
#    {'form': 'weekje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'wēke'},
#     'expansion': 'Middle Dutch wēke'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': '*wika'},
#     'expansion': 'Old Dutch *wika'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*wikā'},
#     'expansion': 'Proto-West Germanic *wikā'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*wikǭ'},
#     'expansion': 'Proto-Germanic *wikǭ'},
#    {'name': 'der',
#     'args': {'1': 'nl',
#      '2': 'ine-pro',
#      '3': '*weyg-',
#      '4': '',
#      '5': 'to bend, wind, turn, yield'},
#     'expansion': 'Proto-Indo-European *weyg- (“to bend, wind, turn, yield”)'}]},
#  {'word': 'week',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['soft, tender, fragile']},
#    '1': {'glosses': ['weak, gentle, weakhearted']}},
#   'forms': [{'form': 'weker', 'tags': ['comparative']},
#    {'form': 'weekst', 'tags': ['superlative']},
#    {'form': 'no-table-tags', 'source': 'declension', 'tags': ['table-tags']},
#    {'form': 'nl-decl-adj',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'week',
#     'tags': ['adverbial', 'positive', 'predicative'],
#     'source': 'declension'},
#    {'form': 'weker',
#     'tags': ['adverbial', 'comparative', 'predicative'],
#     'source': 'declension'},
#    {'form': 'het weekst',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'het weekste',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'weke',
#     'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'wekere',
#     'tags': ['comparative', 'feminine', 'indefinite', 'masculine', 'singular'],
#     'source': 'declension'},
#    {'form': 'weekste',
#     'tags': ['feminine', 'indefinite', 'masculine', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'week',
#     'tags': ['indefinite', 'neuter', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'weker',
#     'tags': ['comparative', 'indefinite', 'neuter', 'singular'],
#     'source': 'declension'},
#    {'form': 'weekste',
#     'tags': ['indefinite', 'neuter', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'weke',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'wekere',
#     'tags': ['comparative', 'indefinite', 'plural'],
#     'source': 'declension'},
#    {'form': 'weekste',
#     'tags': ['indefinite', 'plural', 'superlative'],
#     'source': 'declension'},
#    {'form': 'weke', 'tags': ['definite', 'positive'], 'source': 'declension'},
#    {'form': 'wekere',
#     'tags': ['comparative', 'definite'],
#     'source': 'declension'},
#    {'form': 'weekste',
#     'tags': ['definite', 'superlative'],
#     'source': 'declension'},
#    {'form': 'weeks',
#     'tags': ['partitive', 'positive'],
#     'source': 'declension'},
#    {'form': 'wekers',
#     'tags': ['comparative', 'partitive'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['partitive', 'superlative'],
#     'source': 'declension'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'wêec'},
#     'expansion': 'Middle Dutch wêec'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': '*wēk'},
#     'expansion': 'Old Dutch *wēk'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*waikw'},
#     'expansion': 'Proto-West Germanic *waikw'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*waikwaz'},
#     'expansion': 'Proto-Germanic *waikwaz'}]},
#  {'word': 'week',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['inflection of weken:',
#      'first-person singular present indicative'],
#     'forms': [{'word': 'weken'}]},
#    '1': {'glosses': ['inflection of weken:',
#      'second-person singular present indicative'],
#     'forms': [{'word': 'weken'}]},
#    '2': {'glosses': ['inflection of weken:', 'imperative'],
#     'forms': [{'word': 'weken'}]}},
#   'forms': [{'word': 'weken'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'nonlemma',
#     'args': {},
#     'expansion': 'See the etymology of the corresponding lemma form.'}]},
#  {'word': 'week',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['singular past indicative of wijken'],
#     'forms': [{'word': 'wijken'}]}},
#   'forms': [{'word': 'wijken'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'nonlemma',
#     'args': {},
#     'expansion': 'See the etymology of the corresponding lemma form.'}]},
#  {'word': 'nu',
#   'pos': 'adv',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['now, at the present moment']},
#    '1': {'glosses': ['now, this time (indicating a certain amount of impatience)']}},
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'nu'},
#     'expansion': 'Middle Dutch nu'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'nū'},
#     'expansion': 'Old Dutch nū'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*nu'},
#     'expansion': 'Proto-Germanic *nu'}]},
#  {'word': 'nu',
#   'pos': 'conj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['now (that)']}},
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'nu'},
#     'expansion': 'Middle Dutch nu'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'nū'},
#     'expansion': 'Old Dutch nū'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*nu'},
#     'expansion': 'Proto-Germanic *nu'}]},
#  {'word': 'nu',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['n (letter of the Greek alphabet)']}},
#   'forms': [{'form': "nu's", 'tags': ['plural']},
#    {'form': 'nuutje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'grc', '3': 'νῦ'},
#     'expansion': 'Ancient Greek νῦ (nû)'},
#    {'name': 'doublet',
#     'args': {'1': 'nl', '2': 'noen'},
#     'expansion': 'Doublet of noen'}]},
#  {'word': 'lente',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['spring: the season between winter and summer']},
#    '1': {'glosses': ['year of age']}},
#   'forms': [{'form': 'lentes', 'tags': ['plural']},
#    {'form': 'lentetje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'lentin'},
#     'expansion': 'Middle Dutch lentin'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'lentin'},
#     'expansion': 'Old Dutch lentin'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*langatīn'},
#     'expansion': 'Proto-West Germanic *langatīn'}]},
#  {'word': 'zomer',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['summer']}},
#   'forms': [{'form': 'zomers', 'tags': ['plural']},
#    {'form': 'zomertje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'sōmer'},
#     'expansion': 'Middle Dutch sōmer'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'sumar'},
#     'expansion': 'Old Dutch sumar'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*sumaraz'},
#     'expansion': 'Proto-Germanic *sumaraz'}]},
#  {'word': 'zomer',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['inflection of zomeren:',
#      'first-person singular present indicative'],
#     'forms': [{'word': 'zomeren'}]},
#    '1': {'glosses': ['inflection of zomeren:',
#      'second-person singular present indicative'],
#     'forms': [{'word': 'zomeren'}]},
#    '2': {'glosses': ['inflection of zomeren:', 'imperative'],
#     'forms': [{'word': 'zomeren'}]}},
#   'forms': [{'word': 'zomeren'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'nonlemma',
#     'args': {},
#     'expansion': 'See the etymology of the corresponding lemma form.'}]},
#  {'word': 'herfst',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['autumn, fall']}},
#   'forms': [{'form': 'herfstje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'root',
#     'args': {'1': 'nl', '2': 'ine-pro', '3': '*kerp-'},
#     'expansion': ''},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'herfst'},
#     'expansion': 'Middle Dutch herfst'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': '*hervist'},
#     'expansion': 'Old Dutch *hervist'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*harbist'},
#     'expansion': 'Proto-West Germanic *harbist'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*harbistaz'},
#     'expansion': 'Proto-Germanic *harbistaz'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'ine-pro', '3': '*kerp-'},
#     'expansion': 'Proto-Indo-European *kerp-'},
#    {'name': 'cog',
#     'args': {'1': 'nds', '2': 'Harvst'},
#     'expansion': 'Low German Harvst'},
#    {'name': 'cog',
#     'args': {'1': 'en', '2': 'harvest'},
#     'expansion': 'English harvest'}]},
#  {'word': 'winter',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['winter']}},
#   'forms': [{'form': 'winters', 'tags': ['plural']},
#    {'form': 'wintertje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'winter'},
#     'expansion': 'Middle Dutch winter'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'winter'},
#     'expansion': 'Old Dutch winter'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*wintruz'},
#     'expansion': 'Proto-Germanic *wintruz'}]},
#  {'word': 'robot',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['robot']}},
#   'forms': [{'form': 'robots', 'tags': ['plural']},
#    {'form': 'robotten', 'tags': ['plural']},
#    {'form': 'robotje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'etymon',
#     'args': {'1': 'nl',
#      'id': 'Q11012',
#      '2': ':der',
#      '3': 'cs:robot<id:Q11012>'},
#     'expansion': ''},
#    {'name': 'bor',
#     'args': {'1': 'nl', '2': 'de', '3': 'Robot'},
#     'expansion': 'German Robot'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'cs', '3': 'robot'},
#     'expansion': 'Czech robot'}]},
#  {'word': 'absent',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['absent']}},
#   'forms': [{'form': 'absenter', 'tags': ['comparative']},
#    {'form': 'absentst', 'tags': ['superlative']},
#    {'form': 'no-table-tags', 'source': 'declension', 'tags': ['table-tags']},
#    {'form': 'nl-decl-adj',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'absent',
#     'tags': ['adverbial', 'positive', 'predicative'],
#     'source': 'declension'},
#    {'form': 'absenter',
#     'tags': ['adverbial', 'comparative', 'predicative'],
#     'source': 'declension'},
#    {'form': 'het absentst',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'het absentste',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'absente',
#     'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'absentere',
#     'tags': ['comparative', 'feminine', 'indefinite', 'masculine', 'singular'],
#     'source': 'declension'},
#    {'form': 'absentste',
#     'tags': ['feminine', 'indefinite', 'masculine', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'absent',
#     'tags': ['indefinite', 'neuter', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'absenter',
#     'tags': ['comparative', 'indefinite', 'neuter', 'singular'],
#     'source': 'declension'},
#    {'form': 'absentste',
#     'tags': ['indefinite', 'neuter', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'absente',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'absentere',
#     'tags': ['comparative', 'indefinite', 'plural'],
#     'source': 'declension'},
#    {'form': 'absentste',
#     'tags': ['indefinite', 'plural', 'superlative'],
#     'source': 'declension'},
#    {'form': 'absente',
#     'tags': ['definite', 'positive'],
#     'source': 'declension'},
#    {'form': 'absentere',
#     'tags': ['comparative', 'definite'],
#     'source': 'declension'},
#    {'form': 'absentste',
#     'tags': ['definite', 'superlative'],
#     'source': 'declension'},
#    {'form': 'absents',
#     'tags': ['partitive', 'positive'],
#     'source': 'declension'},
#    {'form': 'absenters',
#     'tags': ['comparative', 'partitive'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['partitive', 'superlative'],
#     'source': 'declension'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor+',
#     'args': {'1': 'nl', '2': 'fr', '3': 'absent'},
#     'expansion': 'Borrowed from French absent'}]},
#  {'word': 'absolutist',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['absolutist (adherent of the absolute sovereignty of rulers)']},
#    '1': {'glosses': ['absolutist (one believing in metaphysical absolutes)']}},
#   'forms': [{'form': 'absolutisten', 'tags': ['plural']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'es', '3': 'absolutista'},
#     'expansion': 'Spanish absolutista'},
#    {'name': 'suf',
#     'args': {'1': 'nl', '2': 'absoluut', '3': 'ist'},
#     'expansion': 'absoluut + -ist'}]},
#  {'word': 'accolade',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['brace, curly bracket ({ })']},
#    '1': {'glosses': ['anything that resembles the above']}},
#   'forms': [{'form': 'accolades', 'tags': ['plural']},
#    {'form': 'accoladetje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'fr', '3': 'accolade'},
#     'expansion': 'French accolade'}]},
#  {'word': 'accurate',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['inflection of accuraat:',
#      'masculine/feminine singular attributive'],
#     'forms': [{'word': 'accuraat'}]},
#    '1': {'glosses': ['inflection of accuraat:',
#      'definite neuter singular attributive'],
#     'forms': [{'word': 'accuraat'}]},
#    '2': {'glosses': ['inflection of accuraat:', 'plural attributive'],
#     'forms': [{'word': 'accuraat'}]}},
#   'forms': [{'word': 'accuraat'}],
#   'wl_code': 'ENF'},
#  {'word': 'alien',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['an alien, an extraterrestrial']}},
#   'forms': [{'form': 'aliens', 'tags': ['plural']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl',
#      '2': 'en',
#      '3': 'alien',
#      '4': '',
#      '5': 'stranger, foreigner'},
#     'expansion': 'English alien (“stranger, foreigner”)'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'enm', '3': 'alien'},
#     'expansion': 'Middle English alien'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'fro', '3': 'alien'},
#     'expansion': 'Old French alien'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'la', '3': 'aliēnus'},
#     'expansion': 'Latin aliēnus'}]},
#  {'word': 'spring',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['inflection of springen:',
#      'first-person singular present indicative'],
#     'forms': [{'word': 'springen'}]},
#    '1': {'glosses': ['inflection of springen:',
#      'second-person singular present indicative'],
#     'forms': [{'word': 'springen'}]},
#    '2': {'glosses': ['inflection of springen:', 'imperative'],
#     'forms': [{'word': 'springen'}]}},
#   'forms': [{'word': 'springen'}],
#   'wl_code': 'ENF'},
#  {'word': 'de',
#   'pos': 'article',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['the; definite article, masculine and feminine singular, plural']}},
#   'forms': [{'form': 'het', 'tags': ['neuter']},
#    {'form': 'een', 'tags': ['indefinite']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'die'},
#     'expansion': 'Middle Dutch die'}]},
#  {'word': 'de',
#   'pos': 'prep',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['per']}},
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'die'},
#     'expansion': 'Middle Dutch die'}]},
#  {'word': 'en',
#   'pos': 'conj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['and']},
#    '1': {'glosses': ['well, so']},
#    '2': {'glosses': ['plus, and']}},
#   'forms': [{'form': 'ende', 'tags': ['alternative', 'archaic']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'ende'},
#     'expansion': 'Middle Dutch ende'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'ande'},
#     'expansion': 'Old Dutch ande'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*andi'},
#     'expansion': 'Proto-Germanic *andi'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'ine-pro', '3': '*h₂entí'},
#     'expansion': 'Proto-Indo-European *h₂entí'}]},
#  {'word': 'en',
#   'pos': 'adv',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['not (often with another negator, see usage notes)']},
#    '1': {'glosses': ['only, merely, no other than, none other than (together with maar)']}},
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'ne'},
#     'expansion': 'Middle Dutch ne'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'ne'},
#     'expansion': 'Old Dutch ne'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*ne'},
#     'expansion': 'Proto-Germanic *ne'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'ine-pro', '3': '*né'},
#     'expansion': 'Proto-Indo-European *né'}]},
#  {'word': 'het',
#   'pos': 'article',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['neuter singular of de (“the”), the definite article'],
#     'forms': [{'word': 'de', 'extra': '(“the”), the definite article'}]}},
#   'forms': [{'word': 'de', 'extra': '(“the”), the definite article'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'dat'},
#     'expansion': 'Middle Dutch dat'}]},
#  {'word': 'het',
#   'pos': 'pron',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['it; third-person singular neuter subjective personal pronoun']},
#    '1': {'glosses': ['it; third-person singular neuter objective personal pronoun']},
#    '2': {'glosses': ['it; impersonal pronoun']}},
#   'forms': [{'form': 'no-table-tags',
#     'source': 'declension',
#     'tags': ['table-tags']},
#    {'form': 'nl-decl-personal pronouns',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'ik',
#     'tags': ['first-person',
#      'personal',
#      'pronoun',
#      'singular',
#      'stressed',
#      'subjective'],
#     'source': 'declension'},
#    {'form': "'k",
#     'tags': ['first-person',
#      'personal',
#      'pronoun',
#      'singular',
#      'subjective',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'mij',
#     'tags': ['first-person',
#      'objective',
#      'personal',
#      'pronoun',
#      'singular',
#      'stressed'],
#     'source': 'declension'},
#    {'form': 'me',
#     'tags': ['first-person',
#      'objective',
#      'personal',
#      'pronoun',
#      'singular',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'mijn',
#     'tags': ['first-person',
#      'personal',
#      'possessive',
#      'pronoun',
#      'singular',
#      'stressed'],
#     'source': 'declension'},
#    {'form': "m'n",
#     'tags': ['first-person',
#      'personal',
#      'possessive',
#      'pronoun',
#      'singular',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'mijne',
#     'tags': ['first-person',
#      'personal',
#      'possessive',
#      'predicative',
#      'pronoun'],
#     'source': 'declension'},
#    {'form': 'me',
#     'tags': ['first-person',
#      'personal',
#      'possessive',
#      'predicative',
#      'pronoun',
#      'reflexive'],
#     'source': 'declension'},
#    {'form': 'mijner',
#     'tags': ['archaic',
#      'first-person',
#      'genitive',
#      'personal',
#      'predicative',
#      'pronoun'],
#     'source': 'declension'},
#    {'form': 'mijns',
#     'tags': ['archaic',
#      'first-person',
#      'genitive',
#      'personal',
#      'predicative',
#      'pronoun'],
#     'source': 'declension'},
#    {'form': 'jij',
#     'tags': ['personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed',
#      'subjective'],
#     'source': 'declension'},
#    {'form': 'je',
#     'tags': ['personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'subjective',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'jou',
#     'tags': ['objective',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed'],
#     'source': 'declension'},
#    {'form': 'je',
#     'tags': ['objective',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'jouw',
#     'tags': ['personal',
#      'possessive',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed'],
#     'source': 'declension'},
#    {'form': 'je',
#     'tags': ['personal',
#      'possessive',
#      'pronoun',
#      'second-person',
#      'singular',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'jouwe',
#     'tags': ['personal',
#      'possessive',
#      'predicative',
#      'pronoun',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'je',
#     'tags': ['personal',
#      'possessive',
#      'predicative',
#      'pronoun',
#      'reflexive',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'jouwer',
#     'tags': ['archaic',
#      'genitive',
#      'personal',
#      'predicative',
#      'pronoun',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'jouws',
#     'tags': ['archaic',
#      'genitive',
#      'personal',
#      'predicative',
#      'pronoun',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'gij',
#     'tags': ['archaic',
#      'dialectal',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed',
#      'subjective'],
#     'source': 'declension'},
#    {'form': 'ge',
#     'tags': ['archaic',
#      'dialectal',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'subjective',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'u',
#     'tags': ['archaic',
#      'dialectal',
#      'objective',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['archaic',
#      'dialectal',
#      'objective',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'uw',
#     'tags': ['archaic',
#      'dialectal',
#      'personal',
#      'possessive',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['archaic',
#      'dialectal',
#      'personal',
#      'possessive',
#      'pronoun',
#      'second-person',
#      'singular',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'uwe',
#     'tags': ['archaic',
#      'dialectal',
#      'personal',
#      'possessive',
#      'predicative',
#      'pronoun',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'u',
#     'tags': ['archaic',
#      'dialectal',
#      'personal',
#      'possessive',
#      'predicative',
#      'pronoun',
#      'reflexive',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'uwer',
#     'tags': ['archaic',
#      'dialectal',
#      'genitive',
#      'personal',
#      'predicative',
#      'pronoun',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'uws',
#     'tags': ['archaic',
#      'dialectal',
#      'genitive',
#      'personal',
#      'predicative',
#      'pronoun',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'u',
#     'tags': ['formal',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed',
#      'subjective'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['formal',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'subjective',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'u',
#     'tags': ['formal',
#      'objective',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['formal',
#      'objective',
#      'personal',
#      'pronoun',
#      'second-person',
#      'singular',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'uw',
#     'tags': ['formal',
#      'personal',
#      'possessive',
#      'pronoun',
#      'second-person',
#      'singular',
#      'stressed'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['formal',
#      'personal',
#      'possessive',
#      'pronoun',
#      'second-person',
#      'singular',
#      'unstressed'],
#     'source': 'declension'},
#    {'form': 'uwe',
#     'tags': ['formal',
#      'personal',
#      'possessive',
#      'predicative',
#      'pronoun',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'u',
#     'tags': ['formal',
#      'personal',
#      'possessive',
#      'predicative',
#      'pronoun',
#      'reflexive',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'zich',
#     'tags': ['formal',
#      'personal',
#      'possessive',
#      'predicative',
#      'pronoun',
#      'reflexive',
#      'second-person'],
#     'source': 'declension'},
#    {'form': 'uwer',
# ...
#     'source': 'declension'},
#    {'form': 'kieze',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'kiezere',
#     'tags': ['comparative', 'indefinite', 'plural'],
#     'source': 'declension'},
#    {'form': 'kieste',
#     'tags': ['indefinite', 'plural', 'superlative'],
#     'source': 'declension'},
#    {'form': 'kieze', 'tags': ['definite', 'positive'], 'source': 'declension'},
#    {'form': 'kiezere',
#     'tags': ['comparative', 'definite'],
#     'source': 'declension'},
#    {'form': 'kieste',
#     'tags': ['definite', 'superlative'],
#     'source': 'declension'},
#    {'form': 'kies', 'tags': ['partitive', 'positive'], 'source': 'declension'},
#    {'form': 'kiezers',
#     'tags': ['comparative', 'partitive'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['partitive', 'superlative'],
#     'source': 'declension'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'unk',
#     'args': {'1': 'nl', 'title': 'Unclear'},
#     'expansion': 'Unclear'},
#    {'name': 'bor',
#     'args': {'1': 'nl', '2': 'enm', '3': 'chis'},
#     'expansion': 'Middle English chis'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'ang', '3': 'ċīs'},
#     'expansion': 'Old English ċīs'}]},
#  {'word': 'kies',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['inflection of kiezen:',
#      'first-person singular present indicative'],
#     'forms': [{'word': 'kiezen'}]},
#    '1': {'glosses': ['inflection of kiezen:',
#      'second-person singular present indicative'],
#     'forms': [{'word': 'kiezen'}]},
#    '2': {'glosses': ['inflection of kiezen:', 'imperative'],
#     'forms': [{'word': 'kiezen'}]}},
#   'forms': [{'word': 'kiezen'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'nonlemma',
#     'args': {},
#     'expansion': 'See the etymology of the corresponding lemma form.'}]},
#  {'word': 'wier',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['seaweed']}},
#   'forms': [{'form': 'wieren', 'tags': ['plural']},
#    {'form': 'wiertje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'wier', '4': '', '5': 'seaweed'},
#     'expansion': 'Middle Dutch wier (“seaweed”)'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': '-'},
#     'expansion': 'Old Dutch'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*wair'},
#     'expansion': 'Proto-West Germanic *wair'},
#    {'name': 'der',
#     'args': {'1': 'nl', '2': 'fy', '3': '-'},
#     'expansion': 'West Frisian'}]},
#  {'word': 'wier',
#   'pos': 'pron',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['whose (feminine, plural)']},
#    '1': {'glosses': ['whose (feminine, plural)']}},
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'root',
#     'args': {'1': 'nl', '2': 'ine-pro', '3': '*kʷ-'},
#     'expansion': ''},
#    {'name': 'suffix',
#     'args': {'1': 'nl',
#      '2': 'wie',
#      '3': '-er',
#      'pos2': 'genitive feminine ending'},
#     'expansion': 'wie + -er (genitive feminine ending)'}]},
#  {'word': 'mond',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['mouth']}},
#   'forms': [{'form': 'monden', 'tags': ['plural']},
#    {'form': 'mondje', 'tags': ['diminutive', 'neuter']},
#    {'form': 'mondt', 'tags': ['alternative']},
#    {'form': 'mont', 'tags': ['alternative']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'mont'},
#     'expansion': 'Middle Dutch mont'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': 'munt'},
#     'expansion': 'Old Dutch munt'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*munþ'},
#     'expansion': 'Proto-West Germanic *munþ'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*munþaz'},
#     'expansion': 'Proto-Germanic *munþaz'}]},
#  {'word': 'mond',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['hand']}},
#   'forms': [{'form': 'monden', 'tags': ['plural']},
#    {'form': 'mondje', 'tags': ['diminutive', 'neuter']},
#    {'form': 'mondt', 'tags': ['alternative']},
#    {'form': 'mont', 'tags': ['alternative']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': '*munda'},
#     'expansion': 'Old Dutch *munda'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*mundō'},
#     'expansion': 'Proto-Germanic *mundō'}]},
#  {'word': 'alert',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['alert']}},
#   'forms': [{'form': 'alerter', 'tags': ['comparative']},
#    {'form': 'alertst', 'tags': ['superlative']},
#    {'form': 'no-table-tags', 'source': 'declension', 'tags': ['table-tags']},
#    {'form': 'nl-decl-adj',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'alert',
#     'tags': ['adverbial', 'positive', 'predicative'],
#     'source': 'declension'},
#    {'form': 'alerter',
#     'tags': ['adverbial', 'comparative', 'predicative'],
#     'source': 'declension'},
#    {'form': 'het alertst',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'het alertste',
#     'tags': ['adverbial', 'predicative', 'superlative'],
#     'source': 'declension'},
#    {'form': 'alerte',
#     'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'alertere',
#     'tags': ['comparative', 'feminine', 'indefinite', 'masculine', 'singular'],
#     'source': 'declension'},
#    {'form': 'alertste',
#     'tags': ['feminine', 'indefinite', 'masculine', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'alert',
#     'tags': ['indefinite', 'neuter', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'alerter',
#     'tags': ['comparative', 'indefinite', 'neuter', 'singular'],
#     'source': 'declension'},
#    {'form': 'alertste',
#     'tags': ['indefinite', 'neuter', 'singular', 'superlative'],
#     'source': 'declension'},
#    {'form': 'alerte',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'alertere',
#     'tags': ['comparative', 'indefinite', 'plural'],
#     'source': 'declension'},
#    {'form': 'alertste',
#     'tags': ['indefinite', 'plural', 'superlative'],
#     'source': 'declension'},
#    {'form': 'alerte',
#     'tags': ['definite', 'positive'],
#     'source': 'declension'},
#    {'form': 'alertere',
#     'tags': ['comparative', 'definite'],
#     'source': 'declension'},
#    {'form': 'alertste',
#     'tags': ['definite', 'superlative'],
#     'source': 'declension'},
#    {'form': 'alerts',
#     'tags': ['partitive', 'positive'],
#     'source': 'declension'},
#    {'form': 'alerters',
#     'tags': ['comparative', 'partitive'],
#     'source': 'declension'},
#    {'form': '-',
#     'tags': ['partitive', 'superlative'],
#     'source': 'declension'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'fr', '3': 'alerte'},
#     'expansion': 'French alerte'}]},
#  {'word': 'aa',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['alternative spelling of a']}},
#   'forms': [{'form': "aa's", 'tags': ['plural']},
#    {'form': 'aatje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF'},
#  {'word': 'wee',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['nauseating']}},
#   'forms': [{'form': 'no-table-tags',
#     'source': 'declension',
#     'tags': ['table-tags']},
#    {'form': 'nl-decl-adj',
#     'source': 'declension',
#     'tags': ['inflection-template']},
#    {'form': 'wee',
#     'tags': ['adverbial', 'positive', 'predicative'],
#     'source': 'declension'},
#    {'form': 'weeë',
#     'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'wee',
#     'tags': ['indefinite', 'neuter', 'positive', 'singular'],
#     'source': 'declension'},
#    {'form': 'weeë',
#     'tags': ['indefinite', 'plural', 'positive'],
#     'source': 'declension'},
#    {'form': 'weeë', 'tags': ['definite', 'positive'], 'source': 'declension'},
#    {'form': 'wees',
#     'tags': ['partitive', 'positive'],
#     'source': 'declension'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': '*wē'},
#     'expansion': 'Old Dutch *wē'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*wai'},
#     'expansion': 'Proto-West Germanic *wai'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*wai'},
#     'expansion': 'Proto-Germanic *wai'},
#    {'name': 'cog',
#     'args': {'1': 'ang', '2': 'wā'},
#     'expansion': 'Old English wā'}]},
#  {'word': 'wee',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['contraction during labour or childbirth']},
#    '1': {'glosses': ['sorrow, sadness, pain, woe (used in interjections of despair or annoyance)']}},
#   'forms': [{'form': 'weeën', 'tags': ['plural']},
#    {'form': 'weetje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': '*wē'},
#     'expansion': 'Old Dutch *wē'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*wai'},
#     'expansion': 'Proto-West Germanic *wai'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gem-pro', '3': '*wai'},
#     'expansion': 'Proto-Germanic *wai'},
#    {'name': 'cog',
#     'args': {'1': 'ang', '2': 'wā'},
#     'expansion': 'Old English wā'}]},
#  {'word': 'brat',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['alternative form of brat']}},
#   'wl_code': 'ENF'},
#  {'word': 'penalty',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['penalty kick']}},
#   'forms': [{'form': "penalty's", 'tags': ['plural']},
#    {'form': "penalty'tje", 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'en', '3': 'penalty'},
#     'expansion': 'English penalty'}]},
#  {'word': 'ekster',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['Eurasian magpie (Pica pica)']},
#    '1': {'glosses': ['magpie (any of various corvids, particularly of the genus Pica)']}},
#   'forms': [{'form': 'eksters', 'tags': ['plural']},
#    {'form': 'ekstertje', 'tags': ['diminutive', 'neuter']},
#    {'form': 'exter', 'tags': ['alternative']},
#    {'form': 'aakster', 'tags': ['alternative']},
#    {'form': 'aekster', 'tags': ['alternative']},
#    {'form': 'aexter', 'tags': ['alternative']},
#    {'form': 'exster', 'tags': ['alternative']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'inh',
#     'args': {'1': 'nl', '2': 'dum', '3': 'egestre'},
#     'expansion': 'Middle Dutch egestre'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'odt', '3': '*agastra'},
#     'expansion': 'Old Dutch *agastra'},
#    {'name': 'inh',
#     'args': {'1': 'nl', '2': 'gmw-pro', '3': '*agastrijā'},
#     'expansion': 'Proto-West Germanic *agastrijā'}]},
#  {'word': 'Vietnamese',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['woman from Vietnam']}},
#   'forms': [{'form': 'Vietnamesen', 'tags': ['plural']},
#    {'form': 'Vietnamees', 'tags': ['masculine']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'suffix',
#     'args': {'1': 'nl', '2': 'Vietnamees', '3': 'e<id:female>'},
#     'expansion': 'Vietnamees + -e'}]},
#  {'word': 'Vietnamese',
#   'pos': 'adj',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['inflection of Vietnamees:',
#      'masculine/feminine singular attributive'],
#     'forms': [{'word': 'Vietnamees'}]},
#    '1': {'glosses': ['inflection of Vietnamees:',
#      'definite neuter singular attributive'],
#     'forms': [{'word': 'Vietnamees'}]},
#    '2': {'glosses': ['inflection of Vietnamees:', 'plural attributive'],
#     'forms': [{'word': 'Vietnamees'}]}},
#   'forms': [{'word': 'Vietnamees'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'suffix',
#     'args': {'1': 'nl', '2': 'Vietnamees', '3': 'e<id:female>'},
#     'expansion': 'Vietnamees + -e'}]},
#  {'word': 'game',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['a video game, an electronic game']}},
#   'forms': [{'form': 'games', 'tags': ['plural']},
#    {'form': 'gamepje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'en', '3': 'game'},
#     'expansion': 'English game'}]},
#  {'word': 'game',
#   'pos': 'verb',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['inflection of gamen:',
#      'first-person singular present indicative'],
#     'forms': [{'word': 'gamen'}]},
#    '1': {'glosses': ['inflection of gamen:',
#      'second-person singular present indicative'],
#     'forms': [{'word': 'gamen'}]},
#    '2': {'glosses': ['inflection of gamen:', 'imperative'],
#     'forms': [{'word': 'gamen'}]},
#    '3': {'glosses': ['inflection of gamen:', 'singular present subjunctive'],
#     'forms': [{'word': 'gamen'}]}},
#   'forms': [{'word': 'gamen'}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'nonlemma',
#     'args': {},
#     'expansion': 'See the etymology of the corresponding lemma form.'}]},
#  {'word': 'precedent',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['precedent']}},
#   'forms': [{'form': 'precedenten', 'tags': ['plural']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'frm', '3': 'precedent'},
#     'expansion': 'Middle French precedent'}]},
#  {'word': 'context',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['context']}},
#   'forms': [{'form': 'contexten', 'tags': ['plural']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'frm', '3': 'contexte'},
#     'expansion': 'Middle French contexte'},
#    {'name': 'bor',
#     'args': {'1': 'nl', '2': 'la', '3': 'contextus'},
#     'expansion': 'Latin contextus'}]},
#  {'word': 'putter',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['a European goldfinch, Eurasian goldfinch (Carduelis carduelis)']}},
#   'forms': [{'form': 'putters', 'tags': ['plural']},
#    {'form': 'puttertje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'suf',
#     'args': {'1': 'nl',
#      '2': 'putten',
#      't1': 'to draw water',
#      '3': 'er',
#      'id2': 'agent noun'},
#     'expansion': 'putten (“to draw water”) + -er'}]},
#  {'word': 'putter',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['a putter, a golf club used to putt']}},
#   'forms': [{'form': 'putters', 'tags': ['plural']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'bor',
#     'args': {'1': 'nl', '2': 'en', '3': 'putter'},
#     'expansion': 'English putter'},
#    {'name': 'suf',
#     'args': {'1': 'nl', '2': 'putten', '3': 'er', 'id2': 'agent noun'},
#     'expansion': 'putten + -er'}]},
#  {'word': 'garden',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['plural of garde'],
#     'forms': [{'word': 'garde'}]}},
#   'forms': [{'word': 'garde'}],
#   'wl_code': 'ENF'},
#  {'word': 'snuffelvliegtuig',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['sniffer plane']}},
#   'forms': [{'form': 'snuffelvliegtuigen', 'tags': ['plural']},
#    {'form': 'snuffelvliegtuigje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'compound',
#     'args': {'1': 'nl', '2': 'snuffelen', '3': 'vliegtuig'},
#     'expansion': 'snuffelen + vliegtuig'}]},
#  {'word': 'paper',
#   'pos': 'noun',
#   'lang_code': 'nl',
#   'senses': {'0': {'glosses': ['paper (short essay or research document), particularly a research paper']}},
#   'forms': [{'form': 'papers', 'tags': ['plural']},
#    {'form': 'papertje', 'tags': ['diminutive', 'neuter']}],
#   'wl_code': 'ENF',
#   'etymology_templates': [{'name': 'ubor',
#     'args': {'1': 'nl', '2': 'en', '3': 'paper'},
#     'expansion': 'Unadapted borrowing from English paper'},
#    {'name': 'doublet',
#     'args': {'1': 'nl', '2': 'papier'},
#     'expansion': 'Doublet of papier'}]},
#  ...]

# %%
ENF_no_change_df = pd.DataFrame(ENF_defs_list_no_change)
ENF_no_change_df
# Out:
#                                   word   pos lang_code  \
# 0                          woordenboek  noun        nl
# 1                               gratis   adj        nl
# 2                              gratuit   adj        nl
# 3                                 word  verb        nl
# 4                                 pond  noun        nl
# ...                                ...   ...       ...
# 128457                       flikkerij  noun        nl
# 128458                      leefruimte  noun        nl
# 128459                    vluchtnummer  noun        nl
# 128460                    overnachting  noun        nl
# 128461  veel voeten in de aarde hebben  verb        nl
#
#                                                    senses  \
# 0                      {'0': {'glosses': ['dictionary']}}
# 1            {'0': {'glosses': ['free, without charge']}}
# 2       {'0': {'glosses': ['gratuitous, not obliged to...
# 3       {'0': {'glosses': ['inflection of worden:', 'f...
# 4       {'0': {'glosses': ['unit of mass, often broadl...
# ...                                                   ...
# 128457                   {'0': {'glosses': ['faggotry']}}
# 128458               {'0': {'glosses': ['living space']}}
# 128459              {'0': {'glosses': ['flight number']}}
# 128460             {'0': {'glosses': ['overnight stay']}}
# 128461  {'0': {'glosses': ['to take some doing, to req...
#
#                                                     forms wl_code  \
# 0       [{'form': 'woordenboeken', 'tags': ['plural']}...     ENF
# 1       [{'form': 'no-table-tags', 'source': 'declensi...     ENF
# 2       [{'form': 'no-table-tags', 'source': 'declensi...     ENF
# 3                                    [{'word': 'worden'}]     ENF
# 4       [{'form': 'ponden', 'tags': ['plural']}, {'for...     ENF
# ...                                                   ...     ...
# 128457                                                NaN     ENF
# 128458  [{'form': 'leefruimten', 'tags': ['plural']}, ...     ENF
# 128459    [{'form': 'vluchtnummers', 'tags': ['plural']}]     ENF
# 128460  [{'form': 'overnachtingen', 'tags': ['plural']...     ENF
# 128461  [{'form': 'veel voeten in aarde hebben', 'tags...     ENF
#
#                                       etymology_templates
# 0       [{'name': 'af', 'args': {'1': 'nl', '2': 'woor...
# 1       [{'name': 'bor', 'args': {'1': 'nl', '2': 'la'...
# 2       [{'name': 'bor', 'args': {'1': 'nl', '2': 'fr'...
# 3                                                     NaN
# 4       [{'name': 'inh', 'args': {'1': 'nl', '2': 'dum...
# ...                                                   ...
# 128457  [{'name': 'af', 'args': {'1': 'nl', '2': 'flik...
# 128458  [{'name': 'compound', 'args': {'1': 'nl', '2':...
# 128459  [{'name': 'compound', 'args': {'1': 'nl', '2':...
# 128460  [{'name': 'af', 'args': {'1': 'nl', '2': 'over...
# 128461  [{'name': 'unknown', 'args': {'1': 'nl', 'titl...
#
# [128462 rows x 7 columns]

# %%
tqdm.pandas(ncols=50)

# %%
enf_dups = get_duplicate_words(ENF_df, filter_by=['word','pos','gloss'])

# %%
enf_dups_gloss = get_duplicate_words(ENF_df, filter_by=['gloss'])

# %%
with pd.option_context('display.max_colwidth', None, 'display.width', 2000, 'display.max_columns', None):
    display(enf_dups)
    display(enf_dups_gloss)
# Out:
#                 word   pos lang_code  sense_code  gloss_code                                                    gloss wl_code                                                                                           forms
# 3               word  verb        nl           0           0                                    inflection of worden:     ENF                                                                            [{'word': 'worden'}]
# 5               word  verb        nl           1           0                                    inflection of worden:     ENF                                                                            [{'word': 'worden'}]
# 7               word  verb        nl           2           0                                    inflection of worden:     ENF                                                                            [{'word': 'worden'}]
# 9               pond  noun        nl           0           0         unit of mass, often broadly similar to 500 grams     ENF  [{'form': 'ponden', 'tags': ['plural']}, {'form': 'pondje', 'tags': ['diminutive', 'neuter']}]
# 11              pond  noun        nl           1           0         unit of mass, often broadly similar to 500 grams     ENF  [{'form': 'ponden', 'tags': ['plural']}, {'form': 'pondje', 'tags': ['diminutive', 'neuter']}]
# ...              ...   ...       ...         ...         ...                                                      ...     ...                                                                                             ...
# 213271  gemotiveerde  verb        nl           1           0                               inflection of gemotiveerd:     ENF                                                                       [{'word': 'gemotiveerd'}]
# 213273  gemotiveerde  verb        nl           2           0                               inflection of gemotiveerd:     ENF                                                                       [{'word': 'gemotiveerd'}]
# 213275      zwaarste   adj        nl           0           0  inflection of zwaarst, the superlative degree of zwaar:     ENF                              [{'word': 'zwaarst', 'extra': 'the superlative degree of zwaar:'}]
# 213277      zwaarste   adj        nl           1           0  inflection of zwaarst, the superlative degree of zwaar:     ENF                              [{'word': 'zwaarst', 'extra': 'the superlative degree of zwaar:'}]
# 213279      zwaarste   adj        nl           2           0  inflection of zwaarst, the superlative degree of zwaar:     ENF                              [{'word': 'zwaarst', 'extra': 'the superlative degree of zwaar:'}]
#
# [44329 rows x 8 columns]
#                                    word   pos lang_code  sense_code  gloss_code                                                    gloss wl_code                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          forms
# 0                           woordenboek  noun        nl           0           0                                               dictionary     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'form': 'woordenboeken', 'tags': ['plural']}, {'form': 'woordenboekje', 'tags': ['diminutive', 'neuter']}, {'form': 'woordboek', 'tags': ['alternative', 'obsolete']}, {'form': 'woordboeck', 'tags': ['alternative', 'obsolete']}]
# 1                                gratis   adj        nl           0           0                                     free, without charge     ENF  [{'form': 'no-table-tags', 'source': 'declension', 'tags': ['table-tags']}, {'form': 'nl-decl-adj', 'source': 'declension', 'tags': ['inflection-template']}, {'form': 'gratis', 'tags': ['adverbial', 'positive', 'predicative'], 'source': 'declension'}, {'form': 'gratis', 'tags': ['feminine', 'indefinite', 'masculine', 'positive', 'singular'], 'source': 'declension'}, {'form': 'gratis', 'tags': ['indefinite', 'neuter', 'positive', 'singular'], 'source': 'declension'}, {'form': 'gratis', 'tags': ['indefinite', 'plural', 'positive'], 'source': 'declension'}, {'form': 'gratis', 'tags': ['definite', 'positive'], 'source': 'declension'}, {'form': 'gratis', 'tags': ['partitive', 'positive'], 'source': 'declension'}]
# 3                                  word  verb        nl           0           0                                    inflection of worden:     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'word': 'worden'}]
# 4                                  word  verb        nl           0           1                 first-person singular present indicative     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'word': 'worden'}]
# 5                                  word  verb        nl           1           0                                    inflection of worden:     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'word': 'worden'}]
# ...                                 ...   ...       ...         ...         ...                                                      ...     ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 213278                         zwaarste   adj        nl           1           1                     definite neuter singular attributive     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'word': 'zwaarst', 'extra': 'the superlative degree of zwaar:'}]
# 213279                         zwaarste   adj        nl           2           0  inflection of zwaarst, the superlative degree of zwaar:     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'word': 'zwaarst', 'extra': 'the superlative degree of zwaar:'}]
# 213280                         zwaarste   adj        nl           2           1                                       plural attributive     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'word': 'zwaarst', 'extra': 'the superlative degree of zwaar:'}]
# 213284  knollen voor citroenen verkopen  verb        nl           0           0                                                  to scam     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# 213289                       leefruimte  noun        nl           0           0                                             living space     ENF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'form': 'leefruimten', 'tags': ['plural']}, {'form': 'leefruimtes', 'tags': ['plural']}]
#
# [100827 rows x 8 columns]

# %%
ENF_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227284 entries, 0 to 227283
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   word        227284 non-null  object
#  1   pos         227284 non-null  object
#  2   lang_code   227284 non-null  object
#  3   sense_code  227284 non-null  object
#  4   gloss_code  227284 non-null  int64
#  5   gloss       227275 non-null  object
#  6   wl_code     227284 non-null  object
#  7   forms       200665 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 13.9+ MB

# %%
both_lang_words = EEF_df.merge(NNF_df, on=['word', 'pos'], how='inner')

# %%
both_lang_words = both_lang_words[both_lang_words['pos'] != 'name']

# %%
both_lang_words
# Out:
#              word   pos lang_code_x  \
# 0       thesaurus  noun          en
# 1          gratis   adj          en
# 2            word  verb          en
# 3            word  verb          en
# 4            pond  noun          en
# ...           ...   ...         ...
# 26185  galoppades  noun          en
# 26186     geelbek  noun          en
# 26191    longread  noun          en
# 26192   longreads  noun          en
# 26193   autogoals  noun          en
#
#                                                 senses_x wl_code_x  \
# 0      {'0': {'glosses': ['A publication that provide...       EEF
# 1          {'0': {'glosses': ['Free: without charge.']}}       EEF
# 2      {'0': {'glosses': ['To say or write (something...       EEF
# 3      {'0': {'glosses': ['Alternative form of worth ...       EEF
# 4      {'0': {'glosses': ['An inland body of standing...       EEF
# ...                                                  ...       ...
# 26185  {'0': {'glosses': ['plural of galoppade.'], 'f...       EEF
# 26186  {'0': {'glosses': ['Alternative form of geelbe...       EEF
# 26191  {'0': {'glosses': ['A piece of (online) long-f...       EEF
# 26192  {'0': {'glosses': ['plural of longread'], 'for...       EEF
# 26193  {'0': {'glosses': ['plural of autogoal'], 'for...       EEF
#
#                                        nl_translations_x lang_code_y  \
# 0      {0: {'word': 'thesaurus', 'sense': 'book of sy...          nl
# 1                                                    NaN          nl
# 2      {0: {'word': 'verwoorden', 'sense': 'to say or...          nl
# 3                                                    NaN          nl
# 4      {0: {'word': 'vijver', 'sense': 'small lake', ...          nl
# ...                                                  ...         ...
# 26185                                                NaN          nl
# 26186                                                NaN          nl
# 26191                                                NaN          nl
# 26192                                                NaN          nl
# 26193                                                NaN          nl
#
#                                                 senses_y wl_code_y  \
# 0      {'0': {'glosses': ['een systematisch georganis...       NNF
# 1      {'0': {'glosses': ['wat zonder betaling verkre...       NNF
# 2      {'0': {'glosses': ['eerste persoon enkelvoud t...       NNF
# 3      {'0': {'glosses': ['eerste persoon enkelvoud t...       NNF
# 4      {'0': {'glosses': ['naam voor verschillende mu...       NNF
# ...                                                  ...       ...
# 26185  {'0': {'glosses': ['meervoud van het zelfstand...       NNF
# 26186  {'0': {'glosses': ['dier met een gele bek']}, ...       NNF
# 26191  {'0': {'glosses': ['lang achtergrond artikel i...       NNF
# 26192  {'0': {'glosses': ['meervoud van het zelfstand...       NNF
# 26193  {'0': {'glosses': ['meervoud van het zelfstand...       NNF
#
#                                          en_translations nl_translations_y
# 0                                                    NaN               NaN
# 1      {0: {'word': 'free', 'sense': 'wat zonder beta...               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4      {0: {'word': 'pound', 'sense': 'naam voor vers...               NaN
# ...                                                  ...               ...
# 26185                                                NaN               NaN
# 26186  {0: {'word': 'African weakfish', 'sense': 'vis...               NaN
# 26191                                                NaN               NaN
# 26192                                                NaN               NaN
# 26193                                                NaN               NaN
#
# [22890 rows x 11 columns]

# %%
both_lang_words.sort_values(by='word')
# Out:
#                word     pos lang_code_x  \
# 5891             'm    pron          en
# 11918            't    pron          en
# 11919            't    pron          en
# 5114             -a  suffix          en
# 5115             -a  suffix          en
# ...             ...     ...         ...
# 4601           über     adv          en
# 20622         über-  prefix          en
# 26117      übercool     adj          en
# 5415     übermensch    noun          en
# 20686  übermenschen    noun          en
#
#                                                 senses_x wl_code_x  \
# 5891    {'0': {'glosses': ['Alternative form of 'em.']}}       EEF
# 11918  {'0': {'glosses': ['Contraction of it.']}, '1'...       EEF
# 11919  {'0': {'glosses': ['Contraction of it.']}, '1'...       EEF
# 5114   {'0': {'glosses': ['plural of -um'], 'forms': ...       EEF
# 5115   {'0': {'glosses': ['plural of -on'], 'forms': ...       EEF
# ...                                                  ...       ...
# 4601   {'0': {'glosses': ['Alternative form of uber.']}}       EEF
# 20622  {'0': {'glosses': ['Alternative form of uber-....       EEF
# 26117  {'0': {'glosses': ['Alternative form of uberco...       EEF
# 5415   {'0': {'glosses': ['An overman (“higher” man) ...       EEF
# 20686  {'0': {'glosses': ['plural of übermensch'], 'f...       EEF
#
#       nl_translations_x lang_code_y  \
# 5891                NaN          nl
# 11918               NaN          nl
# 11919               NaN          nl
# 5114                NaN          nl
# 5115                NaN          nl
# ...                 ...         ...
# 4601                NaN          nl
# 20622               NaN          nl
# 26117               NaN          nl
# 5415                NaN          nl
# 20686               NaN          nl
#
#                                                 senses_y wl_code_y  \
# 5891   {'0': {'glosses': ['clitische voorwerpsvorm vo...       NNF
# 11918  {'0': {'glosses': ['clitische vorm van het als...       NNF
# 11919     {'0': {'glosses': ['clitische vorm van het']}}       NNF
# 5114   {'0': {'glosses': ['vormt een zelfstandig naam...       NNF
# 5115   {'0': {'glosses': ['vormt een zelfstandig naam...       NNF
# ...                                                  ...       ...
# 4601       {'0': {'glosses': ['erg veel, zeer, enorm']}}       NNF
# 20622  {'0': {'glosses': ['in hoge mate, heel erg']},...       NNF
# 26117   {'0': {'glosses': ['meer dan cool, supergaaf']}}       NNF
# 5415   {'0': {'glosses': ['persoon met aangeboren eig...       NNF
# 20686  {'0': {'glosses': ['meervoud van het zelfstand...       NNF
#
#       en_translations nl_translations_y
# 5891              NaN               NaN
# 11918             NaN               NaN
# 11919             NaN               NaN
# 5114              NaN               NaN
# 5115              NaN               NaN
# ...               ...               ...
# 4601              NaN               NaN
# 20622             NaN               NaN
# 26117             NaN               NaN
# 5415              NaN               NaN
# 20686             NaN               NaN
#
# [22890 rows x 11 columns]

# %%
both_english_defs_df = EEF_df.merge(ENF_df, on=['word', 'pos'], how='inner')

# %%
both_english_defs_df[both_english_defs_df['pos'] != 'name']
# Out:
#                    word   pos lang_code_x  \
# 0                gratis   adj          en
# 1                  word  verb          en
# 2                  word  verb          en
# 3                  pond  noun          en
# 4                  pies  noun          en
# ...                 ...   ...         ...
# 11352   Madame Jeanette  noun          en
# 11353           labaria  noun          en
# 11354        dirty chai  noun          en
# 11355  horribile auditu   adv          en
# 11362      Kiekefretter  noun          en
#
#                                                 senses_x wl_code_x  \
# 0          {'0': {'glosses': ['Free: without charge.']}}       EEF
# 1      {'0': {'glosses': ['To say or write (something...       EEF
# 2      {'0': {'glosses': ['Alternative form of worth ...       EEF
# 3      {'0': {'glosses': ['An inland body of standing...       EEF
# 4      {'0': {'glosses': ['plural of pie'], 'forms': ...       EEF
# ...                                                  ...       ...
# 11352  {'0': {'glosses': ['A chili pepper (Capsicum c...       EEF
# 11353          {'0': {'glosses': ['The fer-de-lance.']}}       EEF
# 11354  {'0': {'glosses': ['A chai latte with a shot o...       EEF
# 11355          {'0': {'glosses': ['Horrible to hear.']}}       EEF
# 11362  {'0': {'glosses': ['A native or inhabitant of ...       EEF
#
#                                          nl_translations lang_code_y  \
# 0                                                    NaN          en
# 1      {0: {'word': 'verwoorden', 'sense': 'to say or...          en
# 2                                                    NaN          en
# 3      {0: {'word': 'vijver', 'sense': 'small lake', ...          en
# 4                                                    NaN          en
# ...                                                  ...         ...
# 11352  {0: {'word': 'madame-jeanette', 'sense': 'chil...          en
# 11353                                                NaN          en
# 11354  {0: {'word': 'dirty chai', 'sense': 'chai latt...          en
# 11355  {0: {'word': 'horribile auditu', 'sense': 'hor...          en
# 11362                                                NaN          en
#
#                                                 senses_y wl_code_y
# 0           {'0': {'glosses': ['free, without charge']}}       ENF
# 1      {'0': {'glosses': ['inflection of worden:', 'f...       ENF
# 2      {'0': {'glosses': ['inflection of worden:', 'f...       ENF
# 3      {'0': {'glosses': ['unit of mass, often broadl...       ENF
# 4      {'0': {'glosses': ['alternative form of pis; p...       ENF
# ...                                                  ...       ...
# 11352  {'0': {'glosses': ['alternative form of madame...       ENF
# 11353  {'0': {'glosses': ['synonym of gewone lanspunt...       ENF
# 11354  {'0': {'glosses': ['dirty chai (chai latte wit...       ENF
# 11355  {'0': {'glosses': ['horribile auditu (horrible...       ENF
# 11362  {'0': {'glosses': ['native or inhabitant of Br...       ENF
#
# [9480 rows x 9 columns]

# %%
def extract_single_definition(sense):
    sense = dict(sense)
    if len(sense) == 1:
        if sense['0'].get('glosses'):
            if len(sense['0']['glosses']) == 1:
                definition = sense['0']['glosses'][0]
                return definition
            else:
                return f"multi_gloss: {len(sense['0']['glosses'])}"
        else:
            return "no_gloss"
    else:
        return f"multi_sense: {len(sense)}"

# %%
EEF_df['definition'] = EEF_df['senses'].apply(lambda x: extract_single_definition(x))
# Out:
# C:\Users\elise\AppData\Local\Temp\ipykernel_1536\3680785905.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EEF_df['definition'] = EEF_df['senses'].apply(lambda x: extract_single_definition(x))

# %%
EEF_df_path = Path(current_save_folder, 'EEF_definitions_df.csv')
EEF_df.to_csv(EEF_df_path)

# %%
ENF_df['definition'] = ENF_df['senses'].apply(lambda x: extract_single_definition(x))

# %%
ENF_df_path = Path(current_save_folder, 'ENF_definitions_df.csv')
ENF_df.to_csv(ENF_df_path)

# %%
NEF_df['definition'] = NEF_df['senses'].apply(lambda x: extract_single_definition(x))

# %%
NNF_df['definition'] = NNF_df['senses'].apply(lambda x: extract_single_definition(x))

# %%
NEF_df.head(10)
# Out:
#          word   pos lang_code  \
# 0    busybody  noun        en
# 1   interfere  verb        en
# 2         IPA  noun        en
# 7      French  noun        en
# 8      French   adj        en
# 9     English  noun        en
# 10    English   adj        en
# 11     German  noun        en
# 12     German   adj        en
# 13     Hebrew  noun        en
#
#                                                senses wl_code en_translations  \
# 0   {'0': {'glosses': ['bemoeial; iemand die zich ...     NEF             NaN
# 1                    {'0': {'glosses': ['bemoeien']}}     NEF             NaN
# 2   {'0': {'glosses': ['biersoort gebrouwen uit li...     NEF             NaN
# 7   {'0': {'glosses': ['Frans zn']}, '1': {'glosse...     NEF             NaN
# 8                    {'0': {'glosses': ['Frans bn']}}     NEF             NaN
# 9   {'0': {'glosses': ['Engels']}, '1': {'glosses'...     NEF             NaN
# 10                     {'0': {'glosses': ['Engels']}}     NEF             NaN
# 11  {'0': {'glosses': ['Duitser; inwoner van Duits...     NEF             NaN
# 12  {'0': {'glosses': ['Duits; oorspronkelijk uit ...     NEF             NaN
# 13                  {'0': {'glosses': ['Hebreeuws']}}     NEF             NaN
#
#                                            definition
# 0   bemoeial; iemand die zich bemoeit met zaken va...
# 1                                            bemoeien
# 2   biersoort gebrouwen uit lichte mout waaraan ex...
# 7                                      multi_sense: 3
# 8                                            Frans bn
# 9                                      multi_sense: 2
# 10                                             Engels
# 11                                     multi_sense: 3
# 12  Duits; oorspronkelijk uit Duitsland of uit het...
# 13                                          Hebreeuws

# %%
def transform_df_to_col_table(origin_df, col_name, group_key='def_id'):
    dropped_df = origin_df[~origin_df[col_name].isna()]
    words_df = dropped_df.loc[:, ['entry_id', 'word']]
    df = dropped_df.loc[:, ['entry_id', 'word_id', 'pos', col_name]]
    df[col_name] = df[col_name].apply(safe_eval)
    df = df.explode(col_name, ignore_index=True)
    
    df = pd.concat([df.drop(columns=col_name), pd.json_normalize(df[col_name])],axis=1)
    
    df = df.groupby(group_key, as_index=False).aggregate('first').reindex(columns=df.columns)
    if 'word' in df.columns:
        df = df.rename(columns={'word': col_name})
    
    df = df.merge(words_df, on='def_id')
    df_cols = df.columns.tolist()
    df_cols = df_cols[0:2] + ['word'] + df_cols[2:-1]
    df = df[df_cols]
    #re_df = re_df.insert(1, 'word', col)
    return df

# %%
NEF_df_exploded = NEF_df.explode('senses', ignore_index=True)
NEF_df_exploded = pd.concat([NEF_df_exploded.drop(columns='senses'), pd.json_normalize(NEF_df_exploded['senses'])],axis=1)
NEF_df_exploded
# Out:
#             word   pos lang_code wl_code en_translations  \
# 0       busybody  noun        en     NEF             NaN
# 1      interfere  verb        en     NEF             NaN
# 2            IPA  noun        en     NEF             NaN
# 3         French  noun        en     NEF             NaN
# 4         French  noun        en     NEF             NaN
# ...          ...   ...       ...     ...             ...
# 24907      decay  noun        en     NEF             NaN
# 24908      decay  noun        en     NEF             NaN
# 24909      decay  verb        en     NEF             NaN
# 24910      decay  verb        en     NEF             NaN
# 24911      decay  verb        en     NEF             NaN
#
#                                               definition
# 0      bemoeial; iemand die zich bemoeit met zaken va...
# 1                                               bemoeien
# 2      biersoort gebrouwen uit lichte mout waaraan ex...
# 3                                         multi_sense: 3
# 4                                         multi_sense: 3
# ...                                                  ...
# 24907                                     multi_sense: 2
# 24908                                     multi_sense: 2
# 24909                                     multi_sense: 3
# 24910                                     multi_sense: 3
# 24911                                     multi_sense: 3
#
# [24912 rows x 6 columns]

# %%
NEF_df_exploded
# Out:
#             word   pos lang_code senses wl_code en_translations  \
# 0       busybody  noun        en      0     NEF             NaN
# 1      interfere  verb        en      0     NEF             NaN
# 2            IPA  noun        en      0     NEF             NaN
# 3         French  noun        en      0     NEF             NaN
# 4         French  noun        en      1     NEF             NaN
# ...          ...   ...       ...    ...     ...             ...
# 24907      decay  noun        en      0     NEF             NaN
# 24908      decay  noun        en      1     NEF             NaN
# 24909      decay  verb        en      0     NEF             NaN
# 24910      decay  verb        en      1     NEF             NaN
# 24911      decay  verb        en      2     NEF             NaN
#
#                                               definition
# 0      bemoeial; iemand die zich bemoeit met zaken va...
# 1                                               bemoeien
# 2      biersoort gebrouwen uit lichte mout waaraan ex...
# 3                                         multi_sense: 3
# 4                                         multi_sense: 3
# ...                                                  ...
# 24907                                     multi_sense: 2
# 24908                                     multi_sense: 2
# 24909                                     multi_sense: 3
# 24910                                     multi_sense: 3
# 24911                                     multi_sense: 3
#
# [24912 rows x 7 columns]

# %%
equal_defs_nef = NEF_df[NEF_df['word'] == NEF_df['definition']]

# %%
lang_codes_to_keep = ['nl', 'en', 'simple', 'ang', 'dum', 'nds', 'odt', 'nds-nl', 'enm']

# %%
print(len(one_gloss_defs))
print(len(multi_gloss_defs))
# Out:
# 2165735
# 26278

# %%
display(one_gloss_defs[0:100])
# Out:
# [{'word': 'woordenboek',
#   'pos': 'noun',
#   'definition': 'dictionary',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'gratis',
#   'pos': 'adj',
#   'definition': 'free, without charge',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'gratuit',
#   'pos': 'adj',
#   'definition': 'gratuitous, not obliged to',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'pies',
#   'pos': 'noun',
#   'definition': 'alternative form of pis; pee, piss',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'A',
#   'pos': 'character',
#   'definition': 'The first letter of the Dutch alphabet, written in the Latin script.',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'raven',
#   'pos': 'verb',
#   'definition': 'to (hold a) rave, to party wildly',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'raven',
#   'pos': 'noun',
#   'definition': 'obsolete form of raaf',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'raven',
#   'pos': 'noun',
#   'definition': 'plural of raaf',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'dialect',
#   'pos': 'noun',
#   'definition': 'non-standard dialect; vernacular',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'trade',
#   'pos': 'verb',
#   'definition': 'singular past subjunctive of treden',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'patronage',
#   'pos': 'noun',
#   'definition': 'patronage (act of providing approval and support)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'deal',
#   'pos': 'noun',
#   'definition': 'a deal, a bargain (a favourable transaction)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'product',
#   'pos': 'noun',
#   'definition': 'product',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'name',
#   'pos': 'verb',
#   'definition': 'singular past subjunctive of nemen',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'name',
#   'pos': 'noun',
#   'definition': 'obsolete form of naam',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'f',
#   'pos': 'character',
#   'definition': 'The sixth letter of the Dutch alphabet, written in the Latin script.',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'fa',
#   'pos': 'noun',
#   'definition': 'F (the musical clef or key)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'a-',
#   'pos': 'prefix',
#   'definition': 'a-: not, without, opposite of',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'aam',
#   'pos': 'noun',
#   'definition': 'aam',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'aardwolf',
#   'pos': 'noun',
#   'definition': 'aardwolf',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'abacus',
#   'pos': 'noun',
#   'definition': "abacus (upper portion of a column's capital)",
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'abattoir',
#   'pos': 'noun',
#   'definition': 'abattoir, slaughterhouse',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'abject',
#   'pos': 'adj',
#   'definition': 'reprehensible, despicable, abject',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'abrupt',
#   'pos': 'adj',
#   'definition': 'abrupt (sudden)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'on',
#   'pos': 'adv',
#   'definition': 'rarely used as shorthand for oneven (odd), the prefix on- means not (corresponds to English un-)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'kun',
#   'pos': 'verb',
#   'definition': 'second-person singular present indicative of kunnen',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'quiz',
#   'pos': 'noun',
#   'definition': 'quiz',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'millennium',
#   'pos': 'noun',
#   'definition': 'millennium',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'week',
#   'pos': 'noun',
#   'definition': 'week, period of seven days',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'week',
#   'pos': 'adj',
#   'definition': 'weak, gentle, weakhearted',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'week',
#   'pos': 'verb',
#   'definition': 'singular past indicative of wijken',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'nu',
#   'pos': 'adv',
#   'definition': 'now, this time (indicating a certain amount of impatience)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'nu',
#   'pos': 'conj',
#   'definition': 'now (that)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'nu',
#   'pos': 'noun',
#   'definition': 'n (letter of the Greek alphabet)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'lente',
#   'pos': 'noun',
#   'definition': 'year of age',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'zomer',
#   'pos': 'noun',
#   'definition': 'summer',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'herfst',
#   'pos': 'noun',
#   'definition': 'autumn, fall',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'winter',
#   'pos': 'noun',
#   'definition': 'winter',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'robot',
#   'pos': 'noun',
#   'definition': 'robot',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'absent',
#   'pos': 'adj',
#   'definition': 'absent',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'absolutist',
#   'pos': 'noun',
#   'definition': 'absolutist (one believing in metaphysical absolutes)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'accolade',
#   'pos': 'noun',
#   'definition': 'anything that resembles the above',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'alien',
#   'pos': 'noun',
#   'definition': 'an alien, an extraterrestrial',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'de',
#   'pos': 'article',
#   'definition': 'the; definite article, masculine and feminine singular, plural',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'de',
#   'pos': 'prep',
#   'definition': 'per',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'en',
#   'pos': 'conj',
#   'definition': 'plus, and',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'en',
#   'pos': 'adv',
#   'definition': 'only, merely, no other than, none other than (together with maar)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'het',
#   'pos': 'article',
#   'definition': 'neuter singular of de (“the”), the definite article',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'het',
#   'pos': 'pron',
#   'definition': 'it; impersonal pronoun',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'van',
#   'pos': 'prep',
#   'definition': 'like (quotative (used to introduce direct speech))',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'van',
#   'pos': 'adv',
#   'definition': 'of, about',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'van',
#   'pos': 'noun',
#   'definition': 'any surname',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'hoed',
#   'pos': 'noun',
#   'definition': 'a cover, protecting something else',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'ik',
#   'pos': 'pron',
#   'definition': 'I; first-person singular subjective personal pronoun',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'te',
#   'pos': 'adv',
#   'definition': 'too (indicating excess)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'te',
#   'pos': 'prep',
#   'definition': 'located at, in, on',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'te',
#   'pos': 'article',
#   'definition': 'in idiom; a form of the definite article de',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'dat',
#   'pos': 'det',
#   'definition': 'neuter singular of die (“that”); referring to a thing or a person further away.',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'dat',
#   'pos': 'pron',
#   'definition': 'that, those (regardless of gender and number)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'dat',
#   'pos': 'conj',
#   'definition': 'that (introducing a subordinate clause)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'die',
#   'pos': 'det',
#   'definition': 'a certain, a particular; some; this; referring to a thing or a person invisible or unknown to the audience.',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'die',
#   'pos': 'pron',
#   'definition': 'who, whom, which, that',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'in',
#   'pos': 'prep',
#   'definition': 'in (expressing containment)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'in',
#   'pos': 'adv',
#   'definition': 'into',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'in',
#   'pos': 'adj',
#   'definition': 'in style, fashionable',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'een',
#   'pos': 'article',
#   'definition': 'a, an; indefinite article, placed before a singular noun, indicating a general case of a person or thing',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'een',
#   'pos': 'num',
#   'definition': 'one',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'een',
#   'pos': 'noun',
#   'definition': 'one (use or instance of the number 1)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'hij',
#   'pos': 'pron',
#   'definition': 'he; third-person singular masculine subjective personal pronoun',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'niet',
#   'pos': 'adv',
#   'definition': "not, no, don't: used to express negation.",
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'niet',
#   'pos': 'noun',
#   'definition': 'staple (wire fastener)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'zijn',
#   'pos': 'verb',
#   'definition': 'to be, to equal, to total, to amount to; used to indicate that the values on either side of an equation are the same.',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'zijn',
#   'pos': 'det',
#   'definition': 'its; third-person singular neuter possessive determiner',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'lens',
#   'pos': 'noun',
#   'definition': 'crystalline lens in the eye',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'lens',
#   'pos': 'noun',
#   'definition': 'a type of barbless harpoon used for killing whales',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'lens',
#   'pos': 'noun',
#   'definition': 'alternative form of luns',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'lens',
#   'pos': 'adj',
#   'definition': 'weak, flaccid',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'wolf',
#   'pos': 'noun',
#   'definition': 'one of many other canids of the family Canidae, especially of the genus Canis',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'star',
#   'pos': 'adj',
#   'definition': 'rigid',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'o',
#   'pos': 'intj',
#   'definition': 'oh',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'o',
#   'pos': 'character',
#   'definition': 'The fifteenth letter of the Dutch alphabet, written in the Latin script.',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'acid',
#   'pos': 'noun',
#   'definition': 'acid',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'Mexico',
#   'pos': 'name',
#   'definition': 'ellipsis of Mexico-Stad (= Mexico City): the capital city of Mexico',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'decade',
#   'pos': 'noun',
#   'definition': 'a decade, period of ten years',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'i',
#   'pos': 'character',
#   'definition': 'The ninth letter of the Dutch alphabet, written in the Latin script.',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'letter',
#   'pos': 'noun',
#   'definition': 'letter (written message)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'Japan',
#   'pos': 'name',
#   'definition': 'Japan (a country and archipelago of East Asia)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'beer',
#   'pos': 'noun',
#   'definition': 'a person who is physically impressive and/or crude',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'beer',
#   'pos': 'noun',
#   'definition': 'a male badger',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'beer',
#   'pos': 'noun',
#   'definition': 'liquid, notably human manure (excrement gathered in a pit to fertilize)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'beer',
#   'pos': 'noun',
#   'definition': 'creditor (one to whom one owes debt)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'pseudo-',
#   'pos': 'noun',
#   'definition': 'pseudo-',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'bit',
#   'pos': 'noun',
#   'definition': 'mouthguard',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'bit',
#   'pos': 'noun',
#   'definition': 'bit (datum with two possible values)',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'man',
#   'pos': 'noun',
#   'definition': 'husband, male spouse',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'man',
#   'pos': 'intj',
#   'definition': 'Indicates that something is larger/stronger/... than usual.',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'is',
#   'pos': 'verb',
#   'definition': 'third-person singular present indicative of zijn; is, equals',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'is',
#   'pos': 'adv',
#   'definition': 'clipping of eens',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'are',
#   'pos': 'noun',
#   'definition': 'are, a unit of surface area',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'},
#  {'word': 'rape',
#   'pos': 'verb',
#   'definition': 'singular present subjunctive of rapen',
#   'wl_code': 'ENF',
#   'lang_code': 'nl'}]

# %%
one_gloss_defs_df = pd.DataFrame(one_gloss_defs)

# %%
display(one_gloss_defs_df[~one_gloss_defs_df['translations'].isna()])
# Out:
#                              word   pos  \
# 124707                      event  noun
# 133321                      tonic  noun
# 136657                        LOL  intj
# 139710                         ja   adv
# 139711                         ja  intj
# ...                           ...   ...
# 2164044         Tongeren-Borgloon  name
# 2164129                     Evere  name
# 2164130                  Aarschot  name
# 2164362                Lake Flevo  name
# 2164689  air ambulance helicopter  noun
#
#                                                 definition wl_code lang_code  \
# 124707                                         gebeurtenis     NEF        en
# 133321   een koolzuurhoudende frisdrank met als kenmerk...     NEF        en
# 136657                         hier moet ik hard om lachen     NEF        en
# 139710   duidt bevestiging, instemming, toestemming, in...     NNF        nl
# 139711   nou ja: kijk zo simpel is het! dat je dat niet...     NNF        nl
# ...                                                    ...     ...       ...
# 2164044      A municipality of Limburg, Flanders, Belgium.     EEF        en
# 2164129               A municipality of Brussels, Belgium.     EEF        en
# 2164130             A city in Aerschot, Flanders, Belgium.     EEF        en
# 2164362               An ancient lake in Germania, Europe.     EEF        en
# 2164689  (a helicopter with medical facilities on board...     EEF        en
#
#                                               translations
# 124707   [{'lang_code': 'is', 'lang': 'IJslands', 'word...
# 133321   [{'lang_code': 'en', 'lang': 'Engels', 'word':...
# 136657   [{'lang_code': 'fr', 'lang': 'Frans', 'word': ...
# 139710   [{'lang_code': 'af', 'lang': 'Afrikaans', 'wor...
# 139711   [{'lang_code': 'de', 'lang': 'Duits', 'word': ...
# ...                                                    ...
# 2164044  [{'lang': 'Dutch', 'code': 'nl', 'lang_code': ...
# 2164129  [{'lang': 'Dutch', 'code': 'nl', 'lang_code': ...
# 2164130  [{'lang': 'Dutch', 'code': 'nl', 'lang_code': ...
# 2164362  [{'lang': 'Dutch', 'code': 'nl', 'lang_code': ...
# 2164689  [{'lang': 'Dutch', 'code': 'nl', 'lang_code': ...
#
# [91553 rows x 6 columns]

# %%
dups = one_gloss_defs_df.duplicated(subset=['word'])

# %%
one_gloss_defs_df['duplicated'] = one_gloss_defs_df.duplicated(subset='word')

# %%
one_gloss_defs_df[one_gloss_defs_df['duplicated'] == True]
one
# Out:
#                  word   pos  \
# 6               raven  noun
# 7               raven  noun
# 14               name  noun
# 29               week   adj
# 30               week  verb
# ...               ...   ...
# 2165608  pyridylamine  noun
# 2165649          0/10   adj
# 2165654        fcking  noun
# 2165687         jorks  verb
# 2165718      diffrent   adv
#
#                                                 definition wl_code lang_code  \
# 6                                    obsolete form of raaf     ENF        nl
# 7                                           plural of raaf     ENF        nl
# 14                                   obsolete form of naam     ENF        nl
# 29                               weak, gentle, weakhearted     ENF        nl
# 30                      singular past indicative of wijken     ENF        nl
# ...                                                    ...     ...       ...
# 2165608      Aminopyridine: an amine derived from pyridine     EEF        en
# 2165649                           Bad, horrible, not good.     EEF        en
# 2165654                      Censored spelling of fucking.     EEF        en
# 2165687  third-person singular simple present indicativ...     EEF        en
# 2165718                          Misspelling of different.     EEF        en
#
#         translations  duplicated
# 6                NaN        True
# 7                NaN        True
# 14               NaN        True
# 29               NaN        True
# 30               NaN        True
# ...              ...         ...
# 2165608          NaN        True
# 2165649          NaN        True
# 2165654          NaN        True
# 2165687          NaN        True
# 2165718          NaN        True
#
# [244031 rows x 7 columns]

# %%
one_gloss_defs_df['def_lang'] = one_gloss_defs_df['wl_code'].apply(lambda x: 'en' if x[0] == "E" else "nl")

# %%
one_gloss_defs_df.to_csv(Path(current_save_folder, 'one_gloss_defs.csv'))

# %%
one_gloss_defs_df.rename(columns={'def_code':'def_lang'}, inplace=True)

# %%
one_gloss_defs_df = one_gloss_defs_df.loc[:, ['word', 'pos', 'lang_code', 'def_lang', 'definition', 'translations', 'wl_code', 'duplicated']]

# %%
one_gloss_defs_df
# Out:
#                           word        pos lang_code def_lang  \
# 0                  woordenboek       noun        nl       en
# 1                       gratis        adj        nl       en
# 2                      gratuit        adj        nl       en
# 3                         pies       noun        nl       en
# 4                            A  character        nl       en
# ...                        ...        ...       ...      ...
# 2165730          machine taper       noun        en       en
# 2165731         machine tapers       noun        en       en
# 2165732  authentic assessments       noun        en       en
# 2165733          barn-raisings       noun        en       en
# 2165734                prerift        adj        en       en
#
#                                                 definition translations  \
# 0                                               dictionary          NaN
# 1                                     free, without charge          NaN
# 2                               gratuitous, not obliged to          NaN
# 3                       alternative form of pis; pee, piss          NaN
# 4        The first letter of the Dutch alphabet, writte...          NaN
# ...                                                    ...          ...
# 2165730  A system for securing cutting tools or toolhol...          NaN
# 2165731                            plural of machine taper          NaN
# 2165732                     plural of authentic assessment          NaN
# 2165733                             plural of barn-raising          NaN
# 2165734                           Prior to rift formation.          NaN
#
#         wl_code  duplicated
# 0           ENF       False
# 1           ENF       False
# 2           ENF       False
# 3           ENF       False
# 4           ENF       False
# ...         ...         ...
# 2165730     EEF       False
# 2165731     EEF       False
# 2165732     EEF       False
# 2165733     EEF       False
# 2165734     EEF       False
#
# [2165735 rows x 8 columns]

# %%
duplicated_df = one_gloss_defs_df[one_gloss_defs_df['duplicated'] == True]

# %%
same_rows = one_gloss_defs_df[one_gloss_defs_df['word'] == one_gloss_defs_df['definition']]

# %%
same_rows
# Out:
#                                  word     pos lang_code def_lang  \
# 12                            product    noun        nl       en
# 18                                aam    noun        nl       en
# 19                           aardwolf    noun        nl       en
# 26                               quiz    noun        nl       en
# 27                         millennium    noun        nl       en
# ...                               ...     ...       ...      ...
# 1349491   K. pneumoniae carbapenemase    noun        en       en
# 1385442                          RGSS    name        en       en
# 1513937  I don't want to buy anything  phrase        en       en
# 1736129                        Litvin    noun        en       en
# 2086001                  light orange    noun        en       en
#
#                            definition  \
# 12                            product
# 18                                aam
# 19                           aardwolf
# 26                               quiz
# 27                         millennium
# ...                               ...
# 1349491   K. pneumoniae carbapenemase
# 1385442                          RGSS
# 1513937  I don't want to buy anything
# 1736129                        Litvin
# 2086001                  light orange
#
#                                               translations wl_code  duplicated
# 12                                                     NaN     ENF       False
# 18                                                     NaN     ENF       False
# 19                                                     NaN     ENF       False
# 26                                                     NaN     ENF       False
# 27                                                     NaN     ENF       False
# ...                                                    ...     ...         ...
# 1349491                                                NaN     EEF       False
# 1385442                                                NaN     EEF       False
# 1513937  [{'lang': 'Dutch', 'code': 'nl', 'lang_code': ...     EEF       False
# 1736129                                                NaN     EEF       False
# 2086001                                                NaN     EEF       False
#
# [2124 rows x 8 columns]

# %%
duplicates = one_gloss_defs_df.groupby('word')['lang_code'].nunique().reset_index()
duplicates = duplicates[duplicates['lang_code'] > 1]

# %%
# Out:
#               word  lang_code
# 4             !Xóõ          2
# 73       'Auhelawa          2
# 250            'er          2
# 339             'm          2
# 360             'n          2
# ...            ...        ...
# 1920924      ǃKung          2
# 1921053   β-lactam          2
# 1921238         ◌̀          2
# 1921239         ◌́          2
# 1921243         ◌̈          2
#
# [24803 rows x 2 columns]

# %%
groups = duplicated_df.groupby(group_keys=['word', 'pos'], by='word')

# %%
groups.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 groups.describe()
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\groupby\groupby.py:3603, in GroupBy.describe(self, percentiles, include, exclude)
#    3600     return result.to_frame().T.iloc[:0]
#    3602 with com.temp_setattr(self, "as_index", True):
# -> 3603     result = self._python_apply_general(
#    3604         lambda x: x.describe(
#    3605             percentiles=percentiles, include=include, exclude=exclude
#    3606         ),
#    3607         obj,
#    3608         not_indexed_same=True,
#    3609     )
#    3610 if self.axis == 1:
#    3611     return result.T
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1887, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1852 @final
#    1853 def _python_apply_general(
#    1854     self,
#    (...)   1859     is_agg: bool = False,
#    1860 ) -> NDFrameT:
#    1861     """
#    1862     Apply function f in python space
#    1863
#    (...)   1885         data after applying f
#    1886     """
# -> 1887     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1888     if not_indexed_same is None:
#    1889         not_indexed_same = mutated
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\groupby\ops.py:928, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     926 # group might be modified
#     927 group_axes = group.axes
# --> 928 res = f(group)
#     929 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     930     mutated = True
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\groupby\groupby.py:3604, in GroupBy.describe.<locals>.<lambda>(x)
#    3600     return result.to_frame().T.iloc[:0]
#    3602 with com.temp_setattr(self, "as_index", True):
#    3603     result = self._python_apply_general(
# -> 3604         lambda x: x.describe(
#    3605             percentiles=percentiles, include=include, exclude=exclude
#    3606         ),
#    3607         obj,
#    3608         not_indexed_same=True,
#    3609     )
#    3610 if self.axis == 1:
#    3611     return result.T
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\generic.py:12041, in NDFrame.describe(self, percentiles, include, exclude)
#   11799 @final
#   11800 def describe(
#   11801     self,
#    (...)  11804     exclude=None,
#   11805 ) -> Self:
#   11806     """
#   11807     Generate descriptive statistics.
#   11808
#    (...)  12039     max            NaN      3.0
#   12040     """
# > 12041     return describe_ndframe(
#   12042         obj=self,
#   12043         include=include,
#   12044         exclude=exclude,
#   12045         percentiles=percentiles,
#   12046     ).__finalize__(self, method="describe")
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\methods\describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
#      90 else:
#      91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
# ---> 97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\methods\describe.py:172, in DataFrameDescriber.describe(self, percentiles)
#     170 for _, series in data.items():
#     171     describe_func = select_describe_func(series)
# --> 172     ldesc.append(describe_func(series, percentiles))
#     174 col_names = reorder_columns(ldesc)
#     175 d = concat(
#     176     [x.reindex(col_names, copy=False) for x in ldesc],
#     177     axis=1,
#     178     sort=False,
#     179 )
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\methods\describe.py:272, in describe_categorical_1d(data, percentiles_ignored)
#     262 """Describe series containing categorical data.
#     263
#     264 Parameters
#    (...)    269     Ignored, but in place to unify interface.
#     270 """
#     271 names = ["count", "unique", "top", "freq"]
# --> 272 objcounts = data.value_counts()
#     273 count_unique = len(objcounts[objcounts != 0])
#     274 if count_unique > 0:
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\base.py:1014, in IndexOpsMixin.value_counts(self, normalize, sort, ascending, bins, dropna)
#     927 @final
#     928 def value_counts(
#     929     self,
#    (...)    934     dropna: bool = True,
#     935 ) -> Series:
#     936     """
#     937     Return a Series containing counts of unique values.
#     938
#    (...)   1012     Name: count, dtype: int64
#    1013     """
# -> 1014     return algorithms.value_counts_internal(
#    1015         self,
#    1016         sort=sort,
#    1017         ascending=ascending,
#    1018         normalize=normalize,
#    1019         bins=bins,
#    1020         dropna=dropna,
#    1021     )
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\algorithms.py:954, in value_counts_internal(values, sort, ascending, normalize, bins, dropna)
#     951         result = Series(counts, index=idx, name=name, copy=False)
#     953 if sort:
# --> 954     result = result.sort_values(ascending=ascending)
#     956 if normalize:
#     957     result = result / counts.sum()
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\series.py:3888, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3886 else:
#    3887     values_to_sort = self._values
# -> 3888 sorted_index = nargsort(values_to_sort, kind, bool(ascending), na_position)
#    3890 if is_range_indexer(sorted_index, len(sorted_index)):
#    3891     if inplace:
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\sorting.py:439, in nargsort(items, kind, ascending, na_position, key, mask)
#     437     non_nans = non_nans[::-1]
#     438     non_nan_idx = non_nan_idx[::-1]
# --> 439 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     440 if not ascending:
#     441     indexer = indexer[::-1]
#
# KeyboardInterrupt:

# %% [markdown]
# ## NNF - EEF Replacement Rules Test

# %%
previous_save_path = Path(WIKT_CLEANING_DIR, '13-11-25')
NNF_df_file = Path(previous_save_path, 'NNF_definitions_df.csv')
EEF_df_file = Path(previous_save_path, 'EEF_definitions_df.csv')
NNF_df = pd.read_csv(NNF_df_file, index_col=0)
EEF_df = pd.read_csv(EEF_df_file, index_col=0)
# Out:
# C:\Users\elise\AppData\Local\Temp\ipykernel_26192\2813440772.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   NNF_df = pd.read_csv(NNF_df_file, index_col=0)

# %%
NNF_df
# Out:
#                 word   pos lang_code  sense_code  gloss_code  \
# 0                 ja   adv        nl           0           0
# 1                 ja  intj        nl           0           0
# 2                 ja  intj        nl           1           0
# 3                 ja  noun        nl           0           0
# 4               neen  intj        nl           0           0
# ...              ...   ...       ...         ...         ...
# 709451  mottigaardje  noun        nl           0           0
# 709452   mottigaards  noun        nl           0           0
# 709453   bankpootjes  noun        nl           0           0
# 709454    bankpootje  noun        nl           0           0
# 709455     bankpoten  noun        nl           0           0
#
#                                                     gloss wl_code  \
# 0       duidt bevestiging, instemming, toestemming, in...     NNF
# 1                                     kreet van opwinding     NNF
# 2       nou ja: kijk zo simpel is het! dat je dat niet...     NNF
# 3                      bevestigend of instemmend antwoord     NNF
# 4       ontkenning van de gestelde vraag of gedane bew...     NNF
# ...                                                   ...     ...
# 709451  verkleinwoord enkelvoud van het zelfstandig na...     NNF
# 709452  meervoud van het zelfstandig naamwoord mottigaard     NNF
# 709453  verkleinwoord meervoud van het zelfstandig naa...     NNF
# 709454  verkleinwoord enkelvoud van het zelfstandig na...     NNF
# 709455    meervoud van het zelfstandig naamwoord bankpoot     NNF
#
#                                           en_translations  \
# 0       [{'word': 'yes', 'sense': 'duidt bevestiging o...
# 1       [{'word': 'yes', 'sense': 'kreet van opwinding'}]
# 2       [{'word': 'yes', 'sense': 'kreet van opwinding'}]
# 3       [{'word': 'yes', 'sense': 'bevestigend of inst...
# 4                        [{'word': 'no', 'sense': 'nee'}]
# ...                                                   ...
# 709451                                                NaN
# 709452                                                NaN
# 709453                                                NaN
# 709454                                                NaN
# 709455                                                NaN
#
#                            forms nl_translations
# 0                            NaN             NaN
# 1                            NaN             NaN
# 2                            NaN             NaN
# 3                            NaN             NaN
# 4                            NaN             NaN
# ...                          ...             ...
# 709451  [{'word': 'mottigaard'}]             NaN
# 709452  [{'word': 'mottigaard'}]             NaN
# 709453    [{'word': 'bankpoot'}]             NaN
# 709454    [{'word': 'bankpoot'}]             NaN
# 709455    [{'word': 'bankpoot'}]             NaN
#
# [709456 rows x 10 columns]

# %%
recorder_df = pd.DataFrame(columns=['word', 'pos', 'code', 'test1', 'result1', 'in_en_df'])

# %%
recorder_df = NNF_df.loc[:, ['word', 'pos', 'lang_code']]
recorder_df['word_code'] = recorder_df['word']+ '_' + recorder_df['pos']
recorder_df = recorder_df.drop_duplicates(subset=['word_code'])

# %%
recorder_df = recorder_df.drop_duplicates(subset=['word_code'])
recorder_df = recorder_df.sort_values(by='word_code')

# %%
recorder_df.head(10)
# Out:
#                              word      pos lang_code  \
# 45841                          'k     pron        nl
# 80854                          'm     pron        nl
# 18767                          'n  article        nl
# 604771  'nieuwe' tweezaadlobbigen     noun        nl
# 229473                         'r      adv        nl
# 229469                         'r     pron        nl
# 27585             's anderendaags      adv        nl
# 34532                   's avonds      adv        nl
# 34501                    's daags      adv        nl
# 501430                's dinsdags      adv        nl
#
#                              word_code
# 45841                          'k_pron
# 80854                          'm_pron
# 18767                       'n_article
# 604771  'nieuwe' tweezaadlobbigen_noun
# 229473                          'r_adv
# 229469                         'r_pron
# 27585              's anderendaags_adv
# 34532                    's avonds_adv
# 34501                     's daags_adv
# 501430                 's dinsdags_adv

# %%
EEF_df['word_code'] = EEF_df['word'] + '_' + EEF_df['pos']

# %%
def replace_suffix_tie(word, na_return_val=''):
    if len(word) < 3 or not word.endswith('tie'):
        return na_return_val
    return word[0:-3] + 'tion'
    
def replace_z_begin(word, na_return_val=''):
    if word.startswith('z'):
        return 's' + word[1:]
    return na_return_val
    
def remove_trailing_n(word, na_return_val=''):
    if word.endswith('n'):
        return word[0:-1]
    return na_return_val
    
def remove_end_en(word, na_return_val=''):
    if len(word) > 2 and word.endswith('en'):
        return word[0:-2]
    return na_return_val

def replace_oe_to_oo(word, na_return_val=''):
    index = word.find('oe')
    if index != -1:
        word.replace('oe', 'oo')
        return word
    else:
        return na_return_val

# %%
def replace_letters_in_word(word, original_letters, replace_with, na_return=''):
    if len(word) < len(original_letters):
        return na_return
    index = word.find(original_letters)
    if index != -1:
        word = word.replace(original_letters, replace_with)
        return word
    return na_return

# %%
def replace_beginning_letters(word, original_prefix, replace_with, na_return=''):
    if len(word) < len(original_prefix):
        return na_return
    
    if word.beginswith(original_prefix):
        word = replace_with + word[len(original_prefix):]
        return word
    return na_return

# %%
def replace_end_letters(word, original_suffix, replace_with, na_return=''):
    if len(word) < len(original_suffix):
        return na_return
    if word.endswith(original_suffix):
        word = word[0:-len(original_suffix)] + replace_with
        return word
    return na_return

# %%
recorder_df['test1'] = 'no change'
recorder_df['result1'] = recorder_df['word'].isin(EEF_df['word'])

# %%
display(recorder_df['result1'].value_counts())
recorder_df.head(10)
# Out:
# result1
# False    578143
# True      22189
# Name: count, dtype: int64
#                              word      pos lang_code  \
# 45841                          'k     pron        nl
# 80854                          'm     pron        nl
# 18767                          'n  article        nl
# 604771  'nieuwe' tweezaadlobbigen     noun        nl
# 229473                         'r      adv        nl
# 229469                         'r     pron        nl
# 27585             's anderendaags      adv        nl
# 34532                   's avonds      adv        nl
# 34501                    's daags      adv        nl
# 501430                's dinsdags      adv        nl
#
#                              word_code      test1  result1
# 45841                          'k_pron  no change    False
# 80854                          'm_pron  no change     True
# 18767                       'n_article  no change     True
# 604771  'nieuwe' tweezaadlobbigen_noun  no change    False
# 229473                          'r_adv  no change     True
# 229469                         'r_pron  no change     True
# 27585              's anderendaags_adv  no change    False
# 34532                    's avonds_adv  no change    False
# 34501                     's daags_adv  no change    False
# 501430                 's dinsdags_adv  no change    False

# %%
recorder_df['test2'] = 'drop trailing n'
recorder_df['word2'] = recorder_df['word'].apply(lambda x: remove_trailing_n(x, x))

# %%
recorder_df['result2'] = recorder_df['word2'].isin(EEF_df['word'])

# %%
test = 'result2'
display(recorder_df[test].value_counts())
recorder_df.head(10)
# Out:
# result2
# False    576789
# True      23543
# Name: count, dtype: int64
#                              word      pos lang_code  \
# 45841                          'k     pron        nl
# 80854                          'm     pron        nl
# 18767                          'n  article        nl
# 604771  'nieuwe' tweezaadlobbigen     noun        nl
# 229473                         'r      adv        nl
# 229469                         'r     pron        nl
# 27585             's anderendaags      adv        nl
# 34532                   's avonds      adv        nl
# 34501                    's daags      adv        nl
# 501430                's dinsdags      adv        nl
#
#                              word_code      test1  result1            test2  \
# 45841                          'k_pron  no change    False  drop trailing n
# 80854                          'm_pron  no change     True  drop trailing n
# 18767                       'n_article  no change     True  drop trailing n
# 604771  'nieuwe' tweezaadlobbigen_noun  no change    False  drop trailing n
# 229473                          'r_adv  no change     True  drop trailing n
# 229469                         'r_pron  no change     True  drop trailing n
# 27585              's anderendaags_adv  no change    False  drop trailing n
# 34532                    's avonds_adv  no change    False  drop trailing n
# 34501                     's daags_adv  no change    False  drop trailing n
# 501430                 's dinsdags_adv  no change    False  drop trailing n
#
#                            word2  result2
# 45841                         'k    False
# 80854                         'm     True
# 18767                          '     True
# 604771  'nieuwe' tweezaadlobbige    False
# 229473                        'r     True
# 229469                        'r     True
# 27585            's anderendaags    False
# 34532                  's avonds    False
# 34501                   's daags    False
# 501430               's dinsdags    False

# %%
display(recorder_df['result1'].value_counts())
display(recorder_df['transformed2'].value_counts())
display(recorder_df['result2'].value_counts())
recorder_df.head(10)
# Out:
# result1
# False    580935
# True      19397
# Name: count, dtype: int64
# transformed2
# eene                    7
# ene                     7
# meerdere                6
# al                      6
# boeie                   6
#                        ..
# überseksuelers          1
# α-proteobacterië        1
# β-lactam                1
# β-lactamantibioticum    1
# 's najaars              1
# Name: count, Length: 558357, dtype: int64
# result2
# False    576789
# True      23543
# Name: count, dtype: int64
#                              word      pos lang_code  \
# 45841                          'k     pron        nl
# 80854                          'm     pron        nl
# 18767                          'n  article        nl
# 604771  'nieuwe' tweezaadlobbigen     noun        nl
# 229473                         'r      adv        nl
# 229469                         'r     pron        nl
# 27585             's anderendaags      adv        nl
# 34532                   's avonds      adv        nl
# 34501                    's daags      adv        nl
# 501430                's dinsdags      adv        nl
#
#                              word_code      test1  result1            test2  \
# 45841                          'k_pron  no change    False  drop trailing n
# 80854                          'm_pron  no change     True  drop trailing n
# 18767                       'n_article  no change    False  drop trailing n
# 604771  'nieuwe' tweezaadlobbigen_noun  no change    False  drop trailing n
# 229473                          'r_adv  no change    False  drop trailing n
# 229469                         'r_pron  no change    False  drop trailing n
# 27585              's anderendaags_adv  no change    False  drop trailing n
# 34532                    's avonds_adv  no change    False  drop trailing n
# 34501                     's daags_adv  no change    False  drop trailing n
# 501430                 's dinsdags_adv  no change    False  drop trailing n
#
#                     transformed2  result2
# 45841                         'k    False
# 80854                         'm     True
# 18767                          '     True
# 604771  'nieuwe' tweezaadlobbige    False
# 229473                        'r     True
# 229469                        'r     True
# 27585            's anderendaags    False
# 34532                  's avonds    False
# 34501                   's daags    False
# 501430               's dinsdags    False

# %%
def apply_test(df, check_df, test_num, test_description, original_letters, replace_with, replace_function='middle', na_val='', with_pos_check=False):
    df[f'test{test_num}'] = test_description
    if replace_function == 'begin':
        if not na_val == 'word':
            df[f'word{test_num}'] = df['word'].apply(lambda x: replace_beginning_letters(x, original_letters, replace_with, na_val))
        else:
            df[f'word{test_num}'] = df['word'].apply(lambda x: replace_beginning_letters(x, original_letters, replace_with, x))
    if replace_function == 'end':
        if not na_val == 'word':
            df[f'word{test_num}'] = df['word'].apply(lambda x: replace_end_letters(x, original_letters, replace_with, na_val))
        else:
            df[f'word{test_num}'] = df['word'].apply(lambda x: replace_end_letters(x, original_letters, replace_with, x))
    if replace_function == 'middle':
        if not na_val == 'word':
            df[f'word{test_num}'] = df['word'].apply(lambda x: replace_letters_in_word(x, original_letters, replace_with, na_val))
        else:
            df[f'word{test_num}'] = df['word'].apply(lambda x: replace_letters_in_word(x, original_letters, replace_with, x))
    if with_pos_check:
        temp_col = df[f'word{test_num}'] + '_' + df['pos']
        df[f'result{test_num}'] = temp_col.isin(EEF_df['word_code'])
    else:
        df[f'result{test_num}'] = df[f'word{test_num}'].isin(check_df['word'])
    return df

# %%
apply_test(recorder_df, EEF_df, 3, 'replace oe with oo', 'oe', 'oo', replace_function='middle', na_val='word')
# Out:
#                              word      pos lang_code  \
# 45841                          'k     pron        nl
# 80854                          'm     pron        nl
# 18767                          'n  article        nl
# 604771  'nieuwe' tweezaadlobbigen     noun        nl
# 229473                         'r      adv        nl
# ...                           ...      ...       ...
# 164447              €50-biljetten     noun        nl
# 164411                €500-biljet     noun        nl
# 164466              €500-biljetje     noun        nl
# 164467             €500-biljetjes     noun        nl
# 164465             €500-biljetten     noun        nl
#
#                              word_code      test1  result1            test2  \
# 45841                          'k_pron  no change    False  drop trailing n
# 80854                          'm_pron  no change     True  drop trailing n
# 18767                       'n_article  no change     True  drop trailing n
# 604771  'nieuwe' tweezaadlobbigen_noun  no change    False  drop trailing n
# 229473                          'r_adv  no change     True  drop trailing n
# ...                                ...        ...      ...              ...
# 164447              €50-biljetten_noun  no change    False  drop trailing n
# 164411                €500-biljet_noun  no change    False  drop trailing n
# 164466              €500-biljetje_noun  no change    False  drop trailing n
# 164467             €500-biljetjes_noun  no change    False  drop trailing n
# 164465             €500-biljetten_noun  no change    False  drop trailing n
#
#                            word2  result2               test3  \
# 45841                         'k    False  replace oe with oo
# 80854                         'm     True  replace oe with oo
# 18767                          '     True  replace oe with oo
# 604771  'nieuwe' tweezaadlobbige    False  replace oe with oo
# 229473                        'r     True  replace oe with oo
# ...                          ...      ...                 ...
# 164447              €50-biljette    False  replace oe with oo
# 164411               €500-biljet    False  replace oe with oo
# 164466             €500-biljetje    False  replace oe with oo
# 164467            €500-biljetjes    False  replace oe with oo
# 164465             €500-biljette    False  replace oe with oo
#
#                             word3  result3
# 45841                          'k    False
# 80854                          'm     True
# 18767                          'n     True
# 604771  'nieuwe' tweezaadlobbigen    False
# 229473                         'r     True
# ...                           ...      ...
# 164447              €50-biljetten    False
# 164411                €500-biljet    False
# 164466              €500-biljetje    False
# 164467             €500-biljetjes    False
# 164465             €500-biljetten    False
#
# [600332 rows x 12 columns]

# %%
apply_test(recorder_df, EEF_df, 4, 'replace aa with a', 'aa', 'a', replace_function='middle', na_val='')
# Out:
#                              word      pos lang_code  \
# 45841                          'k     pron        nl
# 80854                          'm     pron        nl
# 18767                          'n  article        nl
# 604771  'nieuwe' tweezaadlobbigen     noun        nl
# 229473                         'r      adv        nl
# ...                           ...      ...       ...
# 164447              €50-biljetten     noun        nl
# 164411                €500-biljet     noun        nl
# 164466              €500-biljetje     noun        nl
# 164467             €500-biljetjes     noun        nl
# 164465             €500-biljetten     noun        nl
#
#                              word_code      test1  result1            test2  \
# 45841                          'k_pron  no change    False  drop trailing n
# 80854                          'm_pron  no change     True  drop trailing n
# 18767                       'n_article  no change     True  drop trailing n
# 604771  'nieuwe' tweezaadlobbigen_noun  no change    False  drop trailing n
# 229473                          'r_adv  no change     True  drop trailing n
# ...                                ...        ...      ...              ...
# 164447              €50-biljetten_noun  no change    False  drop trailing n
# 164411                €500-biljet_noun  no change    False  drop trailing n
# 164466              €500-biljetje_noun  no change    False  drop trailing n
# 164467             €500-biljetjes_noun  no change    False  drop trailing n
# 164465             €500-biljetten_noun  no change    False  drop trailing n
#
#                            word2  result2               test3  \
# 45841                         'k    False  replace oe with oo
# 80854                         'm     True  replace oe with oo
# 18767                          '     True  replace oe with oo
# 604771  'nieuwe' tweezaadlobbige    False  replace oe with oo
# 229473                        'r     True  replace oe with oo
# ...                          ...      ...                 ...
# 164447              €50-biljette    False  replace oe with oo
# 164411               €500-biljet    False  replace oe with oo
# 164466             €500-biljetje    False  replace oe with oo
# 164467            €500-biljetjes    False  replace oe with oo
# 164465             €500-biljette    False  replace oe with oo
#
#                             word3  result3              test4  \
# 45841                          'k    False  replace aa with a
# 80854                          'm     True  replace aa with a
# 18767                          'n     True  replace aa with a
# 604771  'nieuwe' tweezaadlobbigen    False  replace aa with a
# 229473                         'r     True  replace aa with a
# ...                           ...      ...                ...
# 164447              €50-biljetten    False  replace aa with a
# 164411                €500-biljet    False  replace aa with a
# 164466              €500-biljetje    False  replace aa with a
# 164467             €500-biljetjes    False  replace aa with a
# 164465             €500-biljetten    False  replace aa with a
#
#                            word4  result4
# 45841                         'k    False
# 80854                         'm     True
# 18767                         'n     True
# 604771  'nieuwe' tweezadlobbigen    False
# 229473                        'r     True
# ...                          ...      ...
# 164447             €50-biljetten    False
# 164411               €500-biljet    False
# 164466             €500-biljetje    False
# 164467            €500-biljetjes    False
# 164465            €500-biljetten    False
#
# [600332 rows x 15 columns]

# %%
if not Path.exists(current_save_folder):
    Path.mkdir(current_save_folder)
recorder_df.to_csv(Path(current_save_folder, 'recorder_df.csv'))

# %%
def display_results_overview(df, check_changed=True):
    test_indexes = []
    word_indexes = []
    result_indexes = []
    number_words_changed = None
    for i, col in enumerate(df.columns):
        if 'test' in col:
            print('------------')
            print('Test: ', df.iloc[0, i])
        elif 'word' in col and col != 'word_code':
            if check_changed:
                number_words_changed = df[df['word'] != df[col]]
            
                print('Words affected: ', number_words_changed.shape[0])
                
        elif 'result' in col:
            print("Number of words in other dictionary from test: ", len(df[df[col] == True]))
            
            print("Number of words changed in other dictionary: ", number_words_changed[col].value_counts())

# %%
display_results_overview(recorder_df)
# Out:
# Words affected:  0
# ------------
# Test:  no change
# Number of words in other dictionary from test:  22189
# Number of words changed in other dictionary:  Series([], Name: count, dtype: int64)
# ------------
# Test:  drop trailing n
# Words affected:  122718
# Number of words in other dictionary from test:  23543
# Number of words changed in other dictionary:  result2
# False    120195
# True       2523
# Name: count, dtype: int64
# ------------
# Test:  replace oe with oo
# Words affected:  43172
# Number of words in other dictionary from test:  22471
# Number of words changed in other dictionary:  result3
# False    42779
# True       393
# Name: count, dtype: int64
# ------------
# Test:  replace aa with a
# Words affected:  74535
# Number of words in other dictionary from test:  23647
# Number of words changed in other dictionary:  result4
# False    72969
# True      1566
# Name: count, dtype: int64

# %%
apply_test(recorder_df, EEF_df, 5, 'replace tie with tion', 'tie', 'tion', replace_function='end', na_val='word')
# Out:
#                              word      pos lang_code  \
# 45841                          'k     pron        nl
# 80854                          'm     pron        nl
# 18767                          'n  article        nl
# 604771  'nieuwe' tweezaadlobbigen     noun        nl
# 229473                         'r      adv        nl
# ...                           ...      ...       ...
# 164447              €50-biljetten     noun        nl
# 164411                €500-biljet     noun        nl
# 164466              €500-biljetje     noun        nl
# 164467             €500-biljetjes     noun        nl
# 164465             €500-biljetten     noun        nl
#
#                              word_code      test1  result1            test2  \
# 45841                          'k_pron  no change    False  drop trailing n
# 80854                          'm_pron  no change     True  drop trailing n
# 18767                       'n_article  no change     True  drop trailing n
# 604771  'nieuwe' tweezaadlobbigen_noun  no change    False  drop trailing n
# 229473                          'r_adv  no change     True  drop trailing n
# ...                                ...        ...      ...              ...
# 164447              €50-biljetten_noun  no change    False  drop trailing n
# 164411                €500-biljet_noun  no change    False  drop trailing n
# 164466              €500-biljetje_noun  no change    False  drop trailing n
# 164467             €500-biljetjes_noun  no change    False  drop trailing n
# 164465             €500-biljetten_noun  no change    False  drop trailing n
#
#                            word2  result2               test3  \
# 45841                         'k    False  replace oe with oo
# 80854                         'm     True  replace oe with oo
# 18767                          '     True  replace oe with oo
# 604771  'nieuwe' tweezaadlobbige    False  replace oe with oo
# 229473                        'r     True  replace oe with oo
# ...                          ...      ...                 ...
# 164447              €50-biljette    False  replace oe with oo
# 164411               €500-biljet    False  replace oe with oo
# 164466             €500-biljetje    False  replace oe with oo
# 164467            €500-biljetjes    False  replace oe with oo
# 164465             €500-biljette    False  replace oe with oo
#
#                             word3  result3              test4  \
# 45841                          'k    False  replace aa with a
# 80854                          'm     True  replace aa with a
# 18767                          'n     True  replace aa with a
# 604771  'nieuwe' tweezaadlobbigen    False  replace aa with a
# 229473                         'r     True  replace aa with a
# ...                           ...      ...                ...
# 164447              €50-biljetten    False  replace aa with a
# 164411                €500-biljet    False  replace aa with a
# 164466              €500-biljetje    False  replace aa with a
# 164467             €500-biljetjes    False  replace aa with a
# 164465             €500-biljetten    False  replace aa with a
#
#                            word4  result4                  test5  \
# 45841                         'k    False  replace tie with tion
# 80854                         'm     True  replace tie with tion
# 18767                         'n     True  replace tie with tion
# 604771  'nieuwe' tweezadlobbigen    False  replace tie with tion
# 229473                        'r     True  replace tie with tion
# ...                          ...      ...                    ...
# 164447             €50-biljetten    False  replace tie with tion
# 164411               €500-biljet    False  replace tie with tion
# 164466             €500-biljetje    False  replace tie with tion
# 164467            €500-biljetjes    False  replace tie with tion
# 164465            €500-biljetten    False  replace tie with tion
#
#                             word5  result5
# 45841                          'k    False
# 80854                          'm     True
# 18767                          'n     True
# 604771  'nieuwe' tweezaadlobbigen    False
# 229473                         'r     True
# ...                           ...      ...
# 164447              €50-biljetten    False
# 164411                €500-biljet    False
# 164466              €500-biljetje    False
# 164467             €500-biljetjes    False
# 164465             €500-biljetten    False
#
# [600332 rows x 18 columns]

# %%
display_results_overview(recorder_df)
# Out:
# Words affected:  0
# ------------
# Test:  no change
# Number of words in other dictionary from test:  22189
# Number of words changed in other dictionary:  Series([], Name: count, dtype: int64)
# ------------
# Test:  drop trailing n
# Words affected:  122718
# Number of words in other dictionary from test:  23543
# Number of words changed in other dictionary:  result2
# False    120195
# True       2523
# Name: count, dtype: int64
# ------------
# Test:  replace oe with oo
# Words affected:  43172
# Number of words in other dictionary from test:  22471
# Number of words changed in other dictionary:  result3
# False    42779
# True       393
# Name: count, dtype: int64
# ------------
# Test:  replace aa with a
# Words affected:  74535
# Number of words in other dictionary from test:  23647
# Number of words changed in other dictionary:  result4
# False    72969
# True      1566
# Name: count, dtype: int64
# ------------
# Test:  replace tie with tion
# Words affected:  3258
# Number of words in other dictionary from test:  23229
# Number of words changed in other dictionary:  result5
# False    2201
# True     1057
# Name: count, dtype: int64
