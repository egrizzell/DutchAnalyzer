# %%
from dutchanalyzer.config import *
from dutchanalyzer.utilities.utils import *
from dutchanalyzer.utilities.json_utils import *
from dutchanalyzer.utilities.replacement_utils import *

import json
from pathlib import Path

import datetime
import re

import ast
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
NNF_file = Path(WIKT_CLEANING_DIR, 'nl','NNF.jsonl')
NEF_file = Path(WIKT_CLEANING_DIR, 'nl','NEF.jsonl')
EEF_file = Path(WIKT_CLEANING_DIR, 'en','EEF.jsonl')
ENF_file = Path(WIKT_CLEANING_DIR, 'en','ENF.jsonl')
NEF_definitions = Path(WIKT_CLEANING_DIR, 'nl','NEF_definitions.jsonl')
NNF_definitions = Path(WIKT_CLEANING_DIR, 'nl','NNF_definitions.jsonl')
ENF_definitions = Path(WIKT_CLEANING_DIR, 'en','ENF_definitions.jsonl')
EEF_definitions = Path(WIKT_CLEANING_DIR, 'en','EEF_definitions.jsonl')

# %%
EER2_file = Path(EER_DIR, 'EER2.jsonl')
ENR2_file = Path(ENR_DIR, 'ENR2.jsonl')
NER2_file = Path(NER_DIR, 'NER2.jsonl')
NNR2_file = Path(NNR_DIR, 'NNR2.jsonl')

# %%
today = datetime.date.today().__format__("%d-%m-%y")

current_save_folder = Path(INTERIM_DATA_DIR, 'cleaning', 'wikt', str(today))
previous_save_folder = get_previous_save_folder(WIKT_CLEANING_DIR, most_recent=True)

# %%
if not Path.exists(current_save_folder):
    Path.mkdir(current_save_folder, parents=True)

# %% [markdown]
# ## Utils

# %%
def get_translations_list(tlist: list):
    new_t_list = []
    if tlist:
        for tl in tlist:
            if type(tl) == dict:
                if t1.get('word'):
                    new_t_list.append(tl)
                else:
                    tl.get('sense')
    return new_t_list

# %%
def apply_translations_list(df, col):
    new_col_df = []
    
    for i, row in df.iterrows():
        newt = []
        if row[col]:
            newt = [x.get('word') for x in safe_eval(row[col]) if x.get('word')]    
        new_col_df.append({'translation_list': newt})
    return new_col_df

# %% [markdown]
# ## Import DFs

# %%
last_df_folder = Path(WIKT_CLEANING_DIR, '13-11-25')

# %%
NNF_df = pd.read_csv(Path(current_save_folder, 'NNF_definitions_df.csv'), index_col=0)
EEF_df = pd.read_csv(Path(current_save_folder, 'EEF_definitions_df.csv'), index_col=0)
NEF_df = pd.read_csv(Path(current_save_folder, 'NEF_definitions_df.csv'), index_col=0)
ENF_df = pd.read_csv(Path(current_save_folder, 'ENF_definitions_df.csv'), index_col=0)
# Out:
# C:\Users\elise\AppData\Local\Temp\ipykernel_13352\2765474937.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   NNF_df = pd.read_csv(Path(last_df_folder, 'NNF_definitions_df.csv'), index_col=0)

# %%
EEF_df = pd.read_csv(Path(current_save_folder, 'EEF_definitions_df.csv'), index_col=0)

# %%
NNF_df = pd.read_csv(Path(current_save_folder, 'NNF_definitions_df.csv'), index_col=0)
# Out:
# C:\Users\elise\AppData\Local\Temp\ipykernel_12340\3738891819.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   NNF_df = pd.read_csv(Path(current_save_folder, 'NNF_definitions_df.csv'), index_col=0)

# %%
NEF_df.to_csv(Path(current_save_folder, 'NEF_definitions_df.csv'))

# %%
NEF_df.to_csv(Path(current_save_folder, 'NEF_definitions_df.csv'))
EEF_df.to_csv(Path(current_save_folder, 'EEF_definitions_df.csv'))
NNF_df.to_csv(Path(current_save_folder, 'NNF_definitions_df.csv'))
ENF_df.to_csv(Path(current_save_folder, 'ENF_definitions_df.csv'))

# %%
display(EEF_df.info(verbose=True))
EEF_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1464321 entries, 536236 to 198944
# Data columns (total 9 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   word             1464292 non-null  object
#  1   pos              1464321 non-null  object
#  2   lang_code        1464321 non-null  object
#  3   sense_code       1464321 non-null  int64
#  4   gloss_code       1464321 non-null  int64
#  5   gloss            1463461 non-null  object
#  6   wl_code          1464321 non-null  object
#  7   nl_translations  125730 non-null   object
#  8   forms            1176821 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 111.7+ MB
# None
#            word       pos lang_code  sense_code  gloss_code  \
# 536236              punct        en           0           0
# 130442        '    symbol        en           0           0
# 130443        '  particle        en           0           0
# 993527  'Arries      noun        en           0           0
# 993528  'Arriet      noun        en           0           0
# ...         ...       ...       ...         ...         ...
# 96467       NaN      noun        en           1           0
# 96468       NaN      noun        en           2           0
# 96469       NaN      noun        en           3           0
# 96470       NaN      noun        en           0           0
# 198944      NaN      noun        en           0           0
#
#                                                     gloss wl_code  \
# 536236  Used to space out letters in words relating to...     EEF
# 130442                                              See ’     EEF
# 130443                                            See -'.     EEF
# 993527                                    plural of 'Arry     EEF
# 993528                                   A Cockney woman.     EEF
# ...                                                   ...     ...
# 96467    Synonym of nancy: an effeminate male homosexual.     EEF
# 96468                               Synonym of nursemaid.     EEF
# 96469                             Synonym of grandmother.     EEF
# 96470                       Alternative spelling of naan.     EEF
# 198944  Acronym of not a number, applied to numeric va...     EEF
#
#        nl_translations                                       forms
# 536236             NaN    [{'form': '] [', 'tags': ['canonical']}]
# 130442             NaN                                         NaN
# 130443             NaN                                         NaN
# 993527             NaN                         [{'word': "'Arry"}]
# 993528             NaN  [{'form': "'Arriets", 'tags': ['plural']}]
# ...                ...                                         ...
# 96467              NaN      [{'form': 'nans', 'tags': ['plural']}]
# 96468              NaN      [{'form': 'nans', 'tags': ['plural']}]
# 96469              NaN      [{'form': 'nans', 'tags': ['plural']}]
# 96470              NaN      [{'form': 'nans', 'tags': ['plural']}]
# 198944             NaN      [{'form': 'NaNs', 'tags': ['plural']}]
#
# [1464321 rows x 9 columns]

# %% [markdown]
# ## Sort and Refine Values

# %%
EEF_df.sort_values(by='word', inplace=True)
NNF_df.sort_values(by='word', inplace=True)
NEF_df.sort_values(by='word', inplace=True)
ENF_df.sort_values(by='word', inplace=True)

# %%
EEF_df.sort_values(by='word', inplace=True)

# %%
NNF_df['en_translations'].value_counts()
# Out:
# en_translations
# [{'word': 'moderator', 'sense': None}]                                                                                                                                                                                                                                                                                   25
# [{'word': 'affiliate', 'sense': None}]                                                                                                                                                                                                                                                                                   24
# [{'word': 'delineate', 'sense': '1 ergens een lijn omheen tekenen'}, {'word': 'draw', 'sense': '1 ergens een lijn omheen tekenen'}]                                                                                                                                                                                      22
# [{'word': 'in', 'sense': '-12. in (ruimtelijk)'}, {'word': 'in', 'sense': 'in (tijdelijk)'}]                                                                                                                                                                                                                             19
# [{'word': 'bridge', 'sense': 'kunstmatige weg over een diepte'}]                                                                                                                                                                                                                                                         16
#                                                                                                                                                                                                                                                                                                                          ..
# [{'word': 'β-lactam antibiotic', 'sense': 'een stof behorende tot een groep antimicrobiële middelen die de productie van celwandcomponenten remmen ...'}, {'word': 'beta-lactam antibiotic', 'sense': 'een stof behorende tot een groep antimicrobiële middelen die de productie van celwandcomponenten remmen ...'}]     1
# [{'word': 'dispar vulgo', 'sense': 'afwijkend van de grote massa'}]                                                                                                                                                                                                                                                       1
# [{'word': 'dispensing machine', 'sense': None}, {'word': 'dispenser', 'sense': None}]                                                                                                                                                                                                                                     1
# [{'word': "at someone's disposal", 'sense': 'beschikbaar'}, {'word': 'vacant', 'sense': 'beschikbaar'}, {'word': 'available', 'sense': 'beschikbaar'}]                                                                                                                                                                    1
# [{'word': 'in winter', 'sense': 'gedurende de winter'}]                                                                                                                                                                                                                                                                   1
# Name: count, Length: 35614, dtype: int64

# %% [markdown]
# ## Pull Word Level/Short/Long Translations

# %%
EEF_df
# Out:
#            word       pos lang_code  sense_code  gloss_code  \
# 536236              punct        en           0           0
# 130442        '    symbol        en           0           0
# 130443        '  particle        en           0           0
# 993527  'Arries      noun        en           0           0
# 993528  'Arriet      noun        en           0           0
# ...         ...       ...       ...         ...         ...
# 96467       NaN      noun        en           1           0
# 96468       NaN      noun        en           2           0
# 96469       NaN      noun        en           3           0
# 96470       NaN      noun        en           0           0
# 198944      NaN      noun        en           0           0
#
#                                                     gloss wl_code  \
# 536236  Used to space out letters in words relating to...     EEF
# 130442                                              See ’     EEF
# 130443                                            See -'.     EEF
# 993527                                    plural of 'Arry     EEF
# 993528                                   A Cockney woman.     EEF
# ...                                                   ...     ...
# 96467    Synonym of nancy: an effeminate male homosexual.     EEF
# 96468                               Synonym of nursemaid.     EEF
# 96469                             Synonym of grandmother.     EEF
# 96470                       Alternative spelling of naan.     EEF
# 198944  Acronym of not a number, applied to numeric va...     EEF
#
#        nl_translations                                       forms
# 536236             NaN    [{'form': '] [', 'tags': ['canonical']}]
# 130442             NaN                                         NaN
# 130443             NaN                                         NaN
# 993527             NaN                         [{'word': "'Arry"}]
# 993528             NaN  [{'form': "'Arriets", 'tags': ['plural']}]
# ...                ...                                         ...
# 96467              NaN      [{'form': 'nans', 'tags': ['plural']}]
# 96468              NaN      [{'form': 'nans', 'tags': ['plural']}]
# 96469              NaN      [{'form': 'nans', 'tags': ['plural']}]
# 96470              NaN      [{'form': 'nans', 'tags': ['plural']}]
# 198944             NaN      [{'form': 'NaNs', 'tags': ['plural']}]
#
# [1464321 rows x 9 columns]

# %%
EEF_translations_df = EEF_df.loc[:, ['word', 'pos', 'lang_code', 'nl_translations']]
NNF_translations_df = NNF_df.loc[:, ['word', 'pos', 'lang_code', 'en_translations']]

# %%
new_translations_list = []
for i, row in tqdm(EEF_translations_df.iterrows()):
    translations = row['nl_translations']
    
    if translations:
        if type(translations) != float:
            new_list = get_translations_list(translations)
        else:
            new_list = []
    new_translations_list.append({'new_translations': new_list})
EEF_df['new_translations'] = new_translations_list
# Out:
# 1464321it [00:37, 39100.23it/s]

# %%
EEF_df['new_translations'].value_counts()
# Out:
# new_translations
# {'new_translations': []}    1464321
# Name: count, dtype: int64

# %%
def get_translations_list(tlist: list):
    new_t_list = []
    if tlist:
        for tl in tlist:
            if type(tl) == dict:
                if tl.get('word'):
                    new_t_list.append(tl)
                else:
                    tl.get('sense')
    return new_t_list

# %%
print(EEF_translations_df['nl_translations'].value_counts())
EEF_translations_df['nl_translations'].info(verbose=True)

# %% [markdown]
# ## 17-11-25

# %%
NNF2 = []

# %%
NNF2_full_lines = []

# %%
NNF_senses = []
NNF_translations = []
NNF_synonyms = []
NNF_forms = []

# %%
def strip_obj(obj):
    keep_keys = ['word', 'pos', 'lang_code', 'lang', 'standard_lang', 'forms', 'senses', 'translations', 'synonyms', 'etemology_templates', 'sounds']
    obj_keys = list(obj.keys())
    for k in obj_keys:
        if k not in keep_keys:
            obj.pop(k)

# %%
with open(NNR2_file, 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in lines:
        obj = json.loads(line)
        if obj:
            #strip_obj(obj)
            NNF2_full_lines.append(obj)

# %%
NNF2_df = pd.DataFrame(NNF2)

# %%
NNF2_full_df = pd.DataFrame(NNF2_full_lines)

# %%
NNF2_full_df['word_code'] = NNF2_full_df['word'] + '_' + NNF2_full_df['pos']

# %%
NNF2_full_df['dups'] = NNF2_full_df.duplicated(subset=['word_code'])

# %%
NNF2_full_df
# Out:
#                 word      pos lang_code        lang standard_lang  \
# 0                 ja      adv        nl  Nederlands         dutch
# 1                 ja     intj        nl  Nederlands         dutch
# 2                 ja     noun        nl  Nederlands         dutch
# 3               neen     intj        nl  Nederlands         dutch
# 4                een  article        nl  Nederlands         dutch
# ...              ...      ...       ...         ...           ...
# 609641  mottigaardje     noun        nl  Nederlands         dutch
# 609642   mottigaards     noun        nl  Nederlands         dutch
# 609643   bankpootjes     noun        nl  Nederlands         dutch
# 609644    bankpootje     noun        nl  Nederlands         dutch
# 609645     bankpoten     noun        nl  Nederlands         dutch
#
#                                                    senses  \
# 0       [{'glosses': ['duidt bevestiging, instemming, ...
# 1       [{'glosses': ['kreet van opwinding'], 'example...
# 2       [{'glosses': ['bevestigend of instemmend antwo...
# 3       [{'glosses': ['ontkenning van de gestelde vraa...
# 4       [{'glosses': ['onbepaald lidwoord dat in het N...
# ...                                                   ...
# 609641  [{'glosses': ['verkleinwoord enkelvoud van het...
# 609642  [{'glosses': ['meervoud van het zelfstandig na...
# 609643  [{'glosses': ['verkleinwoord meervoud van het ...
# 609644  [{'glosses': ['verkleinwoord enkelvoud van het...
# 609645  [{'glosses': ['meervoud van het zelfstandig na...
#
#                                    antonyms  \
# 0       [{'word': 'neen'}, {'word': 'nee'}]
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 609641                                  NaN
# 609642                                  NaN
# 609643                                  NaN
# 609644                                  NaN
# 609645                                  NaN
#
#                                                categories  \
# 0       [Bijwoord in het Nederlands, Ontbrekend geluid...
# 1       [Ontbrekend geluid, Retrograad van het Nederla...
# 2       [Ontbrekend geluid, Retrograad van het Nederla...
# 3       [Ontbrekend geluid, Retrograad van het Nederla...
# 4       [Erfwoord_in_het_Nederlands, Lidwoord in het N...
# ...                                                   ...
# 609641  [Ontbrekend geluid, Retrograad van het Nederla...
# 609642  [Ontbrekend geluid, Retrograad van het Nederla...
# 609643  [Ontbrekend geluid, Retrograad van het Nederla...
# 609644  [Ontbrekend geluid, Retrograad van het Nederla...
# 609645  [Ontbrekend geluid, Retrograad van het Nederla...
#
#                                                   derived  \
# 0       [{'word': 'ja knikken'}, {'word': 'ja-neevraag...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       [{'word': 'eenzelfde'}, {'word': 'eene'}, {'wo...
# ...                                                   ...
# 609641                                                NaN
# 609642                                                NaN
# 609643                                                NaN
# 609644                                                NaN
# 609645                                                NaN
#
#                                           etymology_texts  ...  \
# 0       [In de betekenis van ‘tussenwerpsel: uitroep t...  ...
# 1       [In de betekenis van ‘tussenwerpsel: uitroep t...  ...
# 2       [In de betekenis van ‘tussenwerpsel: uitroep t...  ...
# 3       [In de betekenis van ‘tussenwerpsel: uitroep t...  ...
# 4       [erfwoord, via Middelnederlands een van Oudned...  ...
# ...                                                   ...  ...
# 609641                                                NaN  ...
# 609642                                                NaN  ...
# 609643                                                NaN  ...
# 609644                                                NaN  ...
# 609645                                                NaN  ...
#
#                                                     forms hypernyms  \
# 0                                                     NaN       NaN
# 1                                                     NaN       NaN
# 2                                                     NaN       NaN
# 3                                                     NaN       NaN
# 4       [{'form': '[A] een', 'tags': ['canonical']}, {...       NaN
# ...                                                   ...       ...
# 609641                                                NaN       NaN
# 609642                                                NaN       NaN
# 609643                                                NaN       NaN
# 609644                                                NaN       NaN
# 609645                                                NaN       NaN
#
#        homophones holonyms metonyms descendants abbreviations paronyms  \
# 0             NaN      NaN      NaN         NaN           NaN      NaN
# 1             NaN      NaN      NaN         NaN           NaN      NaN
# 2             NaN      NaN      NaN         NaN           NaN      NaN
# 3             NaN      NaN      NaN         NaN           NaN      NaN
# 4             NaN      NaN      NaN         NaN           NaN      NaN
# ...           ...      ...      ...         ...           ...      ...
# 609641        NaN      NaN      NaN         NaN           NaN      NaN
# 609642        NaN      NaN      NaN         NaN           NaN      NaN
# 609643        NaN      NaN      NaN         NaN           NaN      NaN
# 609644        NaN      NaN      NaN         NaN           NaN      NaN
# 609645        NaN      NaN      NaN         NaN           NaN      NaN
#
#                 word_code   dups
# 0                  ja_adv  False
# 1                 ja_intj  False
# 2                 ja_noun  False
# 3               neen_intj  False
# 4             een_article  False
# ...                   ...    ...
# 609641  mottigaardje_noun  False
# 609642   mottigaards_noun  False
# 609643   bankpootjes_noun  False
# 609644    bankpootje_noun  False
# 609645     bankpoten_noun  False
#
# [609646 rows x 28 columns]

# %%
NNF2_full_df_dups = NNF2_full_df[NNF2_full_df['dups'] == True]

# %%
NNF2_full_df_dups.drop(columns=['metonyms', 'abbreviations', 'paronyms'], inplace=True)
# Out:
# C:\Users\elise\AppData\Local\Temp\ipykernel_20960\4214524548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NNF2_full_df_dups.drop(columns=['metonyms', 'abbreviations', 'paronyms'], inplace=True)

# %%
NNF2_full_df_dups.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3004 entries, 13 to 608760
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   word             3004 non-null   object
#  1   pos              3004 non-null   object
#  2   lang_code        3004 non-null   object
#  3   lang             3004 non-null   object
#  4   standard_lang    3004 non-null   object
#  5   senses           3004 non-null   object
#  6   antonyms         24 non-null     object
#  7   categories       3004 non-null   object
#  8   derived          290 non-null    object
#  9   etymology_texts  1668 non-null   object
#  10  hyphenations     2999 non-null   object
#  11  hyponyms         179 non-null    object
#  12  related          253 non-null    object
#  13  sounds           3001 non-null   object
#  14  translations     3004 non-null   object
#  15  tags             1924 non-null   object
#  16  notes            47 non-null     object
#  17  synonyms         375 non-null    object
#  18  forms            1825 non-null   object
#  19  hypernyms        165 non-null    object
#  20  homophones       25 non-null     object
#  21  holonyms         2 non-null      object
#  22  descendants      5 non-null      object
#  23  word_code        3004 non-null   object
#  24  dups             3004 non-null   bool
# dtypes: bool(1), object(24)
# memory usage: 589.7+ KB

# %%
NNF2_df['word_code'] = NNF2_df['word'] + '_' + NNF2_df['pos']

# %%
dups = NNF2_df.duplicated(subset=['word_code'])

# %%
NNF2_df['dup'] = dups

# %%
dup_rows = NNF2_df[NNF2_df['dup'] == True]

# %%
groups = dup_rows.groupby(dup_rows['word'], group_keys='word_code')

# %%
def highlight(d):
    df = pd.DataFrame(columns=d.columns, index=d.index)
    
    col1 = d.columns[0]
    col2 = d.columns[1]
    df[[col1, col2]] = 'background: None'
    
    df.loc[d[col1].ne(d[col2]), [col1, col2]] = 'background: yellow'

    return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 12
#       8     df.loc[d[col1].ne(d[col2]), [col1, col2]] = 'background: yellow'
#      10     return df
# ---> 12 df.loc[:1].T.style.apply(highlight, axis=None)
#
# NameError: name 'df' is not defined

# %%
def standardize_forms(form_dict):
    if isinstance(form_dict, dict):
        new_forms = []
        if 'form' in form_dict:
            form = form_dict['form']
            if ']' in form:
                form = form.split(']')

                print('split form',form)
                if len(form) > 1:
                    form = form[1]
                    form_dict['form'] = form[1]
            return form_dict
                #form_dict['form'] = form.split(']')[1]

# %%
NNF2_full_df_dups[NNF2_full_df_dups.apply(lambda x: [standardize_forms(y) for y in x['forms']])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'forms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 NNF2_full_df_dups[NNF2_full_df_dups.apply(lambda x: [standardize_forms(y) for y in x['forms']])]
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[73], line 1, in <lambda>(x)
# ----> 1 NNF2_full_df_dups[NNF2_full_df_dups.apply(lambda x: [standardize_forms(y) for y in x['forms']])]
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'forms'

# %%
NNF2_full_df_dups['forms'].value_counts()
# Out:
# forms
# [{'form': '[B]', 'tags': ['canonical']}]                                                                                                                    7
# [{'form': 'beren', 'tags': ['plural']}, {'form': 'beertje', 'tags': ['diminutive', 'singular']}, {'form': 'beertjes', 'tags': ['diminutive', 'plural']}]    4
# [{'form': 'kolot', 'tags': ['plural']}]                                                                                                                     3
# [{'form': 'voerde over', 'tags': ['past']}, {'form': 'overgevoerd', 'tags': ['past', 'participle']}]                                                        3
# [{'form': '[B] mul', 'tags': ['canonical']}]                                                                                                                3
#                                                                                                                                                            ..
# [{'form': 'overíjle', 'tags': ['canonical']}]                                                                                                               1
# [{'form': 'overjáge', 'tags': ['canonical']}]                                                                                                               1
# [{'form': 'overkáppe', 'tags': ['canonical']}]                                                                                                              1
# [{'form': 'overkíjke', 'tags': ['canonical']}]                                                                                                              1
# [{'form': 'overléze', 'tags': ['canonical']}]                                                                                                               1
# Name: count, Length: 1763, dtype: int64

# %%
display(forms.value_counts())
# Out:
# Series([], Name: count, dtype: int64)

# %%
froms = NNF2_full_df_dups.apply()

# %%
drop_indexes = []
same_word_code = []
counter = 0
last_row_index = 0
last_row = NNF2_full_df_dups.iloc[0, :]
new_rows = []
for i, row in NNF2_full_df_dups.iterrows():
    if counter != 0:
        if row.equals(last_row):
            print('equal_rows')
            print(i)
            drop_indexes.append(i)
        else:
            compared = NNF2_full_df_dups.loc[i].compare(NNF2_full_df_dups.loc[last_index])
            
            display(row)
            display(last_row)
        
            #highlight(NNF2_full_df_dups)
            last_row = row

            last_index = i
            last_row = row     
    
    
    counter += 1
    if counter > 3:
        break
# Out:
#                                                       self  \
# derived  [{'word': 'de dato'}, {'word': 'de facto'}, {'...
# forms          [{'form': '[D] de', 'tags': ['canonical']}]
#
#                                                other
# derived                                          NaN
# forms    [{'form': '[C] de', 'tags': ['canonical']}]
# word                                                              de
# pos                                                             prep
# lang_code                                                         nl
# lang                                                      Nederlands
# standard_lang                                                  dutch
# senses             [{'glosses': ['van'], 'raw_tags': ['alleen in ...
# antonyms                                                         NaN
# categories         [Ontbrekend geluid, Retrograad van het Nederla...
# derived            [{'word': 'de dato'}, {'word': 'de facto'}, {'...
# etymology_texts                                                  NaN
# hyphenations                                                     NaN
# hyponyms                                                         NaN
# related                                                          NaN
# sounds                                             [[{'ipa': 'də'}]]
# translations                                                      []
# tags                                                             NaN
# notes                                                            NaN
# synonyms                                                         NaN
# forms                    [{'form': '[D] de', 'tags': ['canonical']}]
# hypernyms                                                        NaN
# homophones                                                       NaN
# holonyms                                                         NaN
# descendants                                                      NaN
# word_code                                                    de_prep
# dups                                                            True
# Name: 14, dtype: object
# word                                                              de
# pos                                                             prep
# lang_code                                                         nl
# lang                                                      Nederlands
# standard_lang                                                  dutch
# senses             [{'glosses': ['van'], 'raw_tags': ['alleen in ...
# antonyms                                                         NaN
# categories         [Ontbrekend geluid, Retrograad van het Nederla...
# derived                                                          NaN
# etymology_texts                                                  NaN
# hyphenations                                                     NaN
# hyponyms                                                         NaN
# related                                                          NaN
# sounds                                             [[{'ipa': 'də'}]]
# translations                                                      []
# tags                                                             NaN
# notes                                                            NaN
# synonyms                                                         NaN
# forms                    [{'form': '[C] de', 'tags': ['canonical']}]
# hypernyms                                                        NaN
# homophones                                                       NaN
# holonyms                                                         NaN
# descendants                                                      NaN
# word_code                                                    de_prep
# dups                                                            True
# Name: 13, dtype: object
#                                                               self  \
# word                                                           het
# pos                                                           pron
# senses           [{'glosses': ['3e persoon enkelvoud onzijdig']...
# categories       [Erfwoord_in_het_Nederlands, Onbepaald voornaa...
# derived          [{'word': 'hetgeen'}, {'word': 'hetwelk'}, {'w...
# etymology_texts  [erfwoord als persoonlijk voornaamwoord aanget...
# hyphenations                                  [{'parts': ['het']}]
# sounds           [[{'ipa': 'hɛt'}], [{'ipa': '/ɦɛt/', 'raw_tags...
# translations     [{'word': 'it', 'lang_code': 'en', 'lang': 'en...
# tags                                                  [indefinite]
# forms                                                          NaN
# word_code                                                 het_pron
#
#                                                              other
# word                                                            de
# pos                                                           prep
# senses           [{'glosses': ['van'], 'raw_tags': ['alleen in ...
# categories       [Ontbrekend geluid, Retrograad van het Nederla...
# derived          [{'word': 'de dato'}, {'word': 'de facto'}, {'...
# etymology_texts                                                NaN
# hyphenations                                                   NaN
# sounds                                           [[{'ipa': 'də'}]]
# translations                                                    []
# tags                                                           NaN
# forms                  [{'form': '[D] de', 'tags': ['canonical']}]
# word_code                                                  de_prep
# word                                                             het
# pos                                                             pron
# lang_code                                                         nl
# lang                                                      Nederlands
# standard_lang                                                  dutch
# senses             [{'glosses': ['3e persoon enkelvoud onzijdig']...
# antonyms                                                         NaN
# categories         [Erfwoord_in_het_Nederlands, Onbepaald voornaa...
# derived            [{'word': 'hetgeen'}, {'word': 'hetwelk'}, {'w...
# etymology_texts    [erfwoord als persoonlijk voornaamwoord aanget...
# hyphenations                                    [{'parts': ['het']}]
# hyponyms                                                         NaN
# related                                                          NaN
# sounds             [[{'ipa': 'hɛt'}], [{'ipa': '/ɦɛt/', 'raw_tags...
# translations       [{'word': 'it', 'lang_code': 'en', 'lang': 'en...
# tags                                                    [indefinite]
# notes                                                            NaN
# synonyms                                                         NaN
# forms                                                            NaN
# hypernyms                                                        NaN
# homophones                                                       NaN
# holonyms                                                         NaN
# descendants                                                      NaN
# word_code                                                   het_pron
# dups                                                            True
# Name: 16, dtype: object
# word                                                              de
# pos                                                             prep
# lang_code                                                         nl
# lang                                                      Nederlands
# standard_lang                                                  dutch
# senses             [{'glosses': ['van'], 'raw_tags': ['alleen in ...
# antonyms                                                         NaN
# categories         [Ontbrekend geluid, Retrograad van het Nederla...
# derived            [{'word': 'de dato'}, {'word': 'de facto'}, {'...
# etymology_texts                                                  NaN
# hyphenations                                                     NaN
# hyponyms                                                         NaN
# related                                                          NaN
# sounds                                             [[{'ipa': 'də'}]]
# translations                                                      []
# tags                                                             NaN
# notes                                                            NaN
# synonyms                                                         NaN
# forms                    [{'form': '[D] de', 'tags': ['canonical']}]
# hypernyms                                                        NaN
# homophones                                                       NaN
# holonyms                                                         NaN
# descendants                                                      NaN
# word_code                                                    de_prep
# dups                                                            True
# Name: 14, dtype: object
#                                                               self  \
# word                                                           IPA
# pos                                                           noun
# senses           [{'glosses': [''extra hoppig' lichtbier of pil...
# categories       [Initiaalwoord_in_het_Nederlands, Ontbrekend g...
# derived                                                        NaN
# etymology_texts  [zn o: (initiaalwoord) van Engels IPA en [2], ...
# hyphenations                                  [{'parts': ['IPA']}]
# sounds                 [[{'ipa': 'ipeˈʔa'}], [{'ipa': 'ɑjpiˈʔe'}]]
# translations                                                    []
# tags                                                   [masculine]
# forms                      [{'form': 'IPA's', 'tags': ['plural']}]
# word_code                                                 IPA_noun
#
#                                                              other
# word                                                           het
# pos                                                           pron
# senses           [{'glosses': ['3e persoon enkelvoud onzijdig']...
# categories       [Erfwoord_in_het_Nederlands, Onbepaald voornaa...
# derived          [{'word': 'hetgeen'}, {'word': 'hetwelk'}, {'w...
# etymology_texts  [erfwoord als persoonlijk voornaamwoord aanget...
# hyphenations                                  [{'parts': ['het']}]
# sounds           [[{'ipa': 'hɛt'}], [{'ipa': '/ɦɛt/', 'raw_tags...
# translations     [{'word': 'it', 'lang_code': 'en', 'lang': 'en...
# tags                                                  [indefinite]
# forms                                                          NaN
# word_code                                                 het_pron
# word                                                             IPA
# pos                                                             noun
# lang_code                                                         nl
# lang                                                      Nederlands
# standard_lang                                                  dutch
# senses             [{'glosses': [''extra hoppig' lichtbier of pil...
# antonyms                                                         NaN
# categories         [Initiaalwoord_in_het_Nederlands, Ontbrekend g...
# derived                                                          NaN
# etymology_texts    [zn o: (initiaalwoord) van Engels IPA en [2], ...
# hyphenations                                    [{'parts': ['IPA']}]
# hyponyms                                                         NaN
# related                                                          NaN
# sounds                   [[{'ipa': 'ipeˈʔa'}], [{'ipa': 'ɑjpiˈʔe'}]]
# translations                                                      []
# tags                                                     [masculine]
# notes                                                            NaN
# synonyms                                                         NaN
# forms                        [{'form': 'IPA's', 'tags': ['plural']}]
# hypernyms                                                        NaN
# homophones                                                       NaN
# holonyms                                                         NaN
# descendants                                                      NaN
# word_code                                                   IPA_noun
# dups                                                            True
# Name: 38, dtype: object
# word                                                             het
# pos                                                             pron
# lang_code                                                         nl
# lang                                                      Nederlands
# standard_lang                                                  dutch
# senses             [{'glosses': ['3e persoon enkelvoud onzijdig']...
# antonyms                                                         NaN
# categories         [Erfwoord_in_het_Nederlands, Onbepaald voornaa...
# derived            [{'word': 'hetgeen'}, {'word': 'hetwelk'}, {'w...
# etymology_texts    [erfwoord als persoonlijk voornaamwoord aanget...
# hyphenations                                    [{'parts': ['het']}]
# hyponyms                                                         NaN
# related                                                          NaN
# sounds             [[{'ipa': 'hɛt'}], [{'ipa': '/ɦɛt/', 'raw_tags...
# translations       [{'word': 'it', 'lang_code': 'en', 'lang': 'en...
# tags                                                    [indefinite]
# notes                                                            NaN
# synonyms                                                         NaN
# forms                                                            NaN
# hypernyms                                                        NaN
# homophones                                                       NaN
# holonyms                                                         NaN
# descendants                                                      NaN
# word_code                                                   het_pron
# dups                                                            True
# Name: 16, dtype: object

# %%
for group in groups.describe():
    display(group)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 for group in groups.describe():
#       2     display(group)
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\groupby\groupby.py:3603, in GroupBy.describe(self, percentiles, include, exclude)
#    3600     return result.to_frame().T.iloc[:0]
#    3602 with com.temp_setattr(self, "as_index", True):
# -> 3603     result = self._python_apply_general(
#    3604         lambda x: x.describe(
#    3605             percentiles=percentiles, include=include, exclude=exclude
#    3606         ),
#    3607         obj,
#    3608         not_indexed_same=True,
#    3609     )
#    3610 if self.axis == 1:
#    3611     return result.T
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\groupby\groupby.py:1887, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1852 @final
#    1853 def _python_apply_general(
#    1854     self,
#    (...)   1859     is_agg: bool = False,
#    1860 ) -> NDFrameT:
#    1861     """
#    1862     Apply function f in python space
#    1863
#    (...)   1885         data after applying f
#    1886     """
# -> 1887     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1888     if not_indexed_same is None:
#    1889         not_indexed_same = mutated
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\groupby\ops.py:928, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     926 # group might be modified
#     927 group_axes = group.axes
# --> 928 res = f(group)
#     929 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     930     mutated = True
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\groupby\groupby.py:3604, in GroupBy.describe.<locals>.<lambda>(x)
#    3600     return result.to_frame().T.iloc[:0]
#    3602 with com.temp_setattr(self, "as_index", True):
#    3603     result = self._python_apply_general(
# -> 3604         lambda x: x.describe(
#    3605             percentiles=percentiles, include=include, exclude=exclude
#    3606         ),
#    3607         obj,
#    3608         not_indexed_same=True,
#    3609     )
#    3610 if self.axis == 1:
#    3611     return result.T
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\generic.py:12041, in NDFrame.describe(self, percentiles, include, exclude)
#   11799 @final
#   11800 def describe(
#   11801     self,
#    (...)  11804     exclude=None,
#   11805 ) -> Self:
#   11806     """
#   11807     Generate descriptive statistics.
#   11808
#    (...)  12039     max            NaN      3.0
#   12040     """
# > 12041     return describe_ndframe(
#   12042         obj=self,
#   12043         include=include,
#   12044         exclude=exclude,
#   12045         percentiles=percentiles,
#   12046     ).__finalize__(self, method="describe")
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\methods\describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
#      90 else:
#      91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
# ---> 97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\methods\describe.py:172, in DataFrameDescriber.describe(self, percentiles)
#     170 for _, series in data.items():
#     171     describe_func = select_describe_func(series)
# --> 172     ldesc.append(describe_func(series, percentiles))
#     174 col_names = reorder_columns(ldesc)
#     175 d = concat(
#     176     [x.reindex(col_names, copy=False) for x in ldesc],
#     177     axis=1,
#     178     sort=False,
#     179 )
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\methods\describe.py:272, in describe_categorical_1d(data, percentiles_ignored)
#     262 """Describe series containing categorical data.
#     263
#     264 Parameters
#    (...)    269     Ignored, but in place to unify interface.
#     270 """
#     271 names = ["count", "unique", "top", "freq"]
# --> 272 objcounts = data.value_counts()
#     273 count_unique = len(objcounts[objcounts != 0])
#     274 if count_unique > 0:
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\base.py:1014, in IndexOpsMixin.value_counts(self, normalize, sort, ascending, bins, dropna)
#     927 @final
#     928 def value_counts(
#     929     self,
#    (...)    934     dropna: bool = True,
#     935 ) -> Series:
#     936     """
#     937     Return a Series containing counts of unique values.
#     938
#    (...)   1012     Name: count, dtype: int64
#    1013     """
# -> 1014     return algorithms.value_counts_internal(
#    1015         self,
#    1016         sort=sort,
#    1017         ascending=ascending,
#    1018         normalize=normalize,
#    1019         bins=bins,
#    1020         dropna=dropna,
#    1021     )
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\algorithms.py:927, in value_counts_internal(values, sort, ascending, normalize, bins, dropna)
#     925 else:
#     926     values = _ensure_arraylike(values, func_name="value_counts")
# --> 927     keys, counts, _ = value_counts_arraylike(values, dropna)
#     928     if keys.dtype == np.float16:
#     929         keys = keys.astype(np.float32)
#
# File c:\Users\elise\SynologyDrive\Dev\DutchAnalyzerPublic\DutchAnalyzer\venv\Lib\site-packages\pandas\core\algorithms.py:981, in value_counts_arraylike(values, dropna, mask)
#     978 original = values
#     979 values = _ensure_data(values)
# --> 981 keys, counts, na_counter = htable.value_count(values, dropna, mask=mask)
#     983 if needs_i8_conversion(original.dtype):
#     984     # datetime, timedelta, or period
#     986     if dropna:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Internal Translations

# %% [markdown]
# ### From ENF

# %% [markdown]
# ### From NEF
