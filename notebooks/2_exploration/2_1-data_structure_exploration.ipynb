# %%
import json
from pathlib import Path
from dutchanalyzer.config import *
from dutchanalyzer.utils import *
from dutchanalyzer.json_utils import *
import re
from pprint import pprint
import ast
from collections import Counter
from tqdm import tqdm
import pickle

# %%
eng_save_path = Path(WIKT_PREPROCESSING_DIR, 'en')
nld_save_path = Path(WIKT_PREPROCESSING_DIR, 'nl')

# %%
today = datetime.date.today().__format__("%d-%m-%y")
current_save_folder = Path(INTERIM_DATA_DIR, 'cleaning', 'wikt', str(today))
folders = {'en': ['EER', 'ENR','EEF', 'ENF'], 'nl':['NER', 'NNR', 'NEF', 'NNF']}
Path.mkdir(current_save_folder, exist_ok=True)
for k, fold in folders.items():
    Path.mkdir(Path(current_save_folder, k), exist_ok=True)
    for f in fold:
        Path.mkdir(Path(current_save_folder, k, f), exist_ok=True)

# %%
# Paths
NNR_file = Path(NNR_DIR, 'NNR.jsonl')
NER_file = Path(NER_DIR, 'NER.jsonl')
EER_file = Path(EER_DIR, 'EER.jsonl')
ENR_file = Path(ENR_DIR, 'ENR.jsonl')

# %%
NNF_folder = Path(WIKT_CLEANING_DIR, 'nl', 'NNF')
NEF_folder = Path(WIKT_CLEANING_DIR, 'nl', 'NEF')
EEF_folder = Path(WIKT_CLEANING_DIR, 'en', 'EEF')
ENF_folder = Path(WIKT_CLEANING_DIR, 'en', 'ENF')

all_words_file = Path(WIKT_CLEANING_DIR, 'all_words.jsonl')
eef_words_file = Path(EEF_folder, 'eef_words.jsonl')
enf_words_file = Path(ENF_folder, 'enf_words.jsonl')

# %% [markdown]
# ### Explination of Structure via Tatuylonen/wiktextract:

# %% [markdown]
# ## Get Subkeys

# %% [markdown]
# ### Utilities

# %%
def make_structure_line_tuple(key, line):
    size = 0
    if line:
        size = len(line)
        obj_type = type(line)
        if size == 0:
            return (key, obj_type, 0, 0)
        counts = Counter()
        typecounts = Counter(type(x).__name__ for x in line)
        if isinstance(line, dict):
            items = line.items()
            return (key, dict, size, typecounts) 
        elif isinstance(line, list):
            return (key, list, size, typecounts)
        elif isinstance(line, str):
            try:
                line = json.loads(line)
                if isinstance(line, str):
                    return (key, str, size, typecounts)
            except:
                
                return (key, str, size, typecounts)
    return None

# %%
def print_subkeys(structure, depth=0):
    indent = '  ' * depth
    if isinstance(structure, dict):
        for key, value in structure.items():
            print(f"{indent}{key}:")
            print_subkeys(value, depth + 1)
    elif isinstance(structure, list):
        for i, item in enumerate(structure):
            print(f"{indent}- Item {i}:")
            print_subkeys(item, depth + 1)
    else:
        print(f"{indent}{structure}")

# %%
def get_subkeys(obj):
    structure_dict = {}
    obj_type = type(obj)
    if not obj:
        return None
    elif isinstance(obj, (str, int)):
        return obj_type
    elif isinstance(obj, dict):
        for k, v in obj.items():
            structure_dict[k] = get_subkeys(v)
    elif isinstance(obj, list):
        if len(obj) == 0:
            return None
       

        subkeys_list = []
        substruct_count = []
        for i, v in enumerate(obj):
            substruct = get_subkeys(v)
            if substruct not in subkeys_list:
                subkeys_list.append(substruct)
                
            
        return subkeys_list
         # our list has at least 1 item
        # list_type = type(obj[0])
        # if list_type != dict:
        #     return list_type
        
        # now obj is a list of dicts
        # for each dict, get the keys in our dict
    #     for d in obj:
    #         # for each dictionary in our list
    #         for k, v in d.items():
    #             structure_dict[k] = get_subkeys(v)
    # return structure_dict
    else:
        print(obj)


    return structure_dict

# %%
def get_subkeysV2(line):
    structure_dict = {}
    line_type = type(line)
    if not line:
        return line_type
    elif isinstance(line, str):
        return str
    elif isinstance(line, int):
        return int
    elif isinstance(line, dict):
        for k, v in line.items():
            structure_dict[k] = get_subkeysV2(v)
    elif isinstance(line, list):
        subkeys_list = []
        substruct_count = []
        line_tuple_list = []
        keys_set = set()
        for i, v in enumerate(line):
            substruct = get_subkeysV2(v)
            if isinstance(substruct, dict):
                for k in substruct.keys():
                    keys_set.update(k)
            if substruct not in subkeys_list:
                subkeys_list.append(substruct)
                
                substruct_count.append(1)
            else:
                index = subkeys_list.index(substruct)
                substruct_count[index] += 1
        return (keys_set, subkeys_list)
    else:
        print(line)
    return structure_dict

# %% [markdown]
# ## Get Substructures NER

# %%
def get_level_structure(obj, level=0):
     obj_type = type(obj)
     if not isinstance(obj, (list, dict)):
        return obj_type
     else:
         if isinstance(obj, list):
            level_keys = set()
            key_value_types = []
            substructures = []
            for i, item in enumerate(obj):
               if item:
                  if isinstance(item, dict):
                     for k, v in item.items():
                           level_keys.add(k)
                           if (k, type(v)) not in key_value_types:
                              key_value_types.append((k, type(v)))
                            
                           
                  else:
                     key_value_types.append(i, type(item))
            return key_value_types, level_keys

# %%
level_0_keys = {
'senses': [list][dict],
 'pos': [str],
 'head_templates': [list][dict],
 'forms': [list][dict],
 'derived': [list][dict],
 'descendants': [list][dict],
 'sounds': [list][dict],
 'hyphenations': [list][dict],
 'etymology_text': [str],
 'etymology_templates': [list][dict],
 'word': [str],
 'lang': [str],
 'lang_code': [str],
 'inflection_templates': [list][dict],
 'categories': [list][str],
 'related': [list][dict],
 'etymology_number': [int],
 'synonyms': [list][dict],
 'antonyms': [list][dict],
 'wikipedia': [list][str],
 'hypernyms': [list][dict],
 'hyponyms': [list][dict],
 'holonyms': [list][dict],
 'coordinate_terms': [list][dict],
 'meronyms': [list][dict],
 'abbreviations': [list][dict],
 'original_title': [str]}

level_0_list_types = [('senses', Counter({'dict': 1})),
 ('head_templates', Counter({'dict': 1})),
 ('forms', Counter({'dict': 4})),
 ('derived', Counter({'dict': 2})),
 ('descendants', Counter({'dict': 3})),
 ('sounds', Counter({'dict': 3})),
 ('hyphenations', Counter({'dict': 1})),
 ('etymology_templates', Counter({'dict': 8})),
 ('inflection_templates', Counter({'dict': 1})),
 ('categories', Counter({'str': 2})),
 ('related', Counter({'dict': 53})),
 ('synonyms', Counter({'dict': 2})),
 ('antonyms', Counter({'dict': 1})),
 ('wikipedia', Counter({'str': 1})),
 ('hypernyms', Counter({'dict': 1})),
 ('hyponyms', Counter({'dict': 1})),
 ('holonyms', Counter({'dict': 1})),
 ('coordinate_terms', Counter({'dict': 1})),
 ('meronyms', Counter({'dict': 5})),
 ('abbreviations', Counter({'dict': 2}))]

# %%
level_0_list_keys = []
for k, v in level_0_keys.items():
    if v == list:
        level_0_list_keys.append(k)

# %%
senses = {'links': [str],
 'synonyms': [
    {'word': str,
    'tags': list,
    'extra': str,
    'source': str,
    'alt': str,
    'english': str,
    'translation': str,
    'topics': list}],
 'glosses': [str],
 'tags': [str],
 'categories': [str],
 'wikipedia': [str],
 'form_of': [
            {'word': str, 
             'extra': str}],
 'raw_glosses': [str],
 'raw_tags': [str],
 'examples': [{'text': str,
   'bold_text_offsets': list,
   'translation': str,
   'english': str,
   'bold_translation_offsets': list,
   'type': str,
   'tags': list,
   'ref': str,
   'literal_meaning': str,
   'bold_literal_offsets': list,
   'roman': str,
   'raw_tags': list}],
 'alt_of': [{'word': str, 
             'extra': str}],
 'topics': [str],
 'attestations': [{'date': str, 'references': list}],
 'antonyms': [{'word': str}],
 'wikidata': [str],
 'senseid': [str],
 'hypernyms': [{'word': str}],
 'coordinate_terms': [{'word': str, 'english': str, 'translation': str}],
 'meronyms': [{'word': str}],
 'info_templates': [{'args': dict,
   'name': str,
   'extra_data': dict,
   'expansion': str}],
 'holonyms': [{'word': str}],
 'related': [{'word': str, 'tags': list}],
 'hyponyms': [{'word': str}]}

# %%
senses = {'links': list, #str or list of lists with str
 'synonyms': list, #[{'word': str}]
 'glosses': list, #str
 'tags': list,
 'categories': list, # str
 'wikipedia': list, #str
 'form_of': list,
 'raw_glosses': list,
 'raw_tags': list,
 'examples': list,
 'qualifier': str,
 'alt_of': list,
 'topics': list,
 'attestations': list,
 'antonyms': list,
 'wikidata': list,
 'senseid': list,
 'hypernyms': list,
 'coordinate_terms': list,
 'meronyms': list,
 'info_templates': list,
 'head_nr': int,
 'holonyms': list,
 'related': list,
 'hyponyms': list}
forms = {'form': str, 'tags': list[str], 'source': str, 'raw_tags': list[str], 'head_nr': int}
derived = {'word': str,
 'lang': str,
 'lang_code': str,
 'tags': list,
 'ipa': str,
 'audio': str,
 'ogg_url': str,
 'mp3_url': str,
 'parts': list,
 'name': str,
 'args': dict,
 'expansion': str,
 'raw_tags': list,
 'roman': str,
 'rhymes': str,
 'homophone': str,
 'sense': str,
 'descendants': list,
 'english': str,
 'translation': str,
 'note': str,
 'text': str,
 'other': str,
 'topics': list,
 'alt': str,
 'taxonomic': str,
 'ruby': list}
descendants = {'word': str,
 'lang': str,
 'lang_code': str,
 'tags': list,
 'ipa': str,
 'audio': str,
 'ogg_url': str,
 'mp3_url': str,
 'parts': list,
 'name': str,
 'args': dict,
 'expansion': str,
 'raw_tags': list,
 'roman': str,
 'rhymes': str,
 'homophone': str,
 'sense': str,
 'descendants': list,
 'english': str,
 'translation': str,
 'note': str,
 'text': str,
 'other': str,
 'topics': list,
 'alt': str,
 'taxonomic': str,
 'ruby': list}
sounds = {'ipa': str,
 'audio': str,
 'ogg_url': str,
 'mp3_url': str,
 'rhymes': str,
 'homophone': str,
 'tags': list,
 'note': str,
 'text': str,
 'other': str}
hyphenations = {'parts': list}
etymology_templates = {'name': str, 'args': dict, 'expansion': str}
inflection_templates = {'name': str, 'args': dict}

related = {'tags': list,
 'word': str,
 'sense': str,
 'english': str,
 'translation': str,
 'roman': str,
 'topics': list,
 'alt': str,
 'raw_tags': list}
coordinate_terms= {'word': str,
 'tags': list,
 'sense': str,
 'topics': list,
 'english': str,
 'translation': str,
 'alt': str}
abbreviations= {'word': str}
synonyms= {'word': str,
 'sense': str,
 'tags': list,
 'raw_tags': list,
 'topics': list,
 'source': str,
 'alt': str,
 'english': str,
 'translation': str,
 'taxonomic': str,
 'roman': str}
antonyms= {'word': str,
 'sense': str,
 'english': str,
 'translation': str,
 'tags': list,
 'topics': list,
 'alt': str}

hypernyms= {'word': str,
 'sense': str,
 'topics': list,
 'alt': str,
 'tags': list,
 'english': str,
 'translation': str}
hyponyms= {'word': str,
 'sense': str,
 'english': str,
 'translation': str,
 'topics': list,
 'taxonomic': str,
 'alt': str}
holonyms= {'word': str, 'tags': list}

meronyms= {'word': str, 'alt': str}

# %%
file = ENR_file
sense_synonyms= {}
sense_antonyms= {}
sense_hypernyms= {}
sense_hyponyms= {}
sense_holonyms= {}
sense_meronyms= {}
sense_glosses = {}
senses_tags = {}
keys = []
key_types = []
with open(file, 'r', encoding='utf-8') as f:
    with open(all_words_file, 'a+', encoding='utf-8') as out:
        for i, obj in tqdm(enumerate(f)):
            loaded = json.loads(obj)
            if loaded:
                
                try:
                    if 'senses' in loaded:
                        senses_loaded = loaded['senses']
                        if 'glosses' in senses_loaded:
                            temp_dict = {}
                            for j, item in enumerate(sense_glosses['glosses']):
                                for k, v in item.items():
                                    if k not in temp_dict.keys():
                                        temp_dict[k] = type(v)
                            
                            sense_glosses.update(temp_dict) 
                        
                        if 'antonyms' in senses_loaded:
                            temp_dict1 = {}
                            for j, item in enumerate(loaded['antonyms']):
                                for k, v in item.items():
                                    if k not in temp_dict1.keys():
                                        temp_dict1[k] = type(v)
                            
                            antonyms.update(temp_dict1) 
                            
                        if 'hypernyms' in senses_loaded:
                            temp_dict2 = {}
                            for j, item in enumerate(loaded['hypernyms']):
                                for k, v in item.items():
                                    if k not in temp_dict2.keys():
                                        temp_dict2[k] = type(v)
                            hypernyms.update(temp_dict2) 
                        
                        if 'hyponyms' in senses_loaded:
                            temp_dict3 = {}
                            for j, item in enumerate(loaded['hyponyms']):
                                for k, v in item.items():
                                    if k not in temp_dict3.keys():
                                        temp_dict3[k] = type(v)
                        
                            senses_hyponyms.update(temp_dict3)
                            
                        if 'holonyms' in senses_loaded:
                            temp_dict4 = {}
                            for j, item in enumerate(senses_loaded['holonyms']):
                                for k, v in item.items():
                                    if k not in temp_dict4.keys():
                                        temp_dict4[k] = type(v)
                    
                            senses_holonyms.update(temp_dict4)
                    
                        if 'meronyms' in senses_loaded:
                            temp_dict5 = {}
                            for j, item in enumerate(senses_loaded['meronyms']):
                                for k, v in item.items():
                                    if k not in temp_dict5.keys():
                                        temp_dict5[k] = type(v)
                
                            senses_meronyms.update(temp_dict5)
                        
                        if 'related' in loaded:
                            temp_dict6 = {}
                            for j, item in enumerate(loaded['related']):
                                for k, v in item.items():
                                    if k not in temp_dict6.keys():
                                        temp_dict6[k] = type(v)
    
                            related.update(temp_dict6)
                     
                    # if 'coordinate_terms' in loaded:
                    #     temp_dict7 = {}
                    #     for j, item in enumerate(loaded['coordinate_terms']):
                    #         for k, v in item.items():
                    #             if k not in temp_dict7.keys():
                    #                 temp_dict7[k] = type(v)
                  
                    #     coordinate_terms.update(temp_dict7)  
                    
                    # if 'abbreviations' in loaded:
                    #     temp_dict8 = {}
                    #     for j, item in enumerate(loaded['abbreviations']):
                    #         for k, v in item.items():
                    #             if k not in temp_dict8.keys():
                    #                 temp_dict8[k] = type(v)
                  
                    #     abbreviations.update(temp_dict8) 
                        
               
                except:
                    print(i)
                    break
                

                     
                        # else:
                        #     if type(value) not in level_0_keys[key]:
                        #         level_0_keys[key].append(type(value))
# Out:
# 140922it [00:02, 59561.30it/s]

# %%
from pandas import value_counts


file = ENR_file
sub_senses = {}
sense_synonyms= {}
sense_antonyms= {}
sense_hypernyms= {}
sense_hyponyms= {}
sense_holonyms= {}
sense_meronyms= {}
sense_glosses = {}
senses_tags = {}
all_subkeys_senses_to_make_dicts = []
subkey_dicts_lists = []
keys = []
key_types = []
subkey = 'senses'
with open(file, 'r', encoding='utf-8') as f:
    with open(all_words_file, 'a+', encoding='utf-8') as out:
        for i, obj in tqdm(enumerate(f)):
            loaded = json.loads(obj)
            if loaded:
                if 'senses' in loaded:
                    sense_items_dicts = []
                    
                    for sense in loaded['senses']:
                        if isinstance(sense, dict):
                            for key, value in sense.items():
                                try:
                                    if isinstance(value, list):
                                        temp_keys = []
                                        counter = Counter()
                                        typecounts = Counter(type(x).__name__ for x in value)
                                        sub_key_l = []
                                        if len(typecounts) == 1:
                                            if typecounts.get('dict'):
                                                if not sub_senses.get(key):
                                                    sub_senses[key] = [{}]
                                                for val in value:
                                                    for k, v in val.items():
                                                        if k not in sub_senses[key][0].keys():
                                                            sub_senses[key][0][k] = type(v)
                                                        else: 
                                                            if not isinstance(sub_senses[key][0][k], list):
                                                                if type(v) != sub_senses[key][0][k]:
                                                                    old_val = sub_senses[key][0][k]
                                                                    sub_senses[key][0][k] = ["forced list", old_val, type(v)]
                                                            else:
                                                                if type(v) not in sub_senses[key][0][k]:
                                                                    sub_senses[key][0][k].append(type(v))
                                            elif typecounts.get('list'):
                                                if not sub_senses.get(key):
                                                    sub_senses[key] = []
                                                for val in value:
                                                    for v in val:
                                                        if (type(v)) not in sub_senses[key]:
                                                            sub_senses[key].append((type(v)))
                                            else:
                                                sub_senses[key] = [type(value[0])]
                                        else:
                                            if len(typecounts) > 1:
                                                print(typecounts)
                                except Exception as e:
                                    print("error on ", i, ', ', e)
                                    
                                        # else:
                                        #     if typecounts.get('dict'):
                                        #         if not sub_senses.get(key):
                                        #             sub_senses[key] = [{}]
                                        #         for val in value:
                                        #             for k, v in val.items():
                                        #                 if k not in sub_senses[key][0].keys():
                                        #                     sub_senses[key][0][k] = type(v)
                                        #     elif typecounts.get('list'):
                                        #         if not sub_senses.get(key):
                                        #             sub_senses[key] = []
                                        #         for val in value:
                                        #             for v in val:
                                        #                 if (type(v)) not in sub_senses[key]:
                                        #                     sub_senses[key].append((type(v)))
                                        #     else:
                                        #         sub_senses[key] = [type(value[0])]
                                    
                                                        
                                            
                                            
                                            

                                    # if type_keys[0] == 'dict':
                                    #     
                                            
                                    
                                            
                                    # sub_senses[key] = [type_keys]
                                    
                                            
                                    

                                        
                                            


                                # if isinstance(value, dict):
                                #     sub_senses[key] = value.keys()
                                #     for sense_item in sense: # links and other keys
                                #         if isinstance(sense_item, list):
                                #             key_types.append((key, type(sense_item), sense_item, sense))
                                #             #print(key, ' list, ', sense_item)
                                #             pass
                                #             # for si in sense_item:
                                #             #     pass
                                            
                                #         else:
                                #             key_types.append((key, type(sense_item), sense_item, sense))
                                            
                                      
                        
                            
                                #    for si in sense_item:
                                #        if isinstance(sense_item, list):

                        
                             
                # if subkey in loaded:
                #     subkey_items = loaded[subkey]
                #     subkeys_dict = {}
                #     if isinstance(subkey_items, list):
                #         for j, item in subkey_items:
                #             if isinstance(item, list):

                #     for key, value in subkey_items:
                #         if isinstance(subkey_items, (int, str)):
                #             subkeys_dict[subkey] = type(subkey_items)
                #             print(subkeys_dict)
                #             break
                #         elif isinstance(subkey_items, dict):
                #             for k, v in subkey_items.items():
                #                 if isinstance(v, list):
display(sub_senses)
# Out:
# 140922it [00:04, 30118.21it/s]
# {'links': [str],
#  'synonyms': [{'word': str,
#    'tags': list,
#    'extra': str,
#    'source': str,
#    'alt': str,
#    'english': str,
#    'translation': str,
#    'topics': list}],
#  'glosses': [str],
#  'tags': [str],
#  'categories': [str],
#  'wikipedia': [str],
#  'form_of': [{'word': str, 'extra': str}],
#  'raw_glosses': [str],
#  'raw_tags': [str],
#  'examples': [{'text': str,
#    'bold_text_offsets': list,
#    'translation': str,
#    'english': str,
#    'bold_translation_offsets': list,
#    'type': str,
#    'tags': list,
#    'ref': str,
#    'literal_meaning': str,
#    'bold_literal_offsets': list,
#    'roman': str,
#    'raw_tags': list}],
#  'alt_of': [{'word': str, 'extra': str}],
#  'topics': [str],
#  'attestations': [{'date': str, 'references': list}],
#  'antonyms': [{'word': str}],
#  'wikidata': [str],
#  'senseid': [str],
#  'hypernyms': [{'word': str}],
#  'coordinate_terms': [{'word': str, 'english': str, 'translation': str}],
#  'meronyms': [{'word': str}],
#  'info_templates': [{'args': dict,
#    'name': str,
#    'extra_data': dict,
#    'expansion': str}],
#  'holonyms': [{'word': str}],
#  'related': [{'word': str, 'tags': list}],
#  'hyponyms': [{'word': str}]}

# %%
forms = {'form': str, 'tags': list[str], 'source': str, 'raw_tags': list[str], 'head_nr': int}
sub_forms = {'tags': list[str], 'raw_tags': list[str]}
subkey = 'forms'
with open(file, 'r', encoding='utf-8') as f:
    with open(all_words_file, 'a+', encoding='utf-8') as out:
        for i, obj in tqdm(enumerate(f)):
            loaded = json.loads(obj)
            if loaded:
                if subkey in loaded:
                    for sub in loaded[subkey]:
                            if isinstance(sub, dict):
                                for key, value in sub.items():
                                    if key == 'tags' and type(value) != list:
                                        if type(value[0]) != 'str':
                                            print(i, key, value)
                                    if key == 'raw_tags' and type(value) != list:
                                        if type(value[0]) != 'str':
                                            print(i, key, value)
# Out:
# 140922it [00:02, 57842.00it/s]

# %%
derived = {'word': str,
 'lang': str,
 'lang_code': str,
 'tags': list[str],
 'ipa': str,
 'audio': str,
 'ogg_url': str,
 'mp3_url': str,
 'parts': list[str],
 'name': str,
 'args': dict,
 'expansion': str,
 'raw_tags': list[str],
 'roman': str,
 'rhymes': str,
 'homophone': str,
 'sense': str,
 'descendants': list[str],
 'english': str,
 'translation': str,
 'note': str,
 'text': str,
 'other': str,
 'topics':  list[str],
 'alt': str,
 'taxonomic': str,
 'ruby': list[str]}
descendants = {'word': str,
 'lang': str,
 'lang_code': str,
 'tags': list[str],
 'ipa': str,
 'audio': str,
 'ogg_url': str,
 'mp3_url': str,
 'parts': list[str],
 'name': str,
 'args': dict,
 'expansion': str,
 'raw_tags': list[str],
 'roman': str,
 'rhymes': str,
 'homophone': str,
 'sense': str,
 'descendants': list[str],
 'english': str,
 'translation': str,
 'note': str,
 'text': str,
 'other': str,
 'topics':  list[str],
 'alt': str,
 'taxonomic': str,
 'ruby': list[str]}

# %%
derived_list_dict = {}
for k, v in derived.items():
    if v == list or v == dict:
        derived_list_dict[k] = v
derived_list_dict
# Out:
# {'tags': list,
#  'parts': list,
#  'args': dict,
#  'raw_tags': list,
#  'descendants': list,
#  'topics': list,
#  'ruby': list}

# %%
desc_list_dict = {'tags': list[str],
 'parts': list[str],
 'args': dict,
 'raw_tags': list[str],
 'descendants': list[str],
 'topics': list[str],
 'ruby': list[str]}
sub_dict = {}
subkey = 'derived'
with open(file, 'r', encoding='utf-8') as f:
    with open(all_words_file, 'a+', encoding='utf-8') as out:
        for i, obj in tqdm(enumerate(f)):
            loaded = json.loads(obj)
            if loaded:
                if subkey in loaded:
                    for sub in loaded[subkey]:

                        if isinstance(sub, dict):
                            for key, value in sub.items():
                               

                                if key == 'tags' and type(value) != list:
                                    if type(value[0]) != 'str':
                                        print(i, key, value)
                                if key == 'raw_tags' and type(value) != list:
                                    if type(value[0]) != 'str':
                                        print(i, key, value)
                                    
                                if key == 'parts' and type(value) != list:
                                    if type(value[0]) != 'str':
                                        print(i, key, value)      
                                if key == 'descendants' and type(value) != list:
                                    if type(value[0]) != 'str':
                                        print(i, key, value)
                                    
                                if key == 'topics' and type(value) != list:
                                    if type(value[0]) != 'str':
                                        print(i, key, value)   
                                if key == 'ruby' and type(value) != list:
                                    if type(value[0]) != 'str':
                                        print(i, key, value) 
                                if key == 'ruby':
                                    print(i, key, value)
# Out:
# 140922it [00:02, 67940.30it/s]

# %%
display(holonyms)
meronyms
# Out:
# {'word': str, 'tags': list}
# {'word': str, 'alt': str}

# %%
# if 'senses' in loaded:
#     for j, item in enumerate(loaded['senses']):
#         item_type = type(item)
#         if isinstance(item, dict):
#             for k, v in item.items():
#                 temp_sense_dict[k] = type(v)
#     senses_structure.update(temp_sense_dict)                
# if 'forms' in loaded:
#     for j, item in enumerate(loaded['forms']):
#         for k, v in item.items():
#             temp_forms_dict[k] = type(v)
#     forms.update(temp_forms_dict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 level_0_keys.sort()
#
# AttributeError: 'dict' object has no attribute 'sort'

# %% [markdown]
# ### NL Structure

# %%
substructures = []

# %%
NNF_out = Path(current_save_folder, 'NNF')
NEF_out = Path(current_save_folder, 'NEF')

# %%
substructures2 = []

# %%
def safe_dict(obj_str: str):
    if isinstance(obj_str, str):
        try:
            return ast.literal_eval(obj_str)
        except Exception:
            return ""       # fallback

# %%
def filter_obj(obj):
    if 'anagrams' in obj:
        obj.pop('anagrams')
        
    if 'proverbs' in obj:
        obj.pop('proverbs')
    if 'pos_title' in obj:
        obj.pop('pos_title')
    if 'sounds' in obj:
        sounds = obj['sounds']
        remove_sounds = ['audio','ogg_url','mp3_url']
        new_sounds = []
        for i in sounds:
            ns = []
            for k in i.keys():
                if k not in remove_sounds:
                    ns.append(i)
            if ns:
                new_sounds.append(ns)
            
        obj['sounds'] = new_sounds
    if 'senses' in obj:
        for i in obj['senses']:
            pass

# %%
def make_def_obj(obj) -> dict:
    new_obj_keys = ['word', 'lang_code', 'pos', 'glosses']
    new_obj = {}
    glosses = []
    translations = []
    top_translations = []
    new_obj['word'] = obj['word']
    new_obj['lang_code'] = obj['lang_code']
    new_obj['pos'] = obj['pos']
    if 'senses' in obj:
        for sense in obj['senses']:
            if 'glosses' in sense:
                glosses.append(sense['glosses'])
            if 'translation' in sense:
                translations.append(sense['translation'])

    new_obj['glosses'] = glosses
    if 'translations' in obj:
        top_translations = [x for x in obj['translations'] if x.get("lang_code", '') == 'en' or x.get("lang_code", '') == 'nl']
        new_obj['translations'] = top_translations
    return new_obj

# %%
all_words = Path(current_save_folder, 'all_words.jsonl')

# %%
all_words_defs = []

# %%
nl_file = NNR_file
curr_NEF_file = Path(INTERIM_DATA_DIR, 'cleaning', 'wikt', '11-11-25', 'NEF', 'NEF.jsonl')
file_len = count_lines_with_progress(curr_NEF_file)
outfile = Path(current_save_folder, 'NEF', 'NEF_filtered.jsonl')
batch = []
with open(nl_file, 'r', encoding='utf-8') as f:
        with open(all_words_file, 'a+', encoding='utf-8') as out:
            lines = f.readlines()
            print(len(lines))
            for i, line in tqdm(enumerate(lines)):
            
                loaded = json.loads(line)
                
                if type(loaded) == str:
                    loaded = safe_dict(loaded)
        
                
                if loaded:
                    
                    filter_obj(loaded)
                   
                 
                    new_obj = make_def_obj(loaded)
                    if new_obj:
                        new_obj['wl_code'] = 'NEF'
                        all_words_defs.append(new_obj)
                        batch.append(new_obj)
                    

                        
                
                if len(batch) > 1000:
                    for obj in batch:
                        json.dump(obj, out)
                        out.write('\n')
                    batch = []
         
display(batch)
# Out:
# Counting Lines: 100%|██████████| 8.42M/8.42M [00:00<00:00, 1.26GB/s]
# 611444
# 611444it [00:18, 33005.61it/s]
# [{'word': 'kiezelhard',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['heel erg stevig, heel erg sterk']],
#   'wl_code': 'NEF'},
#  {'word': 'toneelschrijfkunst',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['schrijven van toneelstukken als een literaire kunstuiting']],
#   'wl_code': 'NEF'},
#  {'word': 'drinkvermogen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['de hoeveelheid alcoholische dranken die iemand kan drinken, wat problematisch kan worden bij overmatig of zwaar drinken']],
#   'wl_code': 'NEF'},
#  {'word': 'uitroepingsteken',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['!, een leesteken dat uitdrukt dat de zin een uitroep, bevel of uitdrukking van verbazing is.']],
#   'wl_code': 'NEF'},
#  {'word': 'punthaak',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['[<][>] elk van beide spiegelbeeldige puntvormige leestekens waarmee een bepaald deel van een tekst kan worden gemarkeerd']],
#   'wl_code': 'NEF'},
#  {'word': 'dadfluencer',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een vader die actief is op sociale media en daar zijn dagelijkse leven als vader deelt door middel van content']],
#   'wl_code': 'NEF'},
#  {'word': 'knotsgezellig',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['met een sterke sfeer van een levendige groep mensen die genoegen scheppen in elkaars aanwezigheid']],
#   'wl_code': 'NEF'},
#  {'word': 'nokkievol',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['zo vol dat er niets meer bij kan']],
#   'wl_code': 'NEF'},
#  {'word': 'puntelijk',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['heel precies; zich heel goed aan afspraken houdend']],
#   'wl_code': 'NEF'},
#  {'word': 'reuzeklein',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['enorm klein']],
#   'wl_code': 'NEF'},
#  {'word': 'eilandhoppen',
#   'lang_code': 'nl',
#   'pos': 'verb',
#   'glosses': [['van het ene naar het andere vakantie-eiland trekken']],
#   'wl_code': 'NEF'},
#  {'word': 'welgekend',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['heel bekend, heel beroemd']],
#   'wl_code': 'NEF'},
#  {'word': 'xyloloog',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['deskundige op het gebied van hout en houtsoorten']],
#   'wl_code': 'NEF'},
#  {'word': 'doelwachter',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een speler die bij sporten als voetbal, hockey of handbal de taak heeft om het doel te verdedigen.']],
#   'wl_code': 'NEF'},
#  {'word': 'almeteens',
#   'lang_code': 'nl',
#   'pos': 'adv',
#   'glosses': [['van het ene op het andere moment']],
#   'wl_code': 'NEF'},
#  {'word': 'autopiloot',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een systeem in een vliegtuig, schip of ruimtevaartuig dat het voertuig automatisch bestuurt'],
#    ['het automatisch, routinematig handelen van een persoon']],
#   'wl_code': 'NEF'},
#  {'word': 'benauwelijk',
#   'lang_code': 'nl',
#   'pos': 'adv',
#   'glosses': [['angstaanjagend, beangstigend']],
#   'wl_code': 'NEF'},
#  {'word': 'grammoedig',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['toornig of tot toorn geneigd, verstoord of daarvan blijk gevend; snel geprikkeld']],
#   'wl_code': 'NEF'},
#  {'word': 'schermpagina',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['schermafbeelding, screenshot']],
#   'wl_code': 'NEF'},
#  {'word': 'schermafbeelding',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [["een statische afbeelding ('foto') van wat er op een bepaald moment zichtbaar is op (een deel van) een beeldscherm"]],
#   'wl_code': 'NEF'},
#  {'word': 'schermafdruk',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een afdruk van wat er op een bepaald moment zichtbaar is op (een deel van) een beeldscherm']],
#   'wl_code': 'NEF'},
#  {'word': 'schermfoto',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [["een statische afbeelding ('foto') van wat er op een bepaald moment zichtbaar is op (een deel van) een beeldscherm"]],
#   'wl_code': 'NEF'},
#  {'word': 'schermopname',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een foto van wat er op een bepaald moment zichtbaar is op (een deel van) een beeldscherm']],
#   'wl_code': 'NEF'},
#  {'word': 'screendump',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een foto van wat er op een bepaald moment zichtbaar is op (een deel van) een beeldscherm']],
#   'wl_code': 'NEF'},
#  {'word': 'frontpage',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['webpagina die door de eigenaar bedoeld als toegangspoort van de website']],
#   'wl_code': 'NEF'},
#  {'word': 'lustrerie',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['winkel waar men lampen verkoopt']],
#   'wl_code': 'NEF'},
#  {'word': 'lampenzaak',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['winkel waar men lampen verkoopt']],
#   'wl_code': 'NEF'},
#  {'word': 'lampenwinkel',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['winkel waar men lampen verkoopt']],
#   'wl_code': 'NEF'},
#  {'word': 'groepschatjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord groepschat']],
#   'wl_code': 'NEF'},
#  {'word': 'groepschatje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord groepschat']],
#   'wl_code': 'NEF'},
#  {'word': 'groepschats',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord groepschat']],
#   'wl_code': 'NEF'},
#  {'word': 'nepharen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord nephaar']],
#   'wl_code': 'NEF'},
#  {'word': 'skibidi',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['echt ongewoon of opvallend'],
#    ['echt ongewoon of opvallend', 'positief bedoeld'],
#    ['echt ongewoon of opvallend', 'negatief bedoeld']],
#   'wl_code': 'NEF'},
#  {'word': 'schijtmisselijk',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['met een ziek gevoel in de darmen, neigend naar overgeven of buikloop'],
#    ['vervuld van diepe walging']],
#   'wl_code': 'NEF'},
#  {'word': 'schijtmisselijke',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van schijtmisselijk']],
#   'wl_code': 'NEF'},
#  {'word': 'teenharen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord teenhaar']],
#   'wl_code': 'NEF'},
#  {'word': 'fotosnijdertjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord fotosnijder']],
#   'wl_code': 'NEF'},
#  {'word': 'fotosnijdertje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord fotosnijder']],
#   'wl_code': 'NEF'},
#  {'word': 'fotosnijders',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord fotosnijder']],
#   'wl_code': 'NEF'},
#  {'word': 'memobordjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord memobord']],
#   'wl_code': 'NEF'},
#  {'word': 'memobordje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord memobord']],
#   'wl_code': 'NEF'},
#  {'word': 'memoborden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord memobord']],
#   'wl_code': 'NEF'},
#  {'word': 'eetbordjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord eetbord']],
#   'wl_code': 'NEF'},
#  {'word': 'eetbordje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord eetbord']],
#   'wl_code': 'NEF'},
#  {'word': 'eetborden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord eetbord']],
#   'wl_code': 'NEF'},
#  {'word': 'turnwedstrijdjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord turnwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'turnwedstrijdje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord turnwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'turnwedstrijden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord turnwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'graffitiwedstrijdjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord graffitiwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'graffitiwedstrijdje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord graffitiwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'graffitiwedstrijden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord graffitiwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'voordeurbellen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord voordeurbel']],
#   'wl_code': 'NEF'},
#  {'word': 'vliegenklappertjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord vliegenklapper']],
#   'wl_code': 'NEF'},
#  {'word': 'vliegenklappertje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord vliegenklapper']],
#   'wl_code': 'NEF'},
#  {'word': 'vliegenklappers',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord vliegenklapper']],
#   'wl_code': 'NEF'},
#  {'word': 'vreugdedansjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord vreugdedans']],
#   'wl_code': 'NEF'},
#  {'word': 'vreugdedansje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord vreugdedans']],
#   'wl_code': 'NEF'},
#  {'word': 'vreugdedansen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord vreugdedans']],
#   'wl_code': 'NEF'},
#  {'word': 'walkingdinnertjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord walkingdinner']],
#   'wl_code': 'NEF'},
#  {'word': 'walkingdinnertje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord walkingdinner']],
#   'wl_code': 'NEF'},
#  {'word': 'walkingdinners',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord walkingdinner']],
#   'wl_code': 'NEF'},
#  {'word': 'wagertjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord wager']],
#   'wl_code': 'NEF'},
#  {'word': 'wagertje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord wager']],
#   'wl_code': 'NEF'},
#  {'word': 'wagers',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord wager']],
#   'wl_code': 'NEF'},
#  {'word': 'vakantiepatroontjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord vakantiepatroon']],
#   'wl_code': 'NEF'},
#  {'word': 'vakantiepatroontje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord vakantiepatroon']],
#   'wl_code': 'NEF'},
#  {'word': 'vakantiepatronen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord vakantiepatroon']],
#   'wl_code': 'NEF'},
#  {'word': 'pannenkoekenpannetjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord pannenkoekenpan']],
#   'wl_code': 'NEF'},
#  {'word': 'pannenkoekenpannetje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord pannenkoekenpan']],
#   'wl_code': 'NEF'},
#  {'word': 'pannenkoekenpannen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord pannenkoekenpan']],
#   'wl_code': 'NEF'},
#  {'word': 'pannenkoekpannetjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord pannenkoekpan']],
#   'wl_code': 'NEF'},
#  {'word': 'pannenkoekpannetje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord pannenkoekpan']],
#   'wl_code': 'NEF'},
#  {'word': 'pannenkoekpannen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord pannenkoekpan']],
#   'wl_code': 'NEF'},
#  {'word': 'pannenkoekpan',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een speciale, platte koekenpan met een extra lage rand, die het omdraaien van pannenkoeken, crêpes en omeletten vergemakkelijkt']],
#   'wl_code': 'NEF'},
#  {'word': 'percenttekentjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord percentteken']],
#   'wl_code': 'NEF'},
#  {'word': 'percenttekentje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord percentteken']],
#   'wl_code': 'NEF'},
#  {'word': 'percenttekens',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord percentteken']],
#   'wl_code': 'NEF'},
#  {'word': 'leugenlapjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord leugenlap']],
#   'wl_code': 'NEF'},
#  {'word': 'leugenlapje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord leugenlap']],
#   'wl_code': 'NEF'},
#  {'word': 'leugenlappen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord leugenlap']],
#   'wl_code': 'NEF'},
#  {'word': 'boomkundigen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord boomkundige']],
#   'wl_code': 'NEF'},
#  {'word': 'kwarteldoofste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van kwarteldoof']],
#   'wl_code': 'NEF'},
#  {'word': 'kwarteldoofst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van kwarteldoof']],
#   'wl_code': 'NEF'},
#  {'word': 'kwarteldovers',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van kwarteldoof']],
#   'wl_code': 'NEF'},
#  {'word': 'kwarteldovere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van kwarteldoof']],
#   'wl_code': 'NEF'},
#  {'word': 'kwarteldover',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van kwarteldoof']],
#   'wl_code': 'NEF'},
#  {'word': 'kwarteldoofs',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van kwarteldoof']],
#   'wl_code': 'NEF'},
#  {'word': 'kwarteldove',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van kwarteldoof']],
#   'wl_code': 'NEF'},
#  {'word': 'knoeperhardste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van knoeperhard']],
#   'wl_code': 'NEF'},
#  {'word': 'knoeperhardst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van knoeperhard']],
#   'wl_code': 'NEF'},
#  {'word': 'knoeperharders',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van knoeperhard']],
#   'wl_code': 'NEF'},
#  {'word': 'knoeperhardere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van knoeperhard']],
#   'wl_code': 'NEF'},
#  {'word': 'knoeperharder',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van knoeperhard']],
#   'wl_code': 'NEF'},
#  {'word': 'knoeperhards',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van knoeperhard']],
#   'wl_code': 'NEF'},
#  {'word': 'knoeperharde',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van knoeperhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kogelhardste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van kogelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kogelhardst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van kogelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kogelharders',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van kogelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kogelhardere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van kogelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kogelharder',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van kogelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kogelhards',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van kogelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kogelharde',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van kogelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'bunkerhardste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van bunkerhard']],
#   'wl_code': 'NEF'},
#  {'word': 'bunkerhardst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van bunkerhard']],
#   'wl_code': 'NEF'},
#  {'word': 'bunkerharders',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van bunkerhard']],
#   'wl_code': 'NEF'},
#  {'word': 'bunkerhardere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van bunkerhard']],
#   'wl_code': 'NEF'},
#  {'word': 'bunkerharder',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van bunkerhard']],
#   'wl_code': 'NEF'},
#  {'word': 'bunkerhards',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van bunkerhard']],
#   'wl_code': 'NEF'},
#  {'word': 'bunkerharde',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van bunkerhard']],
#   'wl_code': 'NEF'},
#  {'word': 'oerendhardste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van oerendhard']],
#   'wl_code': 'NEF'},
#  {'word': 'oerendhardst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van oerendhard']],
#   'wl_code': 'NEF'},
#  {'word': 'oerendharders',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van oerendhard']],
#   'wl_code': 'NEF'},
#  {'word': 'oerendhardere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van oerendhard']],
#   'wl_code': 'NEF'},
#  {'word': 'oerendharder',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van oerendhard']],
#   'wl_code': 'NEF'},
#  {'word': 'oerendhards',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van oerendhard']],
#   'wl_code': 'NEF'},
#  {'word': 'oerendharde',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van oerendhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kiezelhardste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van kiezelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kiezelhardst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van kiezelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kiezelharders',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van kiezelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kiezelhardere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van kiezelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kiezelharder',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van kiezelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kiezelhards',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van kiezelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'kiezelharde',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van kiezelhard']],
#   'wl_code': 'NEF'},
#  {'word': 'toneelschrijfkunsten',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord toneelschrijfkunst']],
#   'wl_code': 'NEF'},
#  {'word': 'drinkvermogens',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord drinkvermogen']],
#   'wl_code': 'NEF'},
#  {'word': 'uitroepingstekentjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord uitroepingsteken']],
#   'wl_code': 'NEF'},
#  {'word': 'uitroepingstekentje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord uitroepingsteken']],
#   'wl_code': 'NEF'},
#  {'word': 'uitroepingstekens',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord uitroepingsteken']],
#   'wl_code': 'NEF'},
#  {'word': 'donszacht',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['bijna zonder gewicht en gemakkelijk samen te drukken']],
#   'wl_code': 'NEF'},
#  {'word': 'punthaakjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord punthaak']],
#   'wl_code': 'NEF'},
#  {'word': 'punthaakje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord punthaak']],
#   'wl_code': 'NEF'},
#  {'word': 'punthaken',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord punthaak']],
#   'wl_code': 'NEF'},
#  {'word': 'overzacht',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [],
#   'wl_code': 'NEF'},
#  {'word': 'overzacht',
#   'lang_code': 'nl',
#   'pos': 'adv',
#   'glosses': [['zeer zacht']],
#   'wl_code': 'NEF'},
#  {'word': 'dadfluencertjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord dadfluencer']],
#   'wl_code': 'NEF'},
#  {'word': 'pseudoloog',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['iemand die de neiging heeft om gefantaseerde en vaak heroïsche verhalen te vertellen die hij als waar presenteert; pathologische leugenaar']],
#   'wl_code': 'NEF'},
#  {'word': 'dadfluencertje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord dadfluencer']],
#   'wl_code': 'NEF'},
#  {'word': 'dadfluencers',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord dadfluencer']],
#   'wl_code': 'NEF'},
#  {'word': 'sjadoef',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['handbediend apparaat uit de oudheid, oorspronkelijk uit Egypte, dat wordt gebruikt om water op te pompen uit rivieren of andere waterbronnen om akkers te irrigeren']],
#   'wl_code': 'NEF'},
#  {'word': 'knotsgezelligste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van knotsgezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'knotsgezelligst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van knotsgezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'knotsgezelligers',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van knotsgezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'knotsgezelligere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van knotsgezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'knotsgezelliger',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van knotsgezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'knotsgezelligs',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van knotsgezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'knotsgezellige',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van knotsgezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'nokkievolst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van nokkievol']],
#   'wl_code': 'NEF'},
#  {'word': 'nokkievollers',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van nokkievol']],
#   'wl_code': 'NEF'},
#  {'word': 'nokkievollere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van nokkievol']],
#   'wl_code': 'NEF'},
#  {'word': 'nokkievoller',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van nokkievol']],
#   'wl_code': 'NEF'},
#  {'word': 'nokkievols',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van nokkievol']],
#   'wl_code': 'NEF'},
#  {'word': 'nokkievolle',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van nokkievol']],
#   'wl_code': 'NEF'},
#  {'word': 'nokkievolste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van nokkievol']],
#   'wl_code': 'NEF'},
#  {'word': 'suprafijn',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['heel erg fijn']],
#   'wl_code': 'NEF'},
#  {'word': 'reuzefijn',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['heel erg fijn']],
#   'wl_code': 'NEF'},
#  {'word': 'puntelijkste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van puntelijk']],
#   'wl_code': 'NEF'},
#  {'word': 'puntelijkst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van puntelijk']],
#   'wl_code': 'NEF'},
#  {'word': 'puntelijkers',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van puntelijk']],
#   'wl_code': 'NEF'},
#  {'word': 'puntelijkere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van puntelijk']],
#   'wl_code': 'NEF'},
#  {'word': 'puntelijker',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van puntelijk']],
#   'wl_code': 'NEF'},
#  {'word': 'puntelijks',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van puntelijk']],
#   'wl_code': 'NEF'},
#  {'word': 'puntelijke',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van puntelijk']],
#   'wl_code': 'NEF'},
#  {'word': 'reuzegezellig',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['heel erg gezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'beerlelijk',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['heel erg lelijk']],
#   'wl_code': 'NEF'},
#  {'word': 'reuzekleins',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van reuzeklein']],
#   'wl_code': 'NEF'},
#  {'word': 'reuzekleine',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van reuzeklein']],
#   'wl_code': 'NEF'},
#  {'word': 'boerenkloot',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['zeer dom persoon']],
#   'wl_code': 'NEF'},
#  {'word': 'boerenknurft',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['zeer dom persoon']],
#   'wl_code': 'NEF'},
#  {'word': 'boerenlummel',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['sukkel']],
#   'wl_code': 'NEF'},
#  {'word': 'ezelsveulen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['jong van een ezel'], ['sukkel, domoor']],
#   'wl_code': 'NEF'},
#  {'word': 'dotskop',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['zeer dom persoon']],
#   'wl_code': 'NEF'},
#  {'word': 'NAVO-spellingsalfabet',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['internationaal afgesproken reeks van spelwoorden waarmee elke letter van het Latijnse alfabet kan worden gespeld']],
#   'wl_code': 'NEF'},
#  {'word': 'Karlsbad',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['stad in het westen van Tsjechië'],
#    ['regio in het westen van Tsjechië'],
#    ['district in het westen van Tsjechië'],
#    ['gemeente in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Carlsbad',
#     'sense': ', 2. en 3.',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Mariënbad',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['stad in het westen van Tsjechië']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Hurghada',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['Egyptisch toeristencentrum en badplaats aan de Rode Zee']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Hurghada',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Asjdod',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['havenstad in het westen van Israël']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Ashdod',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Netanja',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['stad in het westen van Israël']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Netanya',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Asjkelon',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['stad in het westen van Israël']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Ashkelon',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Beër Sjeva',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['hoofdstad van het Israëlische district Zuid']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Beersheba',
#     'sense_index': 1},
#    {'lang_code': 'en',
#     'lang': 'Engels',
#     'word': "Be'er-Sheva",
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Maulbronn',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Herrenberg',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Öhringen',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Neckarsulm',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Bad Wimpfen',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Brackenheim',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Leingarten',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Ilsfeld',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een gemeente in de Duitse deelstaat Baden-Württemberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Rosenheim',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Beieren'],
#    ['een district in de Duitse deelstaat Beieren'],
#    ['een gemeente in de Duitse deelstaat Rijnland-Palts']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Kitzbühel',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Oostenrijkse deelstaat Tirol'],
#    ['een district in de Oostenrijkse deelstaat Tirol']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Dornbirn',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Oostenrijkse deelstaat Vorarlberg'],
#    ['een district in de Oostenrijkse deelstaat Vorarlberg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Hallein',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Oostenrijkse deelstaat Salzburg'],
#    ['een district in de Oostenrijkse deelstaat Salzburg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Kufstein',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Oostenrijkse deelstaat Tirol'],
#    ['een district in de Oostenrijkse deelstaat Tirol']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Vöcklabruck',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Oostenrijkse deelstaat Opper-Oostenrijk'],
#    ['een district in de Oostenrijkse deelstaat Opper-Oostenrijk']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Funchal',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['gemeente in het Portugese autonome gebied Madeira']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Freudenberg',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Baden-Württemberg'],
#    ['een stad in de Duitse deelstaat Noordrijn-Westfalen'],
#    ['een gemeente in de Duitse deelstaat Beieren']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Telgte',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Noordrijn-Westfalen']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Varel',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Nedersaksen']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Celle',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Nedersaksen'],
#    ['een district in de Duitse deelstaat Nedersaksen']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Zuiderwijk',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['stadsdeel van de Duitse gemeente Bocholt in het westen van Noordrijn-Westfalen nabij het Nederlandse Dinxperlo']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Dortmund-Eemskanaal',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een kanaal tussen de haven van Dortmund en Emden']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Dortmund–Ems Canal'}],
#   'wl_code': 'NEF'},
#  {'word': 'Eems-Jadekanaal',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['verbinding tussen de rivier de Eems en de Jadeboezem']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Eems-Vechtkanaal',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een kanaal dat de Overijsselse Vecht met de Eems verbindt']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Gelderns-Nierskanaal',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een kanaal dat het Duitse riviertje Niers met de Nederlandse Maas verbindt']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Rijn-Hernekanaal',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een kanaal tussen de Duitse steden Duisburg en Herne, dat de Rijn en het Dortmund-Eemskanaal verbindt']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Rhine–Herne Canal'}],
#   'wl_code': 'NEF'},
#  {'word': 'Monschau',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Noordrijn-Westfalen']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Schmalkalden',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Thüringen']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Eisenach',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een stad in de Duitse deelstaat Thüringen'],
#    ['een gemeente in de Duitse deelstaat Rijnland-Palts']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Wiehengebergte',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['heuvelland van het Weserbergland in het noordoosten van de Duitse deelstaat Noordrijn-Westfalen en het zuidwesten van Nedersaksen']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Wiehen Hills',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Wezergebergte',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['bergrug in de Duitse deelstaten Noordrijn-Westfalen en Nedersaksen']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Weser Hills',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Ahrgebergte',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['gebergte in de Duitse deelstaten Noordrijn-Westfalen en Rijnland-Palts']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Ahr Hills',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Fichtelgebergte',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['middelgebergte tussen de Duitse deelstaat Beieren en Tsjechië']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Ertsgebergte',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een bergketen in de Duitse deelstaat Saksen en in Tsjechië']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Lausitzergebergte',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['gebergte in de Duitse deelstaat Saksen en in Tsjechië']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Elbezandsteengebergte',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['gebergte in de Duitse deelstaat Saksen en in Tsjechië']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Thüringerwoud',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['dichtbebost middelgebergte in de Duitse deelstaat Thüringen']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Thuringian Forest',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Beierse Woud',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['dichtbebost middelgebergte in de Duitse deelstaat Beieren']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Bavarian Forest',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Oostereems',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['zeearm tussen de Oost-Friese waddeneilanden Juist en Borkum in Duitsland']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Zwarte Ernz',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['zijrivier van de Sûre in Luxemburg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Witte Ernz',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['rivier in Luxemburg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Oost-Tirol',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['gedeelte van de Oostenrijkse deelstaat Tirol']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Noord-Tirol',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['gedeelte van de Oostenrijkse deelstaat Tirol']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Kaap Arkona',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['Kaap op het Duitse eiland Rügen']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Cape Arkona',
#     'sense': 'de naam van de zuidwestelijkste punt van Afrika',
#     'sense_index': 1},
#    {'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Cape Arcona',
#     'sense': 'de naam van de zuidwestelijkste punt van Afrika',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Rügen',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['grootste eiland van Duitsland in de Oostzee en onderdeel van de deelstaat Mecklenburg-Vorpommern']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Vorarlberg',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een deelstaat in het uiterste westen van Oostenrijk met deelstaat-hoofdstad Bregenz']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Vorarlberg',
#     'sense': 'deelstaat van Oostenrijk',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Burgenland',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een deelstaat in het uiterste oosten van Oostenrijk met deelstaat-hoofdstad Eisenstadt']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Burgenland',
#     'sense': 'deelstaat van Oostenrijk',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Schaan',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['grootste gemeente in het vorstendom Liechtenstein']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'ICAO',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['internationale organisatie van de VN voor afspraken over de burgerluchtvaart, opgericht in 1947 en gevestigd in Montreal, Canada']],
#   'wl_code': 'NEF'},
#  {'word': 'bereslecht',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['enorm slecht']],
#   'wl_code': 'NEF'},
#  {'word': 'laminator',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een machine die documenten beschermt door ze te voorzien van een transparant, beschermend plastic laagje']],
#   'wl_code': 'NEF'},
#  {'word': 'lamineerapparaat',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een machine die documenten beschermt door ze te voorzien van een transparant, beschermend plastic laagje']],
#   'wl_code': 'NEF'},
#  {'word': 'klontjestang',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['tangetje waarmee men suikerklontjes kan pakken']],
#   'wl_code': 'NEF'},
#  {'word': 'theedoos',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een doosje om thee in te bewaren']],
#   'wl_code': 'NEF'},
#  {'word': 'lepelvaasje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord lepelvaas']],
#   'wl_code': 'NEF'},
#  {'word': 'visbord',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een soort schotel of bord waarop vis wordt geserveerd']],
#   'wl_code': 'NEF'},
#  {'word': 'Weert',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['gemeente en stad in de Nederlandse provincie Limburg']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'frietpan',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['huishoudelijk apparaat gebruikt om in hete olie bepaalde gerechten te frituren']],
#   'wl_code': 'NEF'},
#  {'word': 'baarhuis',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een plaats waar lijken tijdelijk opgebaard liggen']],
#   'wl_code': 'NEF'},
#  {'word': 'paginatitel',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['de titel van een website zoals die wordt weergegeven bij een zoekopdracht']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'page title'}],
#   'wl_code': 'NEF'},
#  {'word': 'Zuid-Karelië',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een regio in het zuidoosten van Finland']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'South Karelia',
#     'sense': 'regio van Finland',
#     'sense_index': 1},
#    {'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Southern Karelia',
#     'sense': 'regio van Finland',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Noord-Karelië',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een regio in het oosten van Finland']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'North Karelia',
#     'sense': 'regio van Finland',
#     'sense_index': 1},
#    {'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Northern Karelia',
#     'sense': 'regio van Finland',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Zuidwest-Finland',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een regio in het zuidwesten van Finland']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Southwest Finland',
#     'sense': 'regio van Finland',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Midden-Finland',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een regio in het midden van Finland']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Central Finland',
#     'sense': 'regio van Finland',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Centraal-Finland',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een regio in het midden van Finland']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Central Finland',
#     'sense': 'regio van Finland',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Moravië-Silezië',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['bestuursregio in het uiterste oosten van Tsjechië']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Moravian-Silesian Region',
#     'sense': 'regio van Tsjechië',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Zuid-Bohemen',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['bestuursregio in het zuiden van Tsjechië']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'South Bohemian Region',
#     'sense': 'regio van Tsjechië',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Midden-Bohemen',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['Tsjechische bestuursregio rond Praag']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Central Bohemian Region',
#     'sense': 'regio van Tsjechië',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Zuid-Moravië',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['bestuursregio in het zuidoosten van Tsjechië']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'South Moravian Region',
#     'sense': 'regio van Tsjechië',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Aargau',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een kanton in het noorden van Zwitserland met kantons-hoofdstad Aarau']],
#   'translations': [{'lang_code': 'en',
#     'lang': 'Engels',
#     'word': 'Aargau',
#     'sense': 'deelstaat van Oostenrijk',
#     'sense_index': 1}],
#   'wl_code': 'NEF'},
#  {'word': 'Nieuw-Nickerie',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['de hoofdplaats van het Surinaamse district Nickerie']],
#   'wl_code': 'NEF'},
#  {'word': 'Lelydorp',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['de hoofdplaats van het Surinaamse district Wanica']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Benzdorp',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een dorp in het Surinaamse district Sipaliwini']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Alfonsdorp',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een dorp in het Surinaamse district Marowijne']],
#   'wl_code': 'NEF'},
#  {'word': 'Bernharddorp',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een dorp in het Surinaamse district Para']],
#   'wl_code': 'NEF'},
#  {'word': 'Cabendadorp',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een plaats in het Surinaamse district Para']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Herminadorp',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een dorp in het Surinaamse district Sipaliwini']],
#   'wl_code': 'NEF'},
#  {'word': 'Stolkertsijver',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een plaats in het Surinaamse district Commewijne']],
#   'wl_code': 'NEF'},
#  {'word': 'Smalkalden',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een plaats in het Surinaamse district Para']],
#   'wl_code': 'NEF'},
#  {'word': 'Post Utrecht',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een dorpje in het Surinaamse district Nickerie']],
#   'wl_code': 'NEF'},
#  {'word': 'Nieuw-Koffiekamp',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een dorp in het Surinaamse district Brokopondo']],
#   'wl_code': 'NEF'},
#  {'word': 'Nieuw-Lombe',
#   'lang_code': 'nl',
#   'pos': 'name',
#   'glosses': [['een transmigratiedorp in het Surinaamse district Brokopondo']],
#   'translations': [],
#   'wl_code': 'NEF'},
#  {'word': 'Laarwijk',
#   'lang_code': 'nl',
#   'pos': 'name',
# ...
#   'wl_code': 'NEF'},
#  {'word': 'teamwedstrijdje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord teamwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'teamwedstrijden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord teamwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'gewichtschijf',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['rond en plat gewicht met een gat in het midden, gebruikt bij spieroefeningen of als onderdeel van een balans']],
#   'wl_code': 'NEF'},
#  {'word': 'zinnendictee',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een oefening in het onderwijs waarbij een volledige zin wordt voorgezegd en de leerling deze vervolgens correct opschrijft']],
#   'wl_code': 'NEF'},
#  {'word': 'zinsdictee',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een oefening in het onderwijs waarbij een volledige zin wordt voorgezegd en de leerling deze vervolgens correct opschrijft']],
#   'wl_code': 'NEF'},
#  {'word': 'zindictee',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een oefening in het onderwijs waarbij een volledige zin wordt voorgezegd en de leerling deze vervolgens correct opschrijft']],
#   'wl_code': 'NEF'},
#  {'word': 'littere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van lit']],
#   'wl_code': 'NEF'},
#  {'word': 'litter',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van lit']],
#   'wl_code': 'NEF'},
#  {'word': 'litte',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van lit']],
#   'wl_code': 'NEF'},
#  {'word': 'kwartfinalewedstrijdjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord kwartfinalewedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'kwartfinalewedstrijdje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord kwartfinalewedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'kwartfinalewedstrijden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord kwartfinalewedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'schaakwedstrijdjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord schaakwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'schaakwedstrijdje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord schaakwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'schaakwedstrijden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord schaakwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'motorwedstrijdjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord motorwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'motorwedstrijdje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord motorwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'motorwedstrijden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord motorwedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'liedjeswedstrijdjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord liedjeswedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'liedjeswedstrijdje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord liedjeswedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'liedjeswedstrijden',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord liedjeswedstrijd']],
#   'wl_code': 'NEF'},
#  {'word': 'pepdrankjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord pepdrank']],
#   'wl_code': 'NEF'},
#  {'word': 'pepdrankje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord pepdrank']],
#   'wl_code': 'NEF'},
#  {'word': 'pepdranken',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord pepdrank']],
#   'wl_code': 'NEF'},
#  {'word': 'pestgedrag',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['herhaaldelijk en voortdurend lastigvallen, waarbij de pesters vaak een zekere machtspositie hebben']],
#   'wl_code': 'NEF'},
#  {'word': 'oneindighoekjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord oneindighoek']],
#   'wl_code': 'NEF'},
#  {'word': 'oneindighoekje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord oneindighoek']],
#   'wl_code': 'NEF'},
#  {'word': 'oneindighoeken',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord oneindighoek']],
#   'wl_code': 'NEF'},
#  {'word': 'strooiingen',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord strooiing']],
#   'wl_code': 'NEF'},
#  {'word': 'dottigste',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de overtreffende trap van dottig']],
#   'wl_code': 'NEF'},
#  {'word': 'dottigst',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de overtreffende trap van dottig']],
#   'wl_code': 'NEF'},
#  {'word': 'dottigers',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de vergrotende trap van dottig']],
#   'wl_code': 'NEF'},
#  {'word': 'dottigere',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de vergrotende trap van dottig']],
#   'wl_code': 'NEF'},
#  {'word': 'dottiger',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['onverbogen vorm van de vergrotende trap van dottig']],
#   'wl_code': 'NEF'},
#  {'word': 'dottigs',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['partitief van de stellende trap van dottig']],
#   'wl_code': 'NEF'},
#  {'word': 'dottige',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van dottig']],
#   'wl_code': 'NEF'},
#  {'word': 'waterachtbaan',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een achtbaan die eindigt in een splash']],
#   'wl_code': 'NEF'},
#  {'word': 'boomstamrivier',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een type wildwaterbaan met boomstamvormige boten die in een smalle goot varen.']],
#   'wl_code': 'NEF'},
#  {'word': 'boomstambaan',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een type wildwaterbaan met boomstamvormige boten die in een smalle goot varen.']],
#   'wl_code': 'NEF'},
#  {'word': 'drinkersbaas',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['zuiplap']],
#   'wl_code': 'NEF'},
#  {'word': 'pappert',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['zuiplap']],
#   'wl_code': 'NEF'},
#  {'word': 'zuipzak',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['iemand die verslaafd is aan alcohol']],
#   'wl_code': 'NEF'},
#  {'word': 'stokfiguur',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een basale tekening die bestaat uit lijnen en een of meer cirkels, vaak gebaseerd op de vorm van een mens of dier']],
#   'wl_code': 'NEF'},
#  {'word': 'hondenslager',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['persoon die aangesteld om loslopende honden dood te slaan']],
#   'wl_code': 'NEF'},
#  {'word': 'hondenmepper',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['persoon die aangesteld om loslopende honden dood te slaan']],
#   'wl_code': 'NEF'},
#  {'word': 'hondenfooi',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['te klein bedrag']],
#   'wl_code': 'NEF'},
#  {'word': 'oerexplosie',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['het ontstaan van het heelal']],
#   'wl_code': 'NEF'},
#  {'word': 'oerknus',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['extreem gezellig']],
#   'wl_code': 'NEF'},
#  {'word': 'oerouderwets',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['extreem ouderwets']],
#   'wl_code': 'NEF'},
#  {'word': 'oergeestig',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['extreem geestig, extreem grappig']],
#   'wl_code': 'NEF'},
#  {'word': 'oergelukkig',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['extreem gelukkig']],
#   'wl_code': 'NEF'},
#  {'word': 'lekkertand',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['lekkerbek']],
#   'wl_code': 'NEF'},
#  {'word': 'glasafval',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['afval van glas']],
#   'wl_code': 'NEF'},
#  {'word': 'kanteldeurtjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord kanteldeur']],
#   'wl_code': 'NEF'},
#  {'word': 'kanteldeurtje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord kanteldeur']],
#   'wl_code': 'NEF'},
#  {'word': 'kanteldeuren',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord kanteldeur']],
#   'wl_code': 'NEF'},
#  {'word': 'kantelpoortjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord kantelpoort']],
#   'wl_code': 'NEF'},
#  {'word': 'kantelpoortje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord kantelpoort']],
#   'wl_code': 'NEF'},
#  {'word': 'medebeslissingsrecht',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['het recht om samen met anderen ergens over te beslissen']],
#   'wl_code': 'NEF'},
#  {'word': 'lichaamspositiviteit',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['het trots zijn op het eigen lichaam ook als dit niet voldoet aan de schoonheidsidealen']],
#   'wl_code': 'NEF'},
#  {'word': 'botsboot',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een speeltoestel met de gecombineerde eigenschappen van een boot en een botsauto']],
#   'wl_code': 'NEF'},
#  {'word': 'apentaal',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['onverstaanbare taal']],
#   'wl_code': 'NEF'},
#  {'word': 'slaggelingse',
#   'lang_code': 'nl',
#   'pos': 'adj',
#   'glosses': [['verbogen vorm van de stellende trap van slaggelings']],
#   'wl_code': 'NEF'},
#  {'word': 'jokkenaartjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord jokkenaar']],
#   'wl_code': 'NEF'},
#  {'word': 'jokkenaartje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord jokkenaar']],
#   'wl_code': 'NEF'},
#  {'word': 'jokkenaars',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord jokkenaar']],
#   'wl_code': 'NEF'},
#  {'word': 'prengelaartjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord prengelaar']],
#   'wl_code': 'NEF'},
#  {'word': 'prengelaartje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord prengelaar']],
#   'wl_code': 'NEF'},
#  {'word': 'prengelaars',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord prengelaar']],
#   'wl_code': 'NEF'},
#  {'word': 'huppelaartjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord huppelaar']],
#   'wl_code': 'NEF'},
#  {'word': 'huppelaartje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord huppelaar']],
#   'wl_code': 'NEF'},
#  {'word': 'huppelaars',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord huppelaar']],
#   'wl_code': 'NEF'},
#  {'word': 'biljettenautomaat',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['apparaat dat contant geld kan uitdelen']],
#   'wl_code': 'NEF'},
#  {'word': 'afroomkluis',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['kluis die bij de kassa wordt geplaatst om contant geld en munten veilig op te bergen, zonder de kassa zelf te openen']],
#   'wl_code': 'NEF'},
#  {'word': 'armdrukken',
#   'lang_code': 'nl',
#   'pos': 'verb',
#   'glosses': [['een krachtsport waarbij twee tegenstanders met hun ellebogen op een tafel of oppervlak rusten en met hun handen een soortgelijk grijpgevecht aangaan om de hand van de ander op de tafel te drukken']],
#   'wl_code': 'NEF'},
#  {'word': 'drinkeboer',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['iemand die veel alcoholische dranken drinkt vooral in vrolijke gezelschappen']],
#   'wl_code': 'NEF'},
#  {'word': 'luchtbellenijs',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['ijs waar geen water meer onder is']],
#   'wl_code': 'NEF'},
#  {'word': 'lamineermachine',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een apparaat dat gebruikt wordt om documenten te beschermen tegen vocht, vuil en slijtage']],
#   'wl_code': 'NEF'},
#  {'word': 'familiekunde',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['het onderzoeken wie je voorouders waren']],
#   'wl_code': 'NEF'},
#  {'word': 'searchengine',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['computerprogramma waarmee men informatie kan zoeken in een bepaalde collectie; dit kan een bibliotheek, het internet, of een persoonlijke verzameling zijn']],
#   'wl_code': 'NEF'},
#  {'word': 'staafgrafiek',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['grafische weergave van de frequentieverdeling van data, afkomstig uit een discrete kansverdeling']],
#   'wl_code': 'NEF'},
#  {'word': 'schattebol',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['lieverd']],
#   'wl_code': 'NEF'},
#  {'word': 'schoolsucces',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['het goed presteren van een leerling op school']],
#   'wl_code': 'NEF'},
#  {'word': 'naamgrap',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['humoristische combinatie van namen, vaak voor- en achternamen, die samen een grappige of spottende betekenis creëren']],
#   'wl_code': 'NEF'},
#  {'word': 'schoolsportdag',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['een evenement waarbij leerlingen deelnemen aan diverse sportieve en spelgerelateerde activiteiten om te bewegen, te ontspannen en elkaar op een andere manier te leren kennen']],
#   'wl_code': 'NEF'},
#  {'word': 'schoolsport',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['op scholieren gerichte sport- en beweegactiviteiten die georganiseerd worden op, rondom of op weg naar school']],
#   'wl_code': 'NEF'},
#  {'word': 'jeugdtaal',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['taalgebruik dat typisch is voor jongeren']],
#   'wl_code': 'NEF'},
#  {'word': 'joert',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['traditionele, ronde tent die voornamelijk wordt gebruikt als woning door rondtrekkende nomaden in Centraal-Azië']],
#   'wl_code': 'NEF'},
#  {'word': 'potkrauwers',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord potkrauwer']],
#   'wl_code': 'NEF'},
#  {'word': 'mottigaardjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord mottigaard']],
#   'wl_code': 'NEF'},
#  {'word': 'mottigaardje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord mottigaard']],
#   'wl_code': 'NEF'},
#  {'word': 'mottigaards',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord mottigaard']],
#   'wl_code': 'NEF'},
#  {'word': 'bankpootjes',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord meervoud van het zelfstandig naamwoord bankpoot']],
#   'wl_code': 'NEF'},
#  {'word': 'bankpootje',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['verkleinwoord enkelvoud van het zelfstandig naamwoord bankpoot']],
#   'wl_code': 'NEF'},
#  {'word': 'bankpoten',
#   'lang_code': 'nl',
#   'pos': 'noun',
#   'glosses': [['meervoud van het zelfstandig naamwoord bankpoot']],
#   'wl_code': 'NEF'}]

# %%
all_words_defs
# Out:
# []

# %%
with open(Path(NEF_out, f"NLS_to_line_{17441}.pkl"), 'wb') as out:
                        pickle.dump(kv2, out)

# %%
with open(Path(current_save_folder, f"NLS_to_line_{611448}.pkl"), 'wb') as out:
    pickle.dump(kv, out)

# %%
display(kv.keys())
# Out:
# dict_keys(['word', 'lang_code', 'lang', 'pos', 'pos_title', 'senses', 'categories', 'etymology_texts', 'sounds', 'antonyms', 'derived', 'proverbs', 'hyponyms', 'related', 'translations', 'hyphenations', 'tags', 'synonyms', 'notes', 'forms', 'anagrams', 'hypernyms', 'homophones', 'holonyms', 'metonyms', 'descendants', 'abbreviations', 'paronyms'])

# %%
NNL_keys = ['word', 'lang_code', 'lang', 'pos', 'pos_title', 'senses', 'categories', 'etymology_texts', 'sounds', 'antonyms', 'derived', 'proverbs', 'hyponyms', 'related', 'translations', 'hyphenations', 'tags', 'synonyms', 'notes', 'forms', 'anagrams', 'hypernyms', 'homophones', 'holonyms', 'metonyms', 'descendants', 'abbreviations', 'paronyms']

# %%
kv = {}
sub2 = []
for x in tqdm(substructures, total=len(substructures)):
    for key, value in x.items():
        if key not in kv.keys():
            kv[key] = [value]
        elif value not in kv[key]:
            kv[key].append(value)
# Out:
# 100%|██████████| 91386/91386 [00:02<00:00, 39460.00it/s]

# %%
senses_kv = kv['notes']
senses_kv
# Out:
# [[str]]

# %%
print(len(substructures))
# Out:
# 64428

# %%
import pickle
outfile = Path(current_save_folder, 'NL_structures.pkl')
Path.mkdir(current_save_folder, exist_ok=True)
with open(outfile, 'wb') as f:
    pickle.dump(substructures, f)

# %%
Path.mkdir(current_save_folder, exist_okay=True)

# %% [markdown]
# ## Get Defs Translations

# %%
EER_word_definitions_translations = Path(current_save_path, 'EER', 'EER_definitions_translations.jsonl')
words_definitions = {}
with open(EER_file, 'r', encoding='utf-8',errors='ignore') as f:
    if not EER_word_definitions_translations.exists():
        Path.mkdir(Path(current_save_path, 'EER'))
    with open(EER_word_definitions_translations, 'a+', encoding='utf-8') as out:
        lines = f.readlines()
        for obj in tqdm(lines, total=len(lines)):
            try:
                obj = json.loads(obj)

            except Exception as e:
                print()
                print(e)

# %% [markdown]
# ## Previous Exploration categories discovered

# %% [markdown]
# en_en_top_keys = ['word', 'pos', 'lang_code', 'abbreviations', 'antonyms', 'categories', 'coordinate_terms',
#        'derived', 'descendants', 'etymology_number', 'etymology_templates',
#        'etymology_text', 'form_of', 'forms', 'head_templates', 'holonyms',
#        'hypernyms', 'hyphenation', 'hyphenations', 'hyponyms',
#        'inflection_templates', 'info_templates', 'instances', 'lang',
#         'meronyms', 'original_title',  'related', 'senses',
#        'sounds', 'source', 'synonyms', 'translations', 'troponyms', 'wikidata',
#        'wikipedia']

# %%
en_nl_top_keys = ['pos', 'head_templates', 'inflection_templates', 'forms', 'descendants',
       'sounds', 'hyphenations', 'etymology_text', 'etymology_templates',
       'word', 'lang', 'lang_code', 'senses', 'etymology_number', 'derived',
       'related', 'antonyms', 'wikipedia', 'hypernyms', 'synonyms',
       'categories', 'coordinate_terms', 'hyponyms', 'abbreviations',
       'holonyms', 'meronyms']

# %%
senses
pos
head_templates
forms
derived
descendants
sounds
hyphenations
etymology_text
etymology_templates
word
lang
lang_code
inflection_templates
categories
related
etymology_number
synonyms
antonyms
wikipedia
hypernyms
hyponyms
holonyms
coordinate_terms
meronyms

# %%
eep_senses = ['word', 'pos', 'lang_code', 'senses', 'alt_of', 'antonyms', 'attestations', 'categories', 'coordinate_terms', 'derived', 'examples', 'form_of', 'glosses', 'head_nr', 'holonyms', 'hypernyms', 'hyponyms', 'id', 'info_templates', 'instances', 'links', 'meronyms', 'qualifier', 'raw_glosses', 'raw_tags', 'related', 'senseid', 'synonyms', 'tags', 'taxonomic', 'topics', 'translations', 'troponyms', 'wikidata', 'wikipedia']

# %%
"""
EEP Senses
1   word              613365 non-null  object 
 2   pos               613365 non-null  object 
 3   lang_code         613365 non-null  object 
 4   senses            613365 non-null  object 
 5   alt_of            60977 non-null   object 
 6   antonyms          3924 non-null    object 
 7   attestations      3712 non-null    object 
 8   categories        600737 non-null  object 
 9   coordinate_terms  8923 non-null    object 
 10  derived           25243 non-null   object 
 11  examples          128798 non-null  object 
 12  form_of           239885 non-null  object 
 13  glosses           612962 non-null  object 
 14  head_nr           162 non-null     float64
 15  holonyms          189 non-null     object 
 16  hypernyms         4482 non-null    object 
 17  hyponyms          2284 non-null    object 
 18  id                613365 non-null  object 
 19  info_templates    81 non-null      object 
 20  instances         12 non-null      object 
 21  links             599259 non-null  object 
 22  meronyms          229 non-null     object 
 23  qualifier         9498 non-null    object 
 24  raw_glosses       165385 non-null  object 
 25  raw_tags          5429 non-null    object 
 26  related           38556 non-null   object 
 27  senseid           5743 non-null    object 
 28  synonyms          55151 non-null   object 
 29  tags              485883 non-null  object 
 30  taxonomic         34 non-null      object 
 31  topics            91046 non-null   object 
 32  translations      64502 non-null   object 
 33  troponyms         16 non-null      object 
 34  wikidata          2232 non-null    object 
 35  wikipedia         27768 non-null   object 
 """

# %%
ENP Senses
'word', 'pos', 'lang_code', 'antonyms', 'categories',
       'coordinate_terms', 'derived', 'descendants', 'etymology_templates',
       'etymology_text', 'forms', 'head_templates', 'holonyms', 'hypernyms',
       'hyphenations', 'hyponyms', 'inflection_templates', 'meronyms',
       'related', 'senses', 'sounds', 'synonyms'

# %%
NNP
'word', 'pos', 'lang_code', 'antonyms', 'categories',
       'derived', 'descendants', 'etymology_texts', 'forms', 'holonyms',
       'homophones', 'hypernyms', 'hyphenations', 'hyponyms', 'metonyms',
       'notes', 'related', 'senses', 'sounds', 'synonyms', 'tags',
       'translations'

# %%
combined_nl_en_top_keys = ['word', 'pos', 'lang_code', 'senses', 'abbreviations', 'anagrams', 'antonyms', 'categories',
       'coordinate_terms', 'derived', 'descendants', 'etymology_number',
       'etymology_templates', 'etymology_text', 'etymology_texts', 'form_of',
       'forms', 'head_templates', 'holonyms', 'homophones', 'hypernyms',
       'hyphenation', 'hyphenations', 'hyponyms', 'inflection_templates',
       'info_templates', 'instances', 'invalid', 'lang', 
       'meronyms', 'metonyms', 'notes', 'origin', 'original_title', 'paronyms',
        'pos_title', 'proverbs', 'related',  'sounds', 'source',
       'synonyms', 'tags', 'translations', 'troponyms', 'wikidata',
       'wikipedia']
