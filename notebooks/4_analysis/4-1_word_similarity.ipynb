# %%
import Levenshtein
import pandas as pd
import numpy as np
from dutchanalyzer.config import *
from dutchanalyzer.utilities.pandas_utils import *
from dutchanalyzer.utilities.replacement_utils import *
from dutchanalyzer.utilities.json_utils import *

# %%
import pickle

# %%
today = datetime.date.today().__format__("%d-%m-%y")
current_save_folder = Path(WIKT_CLEANING_DIR, str(today))
folders = {'en': ['EEF', 'ENF'], 'nl':['NEF', 'NNF']}


for k, v in folders.items():
    for f in v:
        Path.mkdir(Path(current_save_folder, k, f), parents=True, exist_ok=True)

# %%
enf_one_sense_path = Path(ENF_FOLDER, 'one_sense_entries.pkl')
enf_one_word_glosses_path = Path(ENF_FOLDER, 'one_word_entries.pkl')

# %%
enf_one_word_entries = []
with open(enf_one_word_glosses_path, 'rb') as f:
    enf_one_word_entries = pickle.load(f)

# %% [markdown]
# - The one word defs are not actually one word defs. Will need to be paired down.

# %%
enf_one_word_entries
# Out:
# {('woordenboek', 'noun'): 'dictionary',
#  ('gratis', 'adj'): 'free, without charge',
#  ('gratuit', 'adj'): 'gratuitous, not obliged to',
#  ('pies', 'noun'): 'alternative form of pis; pee, piss',
#  ('raven', 'verb'): 'to (hold a) rave, to party wildly',
#  ('raven', 'noun'): 'plural of raaf',
#  ('trade', 'verb'): 'singular past subjunctive of treden',
#  ('patronage', 'noun'): 'patronage (act of providing approval and support)',
#  ('product', 'noun'): 'product',
#  ('name', 'verb'): 'singular past subjunctive of nemen',
#  ('a-', 'prefix'): 'a-: not, without, opposite of',
#  ('aam', 'noun'): 'aam',
#  ('aardwolf', 'noun'): 'aardwolf',
#  ('abattoir', 'noun'): 'abattoir, slaughterhouse',
#  ('abject', 'adj'): 'reprehensible, despicable, abject',
#  ('abrupt', 'adj'): 'abrupt (sudden)',
#  ('on',
#   'adv'): 'rarely used as shorthand for oneven (odd), the prefix on- means not (corresponds to English un-)',
#  ('kun', 'verb'): 'second-person singular present indicative of kunnen',
#  ('quiz', 'noun'): 'quiz',
#  ('millennium', 'noun'): 'millennium',
#  ('week', 'noun'): 'week, period of seven days',
#  ('week', 'verb'): 'singular past indicative of wijken',
#  ('nu', 'conj'): 'now (that)',
#  ('nu', 'noun'): 'n (letter of the Greek alphabet)',
#  ('zomer', 'noun'): 'summer',
#  ('herfst', 'noun'): 'autumn, fall',
#  ('winter', 'noun'): 'winter',
#  ('robot', 'noun'): 'robot',
#  ('absent', 'adj'): 'absent',
#  ('alien', 'noun'): 'an alien, an extraterrestrial',
#  ('de',
#   'article'): 'the; definite article, masculine and feminine singular, plural',
#  ('de', 'prep'): 'per',
#  ('het', 'article'): 'neuter singular of de (“the”), the definite article',
#  ('ik', 'pron'): 'I; first-person singular subjective personal pronoun',
#  ('te', 'adv'): 'too (indicating excess)',
#  ('te', 'article'): 'in idiom; a form of the definite article de',
#  ('dat',
#   'det'): 'neuter singular of die (“that”); referring to a thing or a person further away.',
#  ('dat', 'conj'): 'that (introducing a subordinate clause)',
#  ('in', 'prep'): 'in (expressing containment)',
#  ('in', 'adj'): 'in style, fashionable',
#  ('een',
#   'article'): 'a, an; indefinite article, placed before a singular noun, indicating a general case of a person or thing',
#  ('hij',
#   'pron'): 'he; third-person singular masculine subjective personal pronoun',
#  ('niet', 'adv'): "not, no, don't: used to express negation.",
#  ('niet', 'noun'): 'staple (wire fastener)',
#  ('lens', 'noun'): 'alternative form of luns',
#  ('o', 'intj'): 'oh',
#  ('beer',
#   'noun'): 'liquid, notably human manure (excrement gathered in a pit to fertilize)',
#  ('pseudo-', 'noun'): 'pseudo-',
#  ('man',
#   'intj'): 'Indicates that something is larger/stronger/... than usual.',
#  ('is',
#   'verb'): 'third-person singular present indicative of zijn; is, equals',
#  ('is', 'adv'): 'clipping of eens',
#  ('are', 'noun'): 'are, a unit of surface area',
#  ('rape', 'verb'): 'singular present subjunctive of rapen',
#  ('doctrine', 'noun'): 'doctrine',
#  ('port', 'noun'): 'port, port wine, Porto',
#  ('os', 'noun'): 'ox (castrated bull)',
#  ('date', 'noun'): 'a date (romantic outing)',
#  ('BTW', 'noun'): 'alternative letter-case form of btw',
#  ('lol', 'noun'): 'fun',
#  ('lol', 'intj'): 'LOL ("laughing out loud", expression of mirth)',
#  ('bot',
#   'noun'): 'a bot (software for repetitive minor tasks; computer-controlled character in video games)',
#  ('ten',
#   'contraction'): 'to the, at the (followed by a masculine or neuter word)',
#  ('onderuitputting', 'noun'): 'incomplete use of budgeted funds',
#  ('onderbenutting',
#   'noun'): 'underutilization, incomplete use (of e.g. a budget)',
#  ('most',
#   'noun'): 'must (unfermented or partially fermented mashed grapes or rarely other fruits, an early stage in the production of wine)',
#  ('wage', 'verb'): 'singular present subjunctive of wagen',
#  ('consensus', 'noun'): 'consensus',
#  ('fruit',
#   'noun'): 'fruit (produced by trees or bushes, or any sweet vegetable; only literal sense)',
#  ('metadata', 'noun'): 'metadata',
#  ('big', 'noun'): 'piglet, little pig',
#  ('meeting', 'noun'): 'meeting',
#  ('quisling', 'noun'): 'quisling',
#  ('SMS', 'noun'): 'misspelling of sms',
#  ('radio', 'noun'): 'radio, tuner',
#  ('barcode', 'noun'): 'barcode',
#  ('um', 'intj'): 'um (expressing hesitation)',
#  ('gas', 'noun'): 'unpaved street',
#  ('mars', 'noun'): 'ass, arse',
#  ('mars', 'intj'): 'march! (military command)',
#  ('mi', 'noun'): 'mi',
#  ('love', 'verb'): 'singular present subjunctive of loven',
#  ('software', 'noun'): 'software (encoded computer instructions)',
#  ('computer', 'noun'): 'computer',
#  ('absurd', 'adj'): 'absurd',
#  ('abundant', 'adj'): 'abundant',
#  ('affix', 'noun'): 'Affix (linguistics and mathematics)',
#  ('bio', 'noun'): 'biology (as a school subject)',
#  ('smiley', 'noun'): 'smiley',
#  ('accountant', 'noun'): 'an accountant; an account-keeper or auditor',
#  ('accumulator', 'noun'): 'battery, accumulator',
#  ('Belarus', 'noun'): 'a make of tractor, named for Belarus',
#  ('ad', 'noun'): 'abbreviation of annō Dominī',
#  ('baby', 'noun'): 'baby (infant)',
#  ('yes', 'intj'): 'yay (exclamation of happiness or enthusiasm)',
#  ('stand', 'noun'): 'stand (small building or booth)',
#  ('yeti', 'noun'): 'yeti',
#  ('radar',
#   'noun'): 'radar (detection system operating by means of radio waves)',
#  ('president', 'noun'): 'president',
#  ('fuck', 'intj'): 'fuck!',
#  ('DNA',
#   'noun'): 'initialism of desoxyribonucleïnezuur (“deoxyribonucleic acid”)',
#  ('kill', 'noun'): 'guy, dude',
#  ('drug',
#   'noun'): 'a recreational drug, psychoactive substance, especially when illegal and addictive',
#  ('dar', 'noun'): 'drone (non-working male bee, ant or wasp)',
#  ('beige', 'adj'): 'beige',
#  ('gold', 'verb'): 'singular past indicative of gelden',
#  ('green', 'noun'): 'green, putting green',
#  ('magenta', 'noun'): 'magenta (pinkish purple colour)',
#  ('magenta', 'adj'): 'magenta (being of the magenta colour)',
#  ('pink',
#   'noun'): 'a pink (historic coastal fishing boat with one mast, often landed on beaches)',
#  ('violet', 'noun'): 'violet, a purplish colour',
#  ('violet', 'adj'): 'violet-coloured',
#  ('Chinese', 'noun'): 'woman from China',
#  ('tuba', 'noun'): 'tuba (large brass musical instrument)',
#  ('duel', 'noun'): 'a duel',
#  ('wrong',
#   'noun'): 'wreath, a ring made of two strips of cloth intertwined used on top of helmets to soften any blow',
#  ('wrong', 'verb'): 'singular past indicative of wringen',
#  ('wove', 'verb'): 'singular past subjunctive of wuiven',
#  ('worst', 'noun'): 'sausage',
#  ('dollar', 'noun'): 'dollar (currency, especially the US dollar)',
#  ('cast', 'noun'): 'cast (people performing a movie or play)',
#  ('router', 'noun'): 'router (networking device)',
#  ('weekend', 'noun'): 'weekend',
#  ('pit', 'noun'): 'pit (refueling station and garage at a race track)',
#  ('Welsh', 'noun'): 'the Welsh (people of Wales)',
#  ('Welsh', 'adj'): 'Welsh',
#  ('imperfect', 'adj'): 'imperfect (not perfect)',
#  ('parallel', 'noun'): 'parallel (all senses)',
#  ('parallel', 'adj'): 'parallel',
#  ('jack', 'noun'): 'jacket',
#  ('design', 'noun'): 'design',
#  ('sol',
#   'noun'): 'sol (the fifth step in the solfège scale of C, preceded by fa and followed by la)',
#  ('tennis', 'noun'): 'tennis (sport)',
#  ('polyglot', 'adj'): 'polyglot',
#  ('shit', 'intj'): 'shit, darn',
#  ('hand',
#   'noun'): 'a hand of a human, other simian or other animal with fingers',
#  ('toe',
#   'intj'): 'come on!, go on! (used when trying to coax someone into doing something)',
#  ('toe', 'adv'): 'alternative form of toen',
#  ('toe', 'conj'): 'alternative form of toen',
#  ('el', 'noun'): 'a unit of length corresponding to about 69 cm: ell, cubit',
#  ('finish', 'noun'): 'finish; end',
#  ('anoa', 'noun'): 'anoa, Bubalus depressicornis',
#  ('elk', 'det'): 'each; every',
#  ('elk', 'pron'): 'everyone; everybody',
#  ('alpaca', 'noun'): 'alpaca',
#  ('yak', 'noun'): 'alternative spelling of jak',
#  ('lama', 'noun'): 'Buddhist lama',
#  ('lama', 'intj'): 'abbreviation of laat maar (“never mind”)',
#  ('guanaco',
#   'noun'): 'guanaco (a South American ruminant (Lama guanicoe), closely related to the other lamoids, the alpaca, llama, and vicuña in the family Camelidae)',
#  ('wombat', 'noun'): 'wombat',
#  ('koala', 'noun'): 'koala (Phascolarctos cinereus)',
#  ('jacht',
#   'noun'): 'yacht (fast, light and now often luxurious (sailing) boat)',
#  ('wiki', 'noun'): 'wiki',
#  ('voornaam', 'noun'): 'first name',
#  ('voornaam', 'adj'): 'important, distinguished',
#  ('voornamelijk', 'adv'): 'mainly, mostly; predominantly',
#  ('ate', 'verb'): 'singular past subjunctive of eten',
#  ('bongo', 'noun'): 'a bongo (small Cuban drum used in pairs)',
#  ('impala', 'noun'): 'impala',
#  ('adjunct',
#   'noun'): 'an adjunct, a subordinate person, esp. an attendant of a government official',
#  ('my', 'pron'): 'obsolete spelling of mij',
#  ('rechtsomkeert',
#   'adv'): "(only used with maken) rechtsomkeert maken: do an about-turn, do an about-face; turn on one's heels, make a U-turn",
#  ('qua', 'prep'): 'regarding, concerning, in terms of',
#  ('species', 'noun'): 'plural of specie',
#  ('mikado', 'noun'): 'mikado, pick-up sticks (game of skill)',
#  ('amusement', 'noun'): 'entertainment, amusement',
#  ('as', 'noun'): 'A-flat',
#  ('as', 'conj'): 'alternative spelling of als',
#  ('bepalingaankondigend voornaamwoord',
#   'noun'): 'a pronoun which announces that it should be immediately followed by a relative clause',
#  ('bijvoeglijk', 'adj'): 'adjective',
#  ('boom', 'noun'): 'obsolete form of bodem (“soil”)',
#  ('wassen', 'verb'): 'to rub wax on, to wax',
#  ('wassen', 'adj'): 'made of wax, waxen',
#  ('kerel', 'noun'): 'a long overgarment',
#  ('kluit', 'noun'): 'obsolete form of kluut',
#  ('met een kluitje in het riet sturen',
#   'verb'): 'to send someone off empty-handed or none the wiser',
#  ('sibling', 'noun'): 'sibling',
#  ('non', 'noun'): 'nun',
#  ('nicht',
#   'noun'): 'male homosexual, a gay man; in particular one who is camp or effeminate',
#  ('hot', 'adj'): 'right, on the right side',
#  ('cool', 'adj'): 'cool, fashionable',
#  ('Thai', 'noun'): 'a Thai person',
#  ('men',
#   'pron'): 'one, you, they, everyone; humanity, (the) people, the public opinion',
#  ('male', 'noun'): 'dative singular of maal',
#  ('male', 'verb'): 'singular present subjunctive of malen',
#  ('bahasa', 'noun'): 'Indonesian language',
#  ('habitat', 'noun'): 'habitat',
#  ('hack', 'noun'): 'hack (exploit; illegitimate attempt to gain access)',
#  ('astronaut', 'noun'): 'a (male) astronaut',
#  ('project', 'noun'): 'project (planned endeavor)',
#  ('experiment', 'noun'): 'experiment',
#  ('pigment', 'noun'): 'pigment, coloring substance',
#  ('update', 'noun'): 'an update',
#  ('bergamot', 'noun'): 'bergamot (pear-shaped citrus fruit)',
#  ('indigo', 'noun'): 'the colour indigo',
#  ('indigo', 'adj'): 'indigo-coloured',
#  ('room', 'noun'): 'cream (of milk)',
#  ('lob', 'noun'): 'lob (arcing pass of a ball)',
#  ('sombrero', 'noun'): 'sombrero (hat)',
#  ('alligator', 'noun'): 'alligator, crocodilian of the genus Alligator',
#  ('hobby', 'noun'): 'hobby (activity)',
#  ('tin', 'noun'): 'tin (metal, metallic element)',
#  ('caracal', 'noun'): 'caracal (Caracal caracal)',
#  ('minister', 'noun'): 'a servant of a monastery, or assistant of a priest',
#  ('hallelujah', 'intj'): 'alternative form of halleluja',
#  ('hallelujah', 'noun'): 'alternative form of halleluja',
#  ('sepia', 'noun'): 'cuttlefish',
#  ('diesel', 'noun'): 'diesel',
#  ('fascist', 'noun'): 'fascist',
#  ('avocado', 'noun'): 'avocado, alligator pear',
#  ('tortilla', 'noun'): 'tortilla (flat round bread)',
#  ('salsa', 'noun'): 'salsa (spicy tomato sauce)',
#  ('om', 'conj'): 'in order to; shortening of om te',
#  ('epigram', 'noun'): 'epigram (short, pithy poem)',
#  ('equinox', 'noun'): 'equinox',
#  ('hazel', 'noun'): 'hazel',
#  ('marina', 'noun'): 'common, ordinary girl (often with a pejorative meaning)',
#  ('hamster', 'noun'): 'hamster',
#  ('replica', 'noun'): 'replica (exact copy)',
#  ("johnny's en marina's",
#   'noun'): 'young people who are considered unsophisticated',
#  ('safari', 'noun'): 'safari',
#  ('handout', 'noun'): 'alternative spelling of hand-out',
#  ('brochure', 'noun'): 'a brochure, a booklet',
#  ('al', 'det'): 'all, all of',
#  ('al', 'conj'): 'even if',
#  ('bei', 'noun'): 'bey, beg (historical Turkish official)',
#  ('del', 'noun'): 'trollop, floozie',
#  ('ai', 'noun'): 'pale-throated sloth (Bradypus tridactylus)',
#  ('vrij', 'adv'): 'fairly, rather, quite, very',
#  ('wij', 'pron'): 'we; first-person plural subjective personal pronoun',
#  ('wei', 'noun'): 'alternative form of weide',
#  ('haar',
#   'pron'): 'her; third-person singular feminine objective personal pronoun',
#  ('haar', 'det'): 'their; third-person plural possessive determiner',
#  ('mijn', 'det'): 'my; first-person singular possessive determiner',
#  ('mijn',
#   'noun'): 'a Dutch auction (reverse auction with gradual reduction of the price until a buyer is found)',
#  ('god', 'noun'): 'god, deity',
#  ('bad', 'verb'): 'singular past indicative of bidden',
#  ('bal', 'noun'): 'ball, dance party',
#  ('bals', 'noun'): 'plural of bal',
#  ('ban', 'noun'): 'a revocation of permission to access or participate',
#  ('listen', 'noun'): 'plural of list',
#  ('talk', 'noun'): 'alternative form of talg (“tallow”)',
#  ('song', 'noun'): 'song',
#  ('zak',
#   'noun'): "a sack or 'tent', oversized or otherwise mismade female gown, dress",
#  ('bef', 'noun'): 'a nickname for an unspecified small Dutch coin',
#  ('beg', 'noun'): 'alternative form of bei',
#  ('begin', 'noun'): 'start, beginning',
#  ('bel', 'noun'): 'bubble',
#  ('beginner',
#   'noun'): 'someone who is just starting something, or has only recently started (similar to English)',
#  ('benen', 'adj'): 'made of bone',
#  ('benen', 'verb'): 'to walk in large strides',
#  ('benen', 'noun'): 'plural of been',
#  ('OK', 'noun'): 'abbreviation of operatiekamer',
#  ('positron', 'noun'): 'positron',
#  ('benzol', 'noun'): 'benzene',
#  ('ver', 'adj'): 'far, distant',
#  ('vers', 'adj'): 'fresh',
#  ('verre', 'adv'): 'archaic form of ver',
#  ('look', 'noun'): 'a look, (clothing) style, appearance',
#  ('look', 'verb'): 'singular past indicative of luiken',
#  ('graffiti', 'noun'): 'graffiti (drawings on a public surface)',
#  ('jargon', 'noun'): 'jargon, specialised language',
#  ('slang',
#   'noun'): 'slang, language outside the conventional register specific to a social group',
#  ('pedant', 'adj'): 'pedantic',
#  ('polder',
#   'noun'): 'polder (land reclaimed from a body of water and enclosed by dykes)',
#  ('we', 'pron'): 'unstressed form of wij (“we”)',
#  ('me', 'pron'): 'pronunciation spelling of mijn (“my”)',
#  ('uwe', 'pron'): 'non-attributive form of uw; yours',
#  ('Taiwanese', 'noun'): 'Taiwanese woman',
#  ('graft', 'noun'): 'obsolete form of gracht (“grave”)',
#  ('leg', 'noun'): 'The act or process of laying something, particularly eggs.',
#  ('IMF', 'noun'): 'IMF',
#  ('pizza', 'noun'): 'pizza',
#  ('perfect', 'adj'): 'perfect',
#  ('mea culpa',
#   'intj'): "mea culpa (interjection acknowledging one's own fault)",
#  ('mea culpa', 'noun'): 'mea culpa (instance of "mea culpa"; an apology)',
#  ('hadj', 'noun'): 'hajj',
#  ('piñata', 'noun'): 'piñata (decorated container filled with candy)',
#  ('gans',
#   'noun'): 'a goose, a waterfowl of the family Anatidae, especially of the subfamily Anserinae excepting the genera Cygnus and Coscoroba; in non-scientific usage the term may be applied to larger waterfowl of the Anatidae who do not belong to the Anserinae',
#  ('gans', 'det'): 'whole, entire',
#  ('gans', 'adv'): 'entirely',
#  ('heel', 'adv'): 'very',
#  ('boulevard', 'noun'): 'boulevard',
#  ('Zulu', 'noun'): 'police helicopter',
#  ('zoom', 'noun'): 'zoom (augmentation of a view)',
#  ('Turk', 'noun'): 'a Turkish person, a Turk',
#  ('deem', 'noun'): 'dumb person',
#  ('ia', 'intj'): 'hee-haw',
#  ('dia', 'noun'): 'slide',
#  ('kali', 'noun'): 'river',
#  ('nada', 'pron'): 'nothing',
#  ('transgender', 'adj'): 'transgender',
#  ('transgender', 'noun'): 'a transgender person',
#  ('boke', 'noun'): 'diminutive of bo',
#  ('dada', 'noun'): 'dada, the cultural movement',
#  ('dada', 'intj'): 'bye-bye',
#  ('dada', 'adv'): 'away',
#  ('dodo', 'noun'): 'sleep, nighty night',
#  ('wilde', 'verb'): 'singular past indicative/subjunctive of willen',
#  ('wilde', 'noun'): 'alternative form of weelde',
#  ('wilde', 'contraction'): 'contraction of wilt gij',
#  ('rail', 'noun'): 'rail',
#  ('down', 'adj'): 'down, depressed',
#  ('mama', 'noun'): 'mama, mother',
#  ('palm', 'noun'): 'a palm, the flat (middle part of the hand)',
#  ('ad libitum', 'adv'): "ad libitum, at one's pleasure, impromptu",
#  ('adherent', 'adj'): 'adherent',
#  ('pin',
#   'noun'): "PIN (A number used to confirm an individual's identity, e.g. when using an ATM or a mobile phone, or when making payment using a credit card or debit card)",
#  ('race', 'noun'): 'a speed contest, a race',
#  ('darmstadtium', 'noun'): 'darmstadtium',
#  ('arts', 'noun'): 'physician, doctor',
#  ('daar', 'conj'): 'since (preceding a reason why something is like it is)',
#  ('er', 'adv'): 'of them, of those (often not translated in English)',
#  ('facet', 'noun'): 'facet',
#  ('advocate', 'noun'): 'female equivalent of advocaat (“lawyer”)',
#  ('were', 'verb'): 'singular present subjunctive of weren',
#  ('bore', 'verb'): 'singular present subjunctive of boren',
#  ('born', 'noun'): 'obsolete form of bron',
#  ('bent', 'verb'): 'second-person singular present indicative of zijn; are',
#  ('bet', 'adv'): 'better',
#  ('bitten', 'noun'): 'plural of bit',
#  ('bled', 'noun'): 'middle of nowhere',
#  ('dove', 'noun'): 'a deaf person',
#  ('dove', 'verb'): 'singular present subjunctive of doven',
#  ('fed', 'noun'): 'abbreviation of federatie',
#  ('fit', 'adj'): 'fit (in good shape)',
#  ('dart', 'noun'): 'dart',
#  ('gave', 'verb'): 'singular past subjunctive of geven',
#  ('held', 'noun'): 'hero',
#  ('go', 'noun'): 'go, an approval or permission to do something',
#  ('grind', 'noun'): 'the diseases scabies (human), mange (canine)',
#  ('have', 'noun'): 'property, possession',
#  ('had', 'verb'): 'singular past indicative of hebben',
#  ('heldin', 'noun'): 'heroine',
#  ('input', 'noun'): 'input (data fed into a process)',
#  ('keep', 'noun'): 'synonym of keeper',
#  ('continent', 'noun'): 'continent (landmass)',
#  ('gerund', 'verb'): 'past participle of runnen',
#  ('lied', 'noun'): 'song',
#  ('natter', 'adj'): 'comparative degree of nat',
#  ('lost', 'adj'): 'superlative degree of los',
#  ('make', 'verb'): 'singular present subjunctive of maken',
#  ('made', 'noun'): 'agricultural meadow used for hay, hayland',
#  ('meet', 'noun'): 'the finish line in a competition',
#  ('met', 'noun'): 'mince (sometimes specifically uncooked)',
#  ('machine', 'noun'): 'machine (mechanical or electrical device)',
#  ('mal', 'noun'): 'mold, cast (device to help creating shapes)',
#  ('mal', 'adj'): 'foolish, crazy, lacking common sense',
#  ('sic', 'adv'): 'sic (thus)',
#  ('rake', 'verb'): 'singular present subjunctive of raken',
#  ('tractor', 'noun'): 'tractor (agricultural vehicle)',
#  ('actor',
#   'noun'): 'actor; agent, player (who has a part in some field of economical, social or other action, i.e., an active human factor)',
#  ('shirt',
#   'noun'): 'a T-shirt or other shirt, typically including undershirts',
#  ('spelling', 'noun'): 'spelling',
#  ('spelt', 'noun'): 'spelt (grain)',
#  ('bug', 'noun'): 'a bug (a software problem)',
#  ('brief', 'noun'): 'letter (written message)',
#  ('boot', 'noun'): 'boat',
#  ('belief', 'verb'): 'imperative of believen',
#  ('camera', 'noun'): 'camera',
#  ('business',
#   'noun'): 'business (commercial activity or specific commercial enterprise)',
#  ('attend', 'verb'): 'present participle of atten',
#  ('basket', 'noun'): 'basket (the goal in basketball)',
#  ('bridge', 'noun'): 'bridge (card game)',
#  ('curve', 'noun'): 'curve: curved line',
#  ('cell', 'noun'): 'cellular phone, mobile phone',
#  ('overate', 'verb'): 'singular past subjunctive of overeten',
#  ('sleep', 'verb'): 'singular past indicative of slijpen',
#  ('proven', 'noun'): 'plural of prove',
#  ('remake', 'noun'): 'remake (of a film)',
#  ('rang', 'noun'): 'rank',
#  ('parasol', 'noun'): 'parasol',
#  ('ambivalent',
#   'adj'): 'ambivalent (simultaneously experiencing conflicting drives)',
#  ('bourgeois', 'noun'): 'bourgeois',
#  ('charlatan', 'noun'): 'charlatan',
#  ('dupe', 'noun'): 'victim',
#  ('interest', 'noun'): 'interest',
#  ('show', 'noun'): 'a show (entertainment)',
#  ('spoke', 'verb'): 'singular present subjunctive of spoken',
#  ('smelt', 'noun'): 'a quantity of molten material',
#  ('spoken', 'noun'): 'plural of spook',
#  ('speed', 'noun'): 'amphetamines',
#  ('spin', 'noun'): 'political spin, media spin',
#  ('spit', 'noun'): 'a skewer',
#  ('spat', 'noun'): 'spot, speckle, stain',
#  ('stank', 'noun'): 'stench',
#  ('impact', 'noun'): 'impact',
#  ('taken', 'noun'): 'plural of taak',
#  ('wake', 'noun'): 'a wake (a gathering to remember a dead person)',
#  ('wake', 'verb'): 'singular present subjunctive of waken',
#  ('woke',
#   'adj'): 'woke; holding left-wing views or attitudes, (especially) with regards to social justice issues to an excessive degree',
#  ('won', 'verb'): 'singular past indicative of winnen',
#  ('wind', 'noun'): 'greyhound',
#  ('limo', 'noun'): 'clipping of limonade',
#  ('concern', 'noun'): 'company, business, concern',
#  ('bi', 'adj'): 'bisexual',
#  ('bib', 'noun'): 'library',
#  ('crush',
#   'noun'): 'crush (infatuation with somebody one is not dating; object of this infatuation)',
#  ('bitter',
#   'noun'): 'bitters, a type of strong spirits made by steeping (often bitter) herbs in brandy or jenever, traditionally considered a digestive drink',
#  ('by', 'prep'): 'obsolete spelling of bij',
#  ('by', 'adv'): 'obsolete spelling of bij',
#  ('by', 'adj'): 'obsolete spelling of bij',
#  ('by', 'noun'): 'obsolete spelling of bij',
#  ('cement', 'noun'): 'cement (powder, paste)',
#  ('cake', 'noun'): 'pound cake',
#  ('base', 'noun'): 'base (class of compounds), alkali',
#  ('bitters', 'noun'): 'plural of bitter',
#  ('stork', 'noun'): 'synonym of ooievaar (“Ciconia ciconia”)',
#  ('relaxed', 'adj'): 'relaxed, chill, nice',
#  ('microbe', 'noun'): 'microbe',
#  ('vendel', 'noun'): 'company',
#  ('venen', 'verb'): 'to extract peat',
#  ('venen', 'noun'): 'plural of veen',
#  ('ven', 'noun'): 'mere, a small shallow lake or pond',
#  ('Russisch', 'adj'): 'Russian, referring to Russia',
#  ('Russisch', 'noun'): 'Russian, language of Russia',
#  ('lake', 'verb'): 'singular present subjunctive of laken',
#  ('door', 'noun'): 'fool, moron',
#  ('end', 'noun'): 'alternative form of eind',
#  ('piano', 'noun'): 'piano',
#  ('octopus', 'noun'): 'octopus',
#  ('penis', 'noun'): 'penis',
#  ('wisent', 'noun'): 'wisent',
#  ('hare', 'pron'): 'non-attributive form of haar; hers',
#  ('lynx',
#   'noun'): 'lynx, felid of the genus Lynx, in particular the Eurasian lynx (Lynx lynx); sometimes used of other medium-sized felids with large, plumed ears',
#  ('marmot', 'noun'): 'marmot, rodent of the genus Marmota',
#  ('modem', 'noun'): 'modem',
#  ('krot', 'noun'): 'derelict or rudimentary house, shanty',
#  ('biet',
#   'noun'): 'beet, beetroot plant or tuber of the genus Beta, esp. Beta vulgaris',
#  ('bil',
#   'noun'): 'a hammer-like double-edged tool used by stonecutters and millers',
#  ('Rom', 'noun'): 'Rom (member of the Roma people), Romani',
#  ('rood', 'noun'): 'the colour red',
#  ('du', 'pron'): 'Second-person singular informal pronoun; thou',
#  ('list', 'noun'): 'a cunning plan, a ruse, a trick',
#  ('long', 'noun'): 'lung',
#  ('high', 'adj'): 'high (intoxicated with a drug other than alcohol)',
#  ('living', 'noun'): 'living room',
#  ('house', 'noun'): 'house music, house (a genre of music)',
#  ('doctor', 'noun'): 'doctor (person who has attained a doctorate)',
#  ('metal', 'noun'): 'metal (rock genre)',
#  ('blade', 'noun'): 'a running blade (prosthetic limb used for running)',
#  ('none',
#   'noun'): 'an interval of 13 (kleine none) or 14 (grote none) halftones',
#  ('wow', 'intj'): 'wow (exclaims surprise or amazement)',
#  ('rotten', 'verb'): 'to rot, to go bad, to decay',
#  ('rotten', 'noun'): 'plural of rot',
#  ('correct', 'adj'): 'correct',
#  ('meter', 'noun'): 'godmother',
#  ('pos', 'noun'): 'ruffe (Gymnocephalus cernua)',
#  ('augment', 'noun'): 'augment (prefix before a past-tense verb)',
#  ('monarch', 'noun'): 'monarch',
#  ('communist', 'noun'): 'communist',
#  ('katana', 'noun'): 'a katana',
#  ('san', 'noun'): 'san (archaic Greek letter)',
#  ('bo', 'noun'): 'sandwich',
#  ('display', 'noun'): 'display (screen)',
#  ('g', 'noun'): 'abbreviation of gram',
#  ('k', 'pron'): "nonstandard form of 'k",
#  ('l', 'noun'): 'Short for lul or any other word starting with an l.',
#  ('m', 'pron'): "nonstandard form of 'm",
#  ('t', 'pron'): "nonstandard form of 't",
#  ('kudde',
#   'noun'): 'herd; collective noun for cows, (koeien), horses (paarden), elephants (olifanten) or camels (kamelen)',
#  ('meute', 'noun'): 'pack, rout, crowd',
#  ('nut', 'adj'): 'useful',
#  ('cylinder', 'noun'): 'superseded spelling of cilinder',
#  ('carburator', 'noun'): 'carburetor, carburettor',
#  ('mare', 'noun'): 'depression in non-volcanic stone, compare maar',
#  ('mare', 'verb'): 'singular present subjunctive of maren',
#  ('prefix', 'noun'): 'prefix',
#  ('prefix', 'adj'): 'fixed, predetermined',
#  ('gram', 'noun'): 'wrath',
#  ('gram', 'adj'): 'angry, irate',
#  ('unbinilium', 'noun'): 'unbinilium',
#  ('integer', 'adj'): 'honest, trustworthy, having integrity',
#  ('persen', 'verb'): 'to press tight, to squeeze',
#  ('persen', 'noun'): 'plural of pers',
#  ('meer', 'det'): 'comparative degree of veel; more',
#  ('meer', 'adv'): 'anymore, any longer',
#  ('peer', 'noun'): 'a pear tree, Pyrus communis',
#  ('pet', 'noun'): 'cap (headwear with a peak at the front)',
#  ('pet', 'adj'): 'bad, crappy',
#  ('content', 'adj'): 'content(ed), satisfied',
#  ('content', 'noun'): 'the content of a medium',
#  ('manga', 'noun'): 'manga',
#  ('CEO', 'noun'): 'CEO; chief executive officer',
#  ('party', 'noun'): 'party',
#  ('kin', 'noun'): 'chin',
#  ('thermometer', 'noun'): 'thermometer',
#  ('band', 'noun'): 'band',
#  ('proton', 'noun'): 'proton',
#  ('neutron', 'noun'): 'neutron',
#  ('weer', 'noun'): 'man',
#  ('weer', 'conj'): 'whether',
#  ('hoop', 'noun'): 'a hope, aspiration, wish',
#  ('pub', 'noun'): 'pub (public house, especially one in the UK or Ireland)',
#  ('halm', 'noun'): 'haulm, stalk, stem of grasses (including grain and reed)',
#  ('etcetera', 'adv'): 'et cetera, and so on',
#  ('teek', 'noun'): 'tick (insect)',
#  ('teken', 'noun'): 'plural of teek',
#  ('zien', 'verb'): 'to see',
#  ('mop', 'noun'): 'a mop (an implement for washing floors, etc.)',
#  ('mark', 'noun'): 'a march, a mark (border region)',
#  ('community',
#   'noun'): 'community, particularly a virtual community or a group of people sharing common interests',
#  ('sake', 'noun'): 'sake (Japanese rice wine)',
#  ('wal', 'noun'): 'whale',
#  ('want', 'conj'): 'for, because, as',
#  ('want',
#   'noun'): 'a mitten, type of glove in which four fingers get only one section, besides the thumb',
#  ('start', 'noun'): 'start',
#  ('lekker', 'adj'): 'comparative degree of lek',
#  ('lekker', 'noun'): 'leaker',
#  ('sofa', 'noun'): 'a couch, a sofa',
#  ('gender', 'noun'): 'gender (mental analog of sex)',
#  ('masker', 'noun'): 'mask',
#  ('massage', 'noun'): 'physical massage',
#  ('masseur', 'noun'): 'masseur',
#  ('masseuse', 'noun'): 'masseuse',
#  ('slapen', 'verb'): 'to sleep',
#  ('slapen', 'noun'): 'plural of slaap',
#  ('hart', 'noun'): 'archaic form of hert (“deer”)',
#  ('hara-kiri', 'noun'): 'archaic spelling of harakiri',
#  ('non-', 'prefix'): 'non-',
#  ('arrogant', 'adj'): 'arrogant',
#  ('hun', 'det'): 'their; third-person plural possessive determiner',
#  ('hun',
#   'pron'): 'The nominative case of the third-person plural personal pronoun: they (only referring to people)',
#  ('landen', 'noun'): 'plural of land',
#  ('Brussels', 'adj'): 'of, from or pertaining to Brussels',
#  ('peen', 'noun'): 'carrot (Daucus carota)',
#  ('lui', 'adj'): 'lazy',
#  ('lui', 'noun'): 'alternative form of lieden',
#  ('luier', 'noun'): 'diaper, nappy',
#  ('luier', 'adj'): 'comparative degree of lui',
#  ('lies', 'noun'): 'the groin, between the pubis and the thighs',
#  ('wier', 'noun'): 'seaweed',
#  ('mond', 'noun'): 'hand',
#  ('alert', 'adj'): 'alert',
#  ('aa', 'noun'): 'alternative spelling of a',
#  ('wee', 'adj'): 'nauseating',
#  ('brat', 'noun'): 'alternative form of brat',
#  ('penalty', 'noun'): 'penalty kick',
#  ('Vietnamese', 'noun'): 'woman from Vietnam',
#  ('game', 'noun'): 'a video game, an electronic game',
#  ('precedent', 'noun'): 'precedent',
#  ('context', 'noun'): 'context',
#  ('putter', 'noun'): 'a putter, a golf club used to putt',
#  ('garden', 'noun'): 'plural of garde',
#  ('snuffelvliegtuig', 'noun'): 'sniffer plane',
#  ('paper',
#   'noun'): 'paper (short essay or research document), particularly a research paper',
#  ('file',
#   'noun'): 'file (an aggregation of data on a storage device identified by a name)',
#  ('image', 'noun'): 'image (characteristic perceived by others)',
#  ('help', 'intj'): 'help!',
#  ('memory',
#   'noun'): 'pelmanism; a memory card game in which a pack of cards is spread out face-down and players try to turn up pairs with the same symbol.',
#  ('eng', 'noun'): 'alternative form of enk',
#  ('las', 'noun'): 'joint, weld',
#  ('PS', 'noun'): 'initialism of post scriptum',
#  ('ruin', 'noun'): 'gelding (castrated male horse)',
#  ('damp', 'noun'): 'vapour (UK), vapor (US)',
#  ('dampen', 'noun'): 'plural of damp',
#  ('host', 'noun'): 'host',
#  ('sense', 'noun'): 'only used in sense maken',
#  ('uh', 'intj'): 'er, uh',
#  ('oh', 'intj'): 'oh',
#  ('ah', 'intj'): 'ah (expressing understanding or surprise)',
#  ('ha', 'intj'): 'ha',
#  ('kick', 'noun'): 'kick, thrill (something that excites or gives pleasure)',
#  ('fier', 'adj'): 'proud',
#  ('bij', 'adj'): 'caught up, not lagging behind',
#  ('bij', 'noun'): 'bee, insect of the clade Anthophila',
#  ('blut', 'adj'): 'without money, broke, bankrupt',
#  ('ham', 'noun'): 'ham (cured pork from the thigh of a swine)',
#  ('vond', 'noun'): 'synonym of vondst (“a find; the act of finding”)',
#  ('vond', 'verb'): 'singular past indicative of vinden',
#  ('jaguar', 'noun'): 'jaguar',
#  ('onze', 'pron'): 'non-attributive form of ons; ours',
#  ('ledig', 'adj'): 'alternative form of leeg',
#  ('rot', 'noun'): 'alternative form of rat',
#  ('EEG', 'noun'): 'rare spelling of eeg',
#  ('elf', 'noun'): 'the number eleven, or a representation thereof',
#  ('kimono', 'noun'): 'kimono',
#  ('duo', 'noun'): 'twosome',
#  ('legend', 'verb'): 'present participle of legen',
#  ('mot', 'noun'): 'light rain; drizzle',
#  ('miljoen', 'noun'): 'a million, 10⁶',
#  ('muziek', 'noun'): 'music (sound; art)',
#  ('honing', 'noun'): 'honey',
#  ('coke', 'noun'): 'synonym of cocaïne',
#  ('download', 'noun'): 'download',
#  ('giraffe', 'noun'): 'alternative spelling of giraf',
#  ('test', 'noun'): 'test',
#  ('digamma', 'noun'): 'digamma (archaic Greek letter)',
#  ('huh', 'intj'): 'huh (an exclamation indicating puzzlement)',
#  ('stud', 'noun'): 'colloquial (in the Netherlands) abbreviation of student',
#  ('munt', 'noun'): 'mint (colour)',
#  ('mint', 'noun'): 'mint (colour)',
#  ('mint', 'adj'): 'mint (colour)',
#  ('rook', 'noun'): 'smoke',
#  ('transferium',
#   'noun'): 'a place on the outskirts of a city where people can park their car and travel into the city using public transport',
#  ('kilometer', 'noun'): 'kilometre',
#  ('decameter', 'noun'): 'a decametre, 10 metres',
#  ('dino',
#   'noun'): 'a dino, a dinosaur; archosaur of the super-order Dinosauria',
#  ('HBO', 'noun'): 'acronym of hoger beroepsonderwijs',
#  ('okapi', 'noun'): 'okapi',
#  ('helium', 'noun'): 'helium',
#  ('orthodontist', 'noun'): 'orthodontist',
#  ('seconde', 'noun'): 'second (a unit of time)',
#  ('carbon', 'noun'): 'carbon paper',
#  ('asterisk', 'noun'): 'asterisk',
#  ('kappa', 'noun'): 'kappa (letter of the Greek alphabet)',
#  ('respect', 'noun'): 'respect',
#  ('osso', 'noun'): 'house',
#  ('lambda', 'noun'): 'lambda (letter of the Greek alphabet)',
#  ('mu', 'noun'): 'mu (letter of the Greek alphabet)',
#  ('gift', 'noun'): 'poison',
#  ('gift', 'adj'): 'poisonous, toxic, venomous',
#  ('decimeter', 'noun'): 'decimetre: one tenth of a metre',
#  ('millimeter', 'noun'): 'millimetre',
#  ('hectometer', 'noun'): 'a hectometre (100 m)',
#  ('petroleum', 'noun'): 'petroleum',
#  ('nerven', 'noun'): 'plural of nerf',
#  ('kilo', 'noun'): 'abbreviation of kilogram',
#  ('dam', 'noun'): 'king (double draught/checker)',
#  ('hm', 'intj'): 'hmm (expressing hesitation)',
#  ('xi', 'noun'): 'xi (letter of the Greek alphabet)',
#  ('dal', 'noun'): 'a type of stone to pave the floor with, flagstone',
#  ('premier', 'noun'): 'prime minister',
#  ('nucleus', 'noun'): 'nucleus, core',
#  ('decibel', 'noun'): 'decibel',
#  ('wok', 'noun'): 'wok (large cooking pan, typical of East-Asian cuisine)',
#  ('echo', 'noun'): 'ultrasound scan',
#  ('sonar', 'noun'): 'sonar',
#  ('milligram', 'noun'): 'milligramme, milligram (0.001 gramme)',
#  ('milliliter', 'noun'): 'milliliter, millilitre (0.001 litre)',
#  ('lithium', 'noun'): 'lithium',
#  ('beryllium', 'noun'): 'beryllium',
#  ('neon', 'noun'): 'neon',
#  ('magnesium', 'noun'): 'magnesium',
#  ('aluminium', 'noun'): 'aluminium',
#  ('chlorine', 'noun'): 'chlorine',
#  ('argon', 'noun'): 'argon',
#  ('calcium', 'noun'): 'calcium',
#  ('scandium', 'noun'): 'scandium (chemical element)',
#  ('titanium', 'noun'): 'titanium',
#  ('vanadium', 'noun'): 'vanadium (chemical element)',
#  ('gallium', 'noun'): 'gallium (chemical element with atomic number 31)',
#  ('germanium', 'noun'): 'germanium (chemical element)',
#  ('selenium', 'noun'): 'selenium',
#  ('krypton', 'noun'): 'krypton',
#  ('rubidium', 'noun'): 'rubidium (chemical element)',
#  ('strontium', 'noun'): 'strontium (chemical element)',
#  ('yttrium', 'noun'): 'yttrium',
#  ('niobium', 'noun'): 'niobium (chemical element)',
#  ('technetium', 'noun'): 'technetium',
#  ('ruthenium', 'noun'): 'ruthenium',
#  ('rhodium', 'noun'): 'rhodium',
#  ('palladium',
#   'noun'): 'palladium, safeguard (something that guarantees protection)',
#  ('cadmium', 'noun'): 'cadmium',
#  ('indium', 'noun'): 'indium',
#  ('tellurium', 'noun'): 'tellurium',
#  ('xenon', 'noun'): 'xenon',
#  ('barium', 'noun'): 'barium',
#  ('cerium', 'noun'): 'cerium',
#  ('praseodymium', 'noun'): 'praseodymium',
#  ('neodymium', 'noun'): 'neodymium',
#  ('promethium', 'noun'): 'promethium',
#  ('samarium', 'noun'): 'samarium',
#  ('europium', 'noun'): 'europium',
#  ('gadolinium', 'noun'): 'gadolinium',
#  ('terbium', 'noun'): 'terbium',
#  ('dysprosium', 'noun'): 'dysprosium',
#  ('holmium', 'noun'): 'holmium',
#  ('erbium', 'noun'): 'erbium',
#  ('thulium', 'noun'): 'thulium',
#  ('ytterbium', 'noun'): 'ytterbium',
#  ('lutetium', 'noun'): 'lutetium',
#  ('hafnium', 'noun'): 'hafnium',
#  ('osmium', 'noun'): 'osmium',
#  ('iridium', 'noun'): 'iridium',
#  ('thallium', 'noun'): 'thallium',
#  ('polonium', 'noun'): 'polonium',
#  ('radon', 'noun'): 'radon',
#  ('francium', 'noun'): 'francium',
#  ('radium', 'noun'): 'radium',
#  ('actinium', 'noun'): 'actinium',
#  ('thorium', 'noun'): 'thorium',
#  ('protactinium', 'noun'): 'protactinium',
#  ('uranium', 'noun'): 'uranium',
#  ('neptunium', 'noun'): 'neptunium',
#  ('plutonium', 'noun'): 'plutonium',
#  ('americium', 'noun'): 'americium',
#  ('curium', 'noun'): 'curium',
#  ('berkelium', 'noun'): 'berkelium',
#  ('californium', 'noun'): 'californium',
#  ('einsteinium', 'noun'): 'einsteinium',
#  ('fermium', 'noun'): 'fermium',
#  ('mendelevium', 'noun'): 'mendelevium',
#  ('nobelium', 'noun'): 'nobelium',
#  ('lawrencium', 'noun'): 'lawrencium',
#  ('rutherfordium', 'noun'): 'rutherfordium',
#  ('dubnium', 'noun'): 'dubnium',
#  ('seaborgium', 'noun'): 'seaborgium',
#  ('bohrium', 'noun'): 'bohrium',
#  ('hassium', 'noun'): 'hassium',
#  ('meitnerium', 'noun'): 'meitnerium',
#  ('roentgenium', 'noun'): 'roentgenium',
#  ('ununtrium', 'noun'): 'ununtrium',
#  ('ununquadium', 'noun'): 'ununquadium',
#  ('ununpentium', 'noun'): 'ununpentium',
#  ('ununhexium', 'noun'): 'ununhexium',
#  ('ununseptium', 'noun'): 'ununseptium',
#  ('ununoctium', 'noun'): 'ununoctium',
#  ('ununennium', 'noun'): 'ununennium',
#  ('cesium', 'noun'): 'caesium, cesium',
#  ('li', 'noun'): 'li (Chinese unit of distance)',
#  ('ne', 'article'): 'a, an',
#  ('school', 'noun'): 'a school, group of fish or other aquatic animals',
#  ('sex', 'noun'): 'alternative spelling of seks',
#  ('buggy', 'adj'): 'Buggy, containing programming errors',
#  ('au', 'intj'): 'ouch!',
#  ('links', 'noun'): 'plural of link',
#  ('na', 'adj'): 'close',
#  ('na', 'prep'): 'archaic form of naar',
#  ('si', 'noun'): 'musical note; ti',
#  ('ar', 'noun'): 'sledge',
#  ('ge', 'pron'): 'unstressed form of gij (“you”)',
#  ('pot', 'noun'): 'dyke (lesbian)',
#  ('deuterium', 'noun'): 'deuterium',
#  ('samoerai', 'noun'): 'samurai',
#  ('croissant', 'noun'): 'croissant',
#  ('NW', 'noun'): 'initialism of noordwest; northwest',
#  ('vat', 'noun'): 'grip, both literal and figurative',
#  ('pint',
#   'noun'): 'a glass of beer (usually 25 cl or 33cl, not an imperial pint)',
#  ('la', 'noun'): 'la (music)',
#  ('po', 'noun'): 'chamber pot',
#  ('ra', 'noun'): "spar (horizontal beam or pole of a ship's mastwork)",
#  ('pa', 'noun'): 'pa, dad',
#  ('es',
#   'noun'): 'a tract of open, often raised agricultural land near or surrounding a village or hamlet',
#  ('es', 'adv'): 'alternative form of eens (“once”)',
#  ('foetus', 'noun'): 'fetus',
#  ('decigram', 'noun'): 'decigramme, decigram (0.1 gramme)',
#  ('centigram', 'noun'): 'centigramme, centigram',
#  ('tri', 'noun'): 'synonym for trichloorethyleen, a chemical solvent',
#  ('wan', 'noun'): 'winnowing basket',
#  ('twee', 'noun'): 'two',
#  ('vier', 'noun'): 'dialectal form of vuur (“fire”)',
#  ('zeven', 'verb'): 'to sift, sieve, strain',
#  ('zeven', 'noun'): 'plural of zeef',
#  ('acht', 'noun'): 'banishment, ostracism',
#  ('info', 'noun'): 'info, information',
#  ('informatie', 'noun'): 'information',
#  ('decagram', 'noun'): 'decagramme, decagram (10 gramme)',
#  ('mus',
#   'noun'): 'sparrow, bird of the family Passeridae, especially of the genus Passer and a few smaller genera',
#  ('gut', 'intj'): 'gee',
#  ('rho', 'noun'): 'rho (letter of the Greek alphabet)',
#  ('milkshake', 'noun'): 'milkshake',
#  ('zebrapad',
#   'noun'): 'a zebra crossing, a crosswalk (place where pedestrians can cross a street)',
#  ('pik', 'noun'): 'pick, pickaxe',
#  ('spade', 'noun'): 'spade',
#  ('spade', 'adj'): 'late',
#  ('lexicon', 'noun'): 'lexicon',
#  ('tool', 'noun'): 'a tool, aid, instrument, auxiliary device',
#  ('omega', 'noun'): 'omega (Greek letter)',
#  ('lief',
#   'noun'): "one's beloved in a romantic relationship, i.e. a boyfriend or girlfriend",
#  ('der', 'adv'): 'there',
#  ('das', 'contraction'): "nonstandard form of da's",
#  ('hallo', 'intj'): 'hello (a general greeting used when meeting somebody)',
#  ('shop', 'noun'): 'shop',
#  ('onus', 'noun'): 'burden',
#  ('intelligent', 'adj'): 'intelligent, bright, smart',
#  ('online',
#   'adv'): 'online (on, via or connected to the Internet or another network)',
#  ('online',
#   'adj'): 'online (on, via, connected or related to the Internet or another network)',
#  ('dok', 'noun'): 'dock',
#  ('spectrum', 'noun'): 'spectrum',
#  ('manifest', 'noun'): 'manifest',
#  ('manifest', 'adj'): 'manifest; obvious, undeniable',
#  ('echt', 'adj'): 'authentic, true, genuine, real',
#  ('echt', 'adv'): 'really',
#  ('echt', 'noun'): 'the institution or bond of marriage; matrimony',
#  ('fork',
#   'noun'): 'a fork, splitting-up of an existing process into itself and a child process executing parts of the same program',
#  ('restaurant', 'noun'): 'restaurant',
#  ('kerosine', 'noun'): 'kerosene',
#  ('lava', 'noun'): 'lava',
#  ('thanks', 'intj'): 'thanks',
#  ('halal', 'adj'): 'allowed, in keeping with Islamic principles',
#  ('halal', 'adv'): 'done in keeping with Islamic principles',
#  ('gras', 'noun'): 'grass',
#  ('pop', 'noun'): 'pop, pop music',
#  ('must', 'noun'): 'a must (necessity, prerequisite)',
#  ('sacrament', 'noun'): 'sacrament',
#  ('protestant',
#   'noun'): 'Protestant (a modern Christian denomination not belonging to the Catholic or Orthodox traditions)',
#  ('rock', 'noun'): 'rock (style of music)',
#  ('cash', 'noun'): 'cash',
#  ('cash', 'adj'): 'in coins and bills/notes',
#  ('psycho-', 'prefix'): 'psycho-',
#  ('lunch', 'noun'): 'a lunch, a meal eaten around noon',
#  ('ei', 'noun'): 'egg',
#  ('kennel', 'noun'): 'kennel',
#  ('maximum', 'noun'): 'maximum',
#  ('minimum', 'noun'): 'minimum',
#  ('mini', 'adj'): 'mini (tiny)',
#  ('mega', 'adj'): 'mega (huge)',
#  ('-um',
#   'suffix'): 'denotes singular grammatical number of words of Latin origins',
#  ('marathon', 'noun'): 'marathon',
#  ('navel', 'noun'): 'navel',
#  ('sloop', 'noun'): 'demolition',
#  ('mast',
#   'noun'): 'mast, fodder for pigs or other animals made up of acorns and beechnuts',
#  ('vegan', 'adj'): 'vegan',
#  ('vegan', 'noun'): 'vegan',
#  ('visa', 'noun'): 'plural of visum',
#  ('smegma', 'noun'): 'smegma',
#  ('jambe', 'noun'): 'iamb',
#  ('harp', 'noun'): 'harp',
#  ('splinter', 'noun'): 'splinter (long, sharp fragment of material)',
#  ('protagonist', 'noun'): 'protagonist, main character',
#  ('privacy', 'noun'): 'privacy',
#  ('ons', 'det'): 'our; first-person plural possessive determiner',
#  ('ons', 'noun'): 'metric ounce (100 grams)',
#  ('bang',
#   'noun'): 'a sharp, percussive sound, like the sound of an explosion or gun; bang',
#  ('mate', 'noun'): 'alternative spelling of maté',
#  ('mate', 'verb'): 'singular past subjunctive of meten',
#  ('belt', 'noun'): '(clothing) A belt',
#  ('equidistant', 'adj'): 'equidistant',
#  ('transcendent', 'adj'): 'transcendental, not algebraic',
#  ('algebra', 'noun'): 'algebra',
#  ('mail', 'noun'): 'alternative form of e-mail',
#  ('bagel', 'noun'): 'bagel (ring-shaped pastry)',
#  ('torus', 'noun'): 'torus',
#  ('parachute', 'noun'): 'parachute',
#  ('acetyleen', 'noun'): 'acetylene',
#  ('punch', 'noun'): 'punch (beverage)',
#  ('fruitcake', 'noun'): 'a fruitcake, cake flavored with fruit',
#  ('neige', 'verb'): 'singular present subjunctive of neigen',
#  ('whiteboard', 'noun'): 'whiteboard',
#  ('matrix', 'noun'): 'matrix (type of array)',
#  ('vector', 'noun'): 'vector, an element of a vector space',
#  ('scalar', 'noun'): 'scalar (quantity with only magnitude)',
#  ('plastic', 'noun'): 'plastic (specific type of synthetic polymer)',
#  ('plastic', 'adj'): 'plastic',
#  ('bar', 'adv'): 'extremely (only in a negative sense)',
#  ('bar', 'noun'): 'bar (a unit of pressure, equal to 100,000 pascals)',
#  ('sail', 'noun'): 'the fin or sail of a submarine',
#  ('union', 'noun'): 'a trade union',
#  ('zoo', 'noun'): 'zoo',
#  ('zoo', 'adv'): 'archaic spelling of zo',
#  ('stressor', 'noun'): 'stressor',
#  ('nice', 'adj'): 'nice',
#  ('lagen', 'noun'): 'plural of laag',
#  ('legen', 'verb'): 'to empty',
#  ('feta', 'noun'): 'feta',
#  ('pat',
#   'noun'): 'the slot in the frame that accepts the axle of the wheel; dropout',
#  ('tap', 'noun'): 'tap',
#  ('koper', 'noun'): 'buyer',
#  ('alchemist', 'noun'): 'alchemist',
#  ('believe', 'verb'): 'singular present subjunctive of believen',
#  ('popcorn', 'noun'): 'popcorn',
#  ('sandwich', 'noun'): 'sandwich',
#  ('sigma', 'noun'): 'sigma (letter of the Greek alphabet)',
#  ('tau', 'noun'): 'tau (Greek letter)',
#  ('upsilon', 'noun'): 'superseded spelling of ypsilon',
#  ('phi', 'noun'): 'phi (letter of the Greek alphabet)',
#  ('chi', 'noun'): 'chi (letter of the Greek alphabet)',
#  ('psi', 'noun'): 'psi (letter of the Greek alphabet)',
#  ('nihil', 'pron'): 'nothing',
#  ('vent', 'noun'): 'chap, fellow',
#  ('fan', 'noun'): 'fan (admirer)',
#  ('terp',
#   'noun'): 'artificial mound or hillock used as shelter during high tide',
#  ('dharma',
#   'noun'): "dharma (order of the universe, society, etc.; one's social or religious duty in Hinduism; teachings of the Buddha)",
#  ('hip-hop', 'noun'): 'alternative form of hiphop',
#  ('serpent', 'noun'): 'serpent (wind instrument)',
#  ('nucleon', 'noun'): 'nucleon',
#  ('botanist', 'noun'): 'botanist',
#  ('pianist', 'noun'): 'pianist',
#  ('hockey', 'noun'): 'hockey, almost always field hockey',
#  ('Nepalese', 'noun'): 'Nepali (female from Nepal)',
#  ('Telugu',
#   'noun'): 'a Telugu; a member of the people who speak the Telugu language',
#  ('hamburger', 'noun'): 'hamburger',
#  ('affect', 'noun'): 'affect',
#  ('enkel', 'adv'): 'exclusively, only, solely',
#  ('enkel', 'noun'): 'ankle',
#  ('candela', 'noun'): 'candela',
#  ('ampère', 'noun'): 'ampere',
#  ('kilogram', 'noun'): 'kilogram',
#  ('coulomb', 'noun'): 'coulomb (unit of electric charge)',
#  ('farad', 'noun'): 'farad',
#  ('joule', 'noun'): 'joule',
#  ('ohm', 'noun'): 'ohm',
#  ('siemens', 'noun'): 'siemens (unit of electrical conductance)',
#  ('score', 'noun'): 'score (number of points earned)',
#  ('Liechtensteiner',
#   'noun'): 'Liechtensteiner (a person from Liechtenstein or of Liechtenstein descent)',
#  ('pauper', 'noun'): 'a pauper',
#  ('volt', 'noun'): 'volt (unit)',
#  ('watt', 'noun'): 'watt',
#  ('drone', 'noun'): 'drone (unmanned aircraft)',
#  ('kim', 'noun'): 'horizon',
#  ('atto-', 'prefix'): 'atto-',
#  ('centi-', 'prefix'): 'centi-',
#  ('deca-', 'prefix'): 'deca-',
#  ('deci-', 'prefix'): 'deci-',
#  ('exa-', 'prefix'): 'exa-',
#  ('giga-', 'prefix'): 'giga-',
#  ('hecto-', 'prefix'): 'hecto-',
#  ('milli-', 'prefix'): 'milli-',
#  ('nano-', 'prefix'): 'nano-',
#  ('peta-', 'prefix'): 'peta-',
#  ('tera-', 'prefix'): 'tera-',
#  ('yocto-', 'prefix'): 'yocto-',
#  ('yotta-', 'prefix'): 'yotta-',
#  ('zepto-', 'prefix'): 'zepto-',
#  ('zetta-', 'prefix'): 'zetta-',
#  ('bont', 'noun'): 'fur',
#  ('vloeien', 'verb'): 'to flow (to move as a fluid)',
#  ('flux', 'noun'): 'flux',
#  ('flux', 'adj'): 'obsolete spelling of fluks',
#  ('spam', 'noun'): 'spam (undesired electronic content)',
#  ('trial',
#   'noun'): 'cross with small but sturdy and very versatile motorcycles, cars or bicycles',
#  ('-ist',
#   'suffix'): 'appended to a word, it yields a noun which signifies the subject who performs something related to that word',
#  ('hype', 'noun'): 'hype',
#  ('Bask',
#   'noun'): 'Basque (native or inhabitant of the Basque Country, Spain) (usually male)',
#  ('banjo', 'noun'): 'banjo (stringed instrument)',
#  ('gym', 'noun'): 'gym (fitness facility)',
#  ('judo', 'noun'): 'judo (Japanese martial art)',
#  ('prototype', 'noun'): 'prototype',
#  ('namen', 'noun'): 'plural of naam',
#  ('bergen', 'noun'): 'plural of berg',
#  ('spades', 'noun'): 'plural of spade',
#  ('infinitief', 'noun'): 'infinitive',
#  ('briller', 'noun'): 'person wearing glasses',
#  ('los', 'noun'): 'synonym of lynx',
#  ('clubs', 'noun'): 'plural of club',
#  ('ach', 'intj'): 'oh (expression of compassion, surprise and dismay)',
#  ('backslash', 'noun'): 'backslash',
#  ('OTO',
#   'noun'): 'initialism of opleiden, trainen & oefenen ("educate, train, & exercise")',
#  ('factotum', 'noun'): 'factotum (jack-of-all-trades)',
#  ('gabardine', 'adj'): 'made from gabardine',
#  ('miasmata', 'noun'): 'plural of miasma',
#  ('sick', 'adj'): 'sick (amazing, awesome, excellent)',
#  ('gazelle', 'noun'): 'gazelle, mammal of the tribe Antilopini',
#  ('wildebeest', 'noun'): 'gnu, wildebeest',
#  ('hyena', 'noun'): 'hyena, any member of the family Hyaenidae',
#  ('flag', 'noun'): 'flag',
#  ('brioche', 'noun'): 'brioche',
#  ('fair', 'adj'): 'fair (just, honest, equitable, adequate)',
#  ('festival', 'noun'): 'a festival (festive event or gathering)',
#  ('type',
#   'noun'): 'type: a class, someone or something from a class. The diminutive is used when made into a caricature',
#  ('type', 'verb'): 'singular present subjunctive of typen',
#  ('galah', 'noun'): 'synonym of roze kaketoe',
#  ('proper', 'adj'): 'clean',
#  ('front', 'noun'): 'front',
#  ('management', 'noun'): 'management',
#  ('transport', 'noun'): 'transport',
#  ('scanner', 'noun'): 'scanner (scanning device)',
#  ('request', 'noun'): 'obsolete spelling of rekest',
#  ('producer', 'noun'): 'producer',
#  ('propaganda', 'noun'): 'propaganda',
#  ('research', 'noun'): 'research',
#  ('dons',
#   'noun'): 'down, small bird feathers used as insulation material in covers and sleeping bags',
#  ('papa',
#   'noun'): 'dad (term of address for one’s father, especially used by young children)',
#  ('dis', 'noun'): 'D-sharp',
#  ('lite', 'noun'): 'the (rare) singular of liten',
#  ('happen', 'verb'): 'to take a bite',
#  ('happen', 'noun'): 'plural of hap',
#  ('heir', 'noun'): 'alternative spelling of heer (“army”)',
#  ('mane', 'verb'): 'singular present subjunctive of manen',
#  ('hond',
#   'noun'): 'an old unit of area measuring 100 roeden, approximately 0.14 hectares',
#  ('hamer', 'noun'): 'hammer',
#  ('cruise', 'noun'): 'cruise',
#  ('glad',
#   'adv'): 'completely, entirely (mostly along with verbs and adjective with a negative meaning)',
#  ('wort', 'noun'): 'wort (unfermented beer)',
#  ('dans', 'noun'): 'dance',
#  ('roman', 'noun'): 'a novel (work of fiction)',
#  ('ghetto', 'noun'): 'nonstandard spelling of getto',
#  ('pare', 'verb'): 'singular present subjunctive of paren',
#  ('souvenir', 'noun'): 'souvenir',
#  ('magazine', 'noun'): 'magazine (periodical publication)',
#  ('Westen', 'noun'): 'the West',
#  ('zenit', 'noun'): 'zenith',
#  ('sein', 'noun'): 'signal',
#  ('seine', 'verb'): 'singular present subjunctive of seinen',
#  ('prestige', 'noun'): 'prestige',
#  ('slip', 'noun'): 'skid, an act or instance of slipping',
#  ('baden', 'verb'): 'to bathe',
#  ('baden', 'noun'): 'plural of bad',
#  ('ex', 'noun'): 'ex (former partner)',
#  ('periodiek systeem', 'noun'): 'periodic table',
#  ('cornflakes', 'noun'): 'corn flakes; plural of cornflake',
#  ('bes', 'noun'): 'an old woman',
#  ('poker', 'noun'): 'somebody who pokes a fire',
#  ('wiegen', 'verb'): 'to rock, to sway',
#  ('clitoris', 'noun'): 'clitoris',
#  ('snooker', 'noun'): 'snooker',
#  ('pool',
#   'noun'): 'the pile (upstanding usually fine hair) on certain fabrics, velvet or carpeting',
#  ('more', 'noun'): 'the unit of length (short or long) in poetic metre',
#  ('log', 'noun'): 'weblog',
#  ('pachinko', 'noun'): 'pachinko',
#  ('special', 'noun'): 'a special broadcast episode',
#  ('recent', 'adj'): 'recent',
#  ('aal', 'noun'): 'alternative form of aalt',
#  ('pater', 'noun'): 'father (as a religious title)',
#  ('frater',
#   'noun'): 'a twite (Linaria flavirostris, syn. Carduelis flavirostris)',
#  ('nix', 'noun'): 'nix, nixie (water spirit)',
#  ('nix', 'pron'): 'deliberate misspelling of niks',
#  ('coyote', 'noun'): 'coyote (Canis latrans)',
#  ('skunk', 'noun'): 'skunk, weed with a high level of THC',
#  ('ska', 'noun'): 'ska',
#  ...}

# %% [markdown]
# ## Levenshtein Distance

# %%
words_with_dist_0_2 = {}
words_with_higher = {}
words_with_100 = {}
lev_counts = {}
for i, j in enf_one_word_entries.items():
    distance = Levenshtein.distance(i[0], j)
    gloss = j
    if distance in lev_counts:
        lev_counts[distance] += 1
    else:
        lev_counts[distance] = 1
    if distance <= 2:
        words_with_dist_0_2[i] = {'gloss': j, 'lev_distance': distance}
    elif distance > 100:
        words_with_100[i] = {'gloss': j, 'lev_distance': distance}
    else:
        words_with_higher[i] = {'gloss': j, 'lev_distance': distance}

# %%
words_with_100
# Out:
# {('een',
#   'article'): {'gloss': 'a, an; indefinite article, placed before a singular noun, indicating a general case of a person or thing', 'lev_distance': 101},
#  ('most',
#   'noun'): {'gloss': 'must (unfermented or partially fermented mashed grapes or rarely other fruits, an early stage in the production of wine)', 'lev_distance': 116},
#  ('guanaco',
#   'noun'): {'gloss': 'guanaco (a South American ruminant (Lama guanicoe), closely related to the other lamoids, the alpaca, llama, and vicuña in the family Camelidae)', 'lev_distance': 137},
#  ('rechtsomkeert',
#   'adv'): {'gloss': "(only used with maken) rechtsomkeert maken: do an about-turn, do an about-face; turn on one's heels, make a U-turn", 'lev_distance': 101},
#  ('gans',
#   'noun'): {'gloss': 'a goose, a waterfowl of the family Anatidae, especially of the subfamily Anserinae excepting the genera Cygnus and Coscoroba; in non-scientific usage the term may be applied to larger waterfowl of the Anatidae who do not belong to the Anserinae', 'lev_distance': 240},
#  ('pin',
#   'noun'): {'gloss': "PIN (A number used to confirm an individual's identity, e.g. when using an ATM or a mobile phone, or when making payment using a credit card or debit card)", 'lev_distance': 152},
#  ('actor',
#   'noun'): {'gloss': 'actor; agent, player (who has a part in some field of economical, social or other action, i.e., an active human factor)', 'lev_distance': 114},
#  ('woke',
#   'adj'): {'gloss': 'woke; holding left-wing views or attitudes, (especially) with regards to social justice issues to an excessive degree', 'lev_distance': 113},
#  ('bitter',
#   'noun'): {'gloss': 'bitters, a type of strong spirits made by steeping (often bitter) herbs in brandy or jenever, traditionally considered a digestive drink', 'lev_distance': 130},
#  ('lynx',
#   'noun'): {'gloss': 'lynx, felid of the genus Lynx, in particular the Eurasian lynx (Lynx lynx); sometimes used of other medium-sized felids with large, plumed ears', 'lev_distance': 139},
#  ('memory',
#   'noun'): {'gloss': 'pelmanism; a memory card game in which a pack of cards is spread out face-down and players try to turn up pairs with the same symbol.', 'lev_distance': 127},
#  ('transferium',
#   'noun'): {'gloss': 'a place on the outskirts of a city where people can park their car and travel into the city using public transport', 'lev_distance': 106},
#  ('fork',
#   'noun'): {'gloss': 'a fork, splitting-up of an existing process into itself and a child process executing parts of the same program', 'lev_distance': 107},
#  ('dharma',
#   'noun'): {'gloss': "dharma (order of the universe, society, etc.; one's social or religious duty in Hinduism; teachings of the Buddha)", 'lev_distance': 108},
#  ('-ist',
#   'suffix'): {'gloss': 'appended to a word, it yields a noun which signifies the subject who performs something related to that word', 'lev_distance': 105},
#  ('Punjabi',
#   'adj'): {'gloss': 'Punjabi, of, pertaining to, descended from the people or culture of the Punjab, or written in the Punjabi language', 'lev_distance': 107},
#  ('worm',
#   'noun'): {'gloss': 'worm, vernacular term for various, mostly legless invertebrates; often nematodes or legless arthropod larvae.', 'lev_distance': 105},
#  ('muur',
#   'noun'): {'gloss': 'any of various small plants of the Caryophyllaceae family, particularly of genus Stellaria (chickweed) but also including others such as Arenaria (sandwort) and Sagina (pearlwort)', 'lev_distance': 175},
#  ('meerkat',
#   'noun'): {'gloss': 'a guenon, vervet, talapoin or patas; one of a number of monkeys of the genus Cercopithecus, or of the tribe Cercopithecini', 'lev_distance': 117},
#  ('over',
#   'intj'): {'gloss': 'over (a radio procedure word meaning that the station is finished with its transmission and is expecting a response.)', 'lev_distance': 113},
#  ('albino',
#   'noun'): {'gloss': 'albino: person or animal congenitally lacking melanin pigmentation in the skin, eyes, and hair or feathers (or more rarely only in the eyes); one afflicted with albinism', 'lev_distance': 163},
#  ('albino',
#   'adj'): {'gloss': 'albino, albinistic: congenitally lacking melanin pigmentation in the skin, eyes, and hair or feathers (or more rarely only in the eyes); afflicted with albinism', 'lev_distance': 154},
#  ('triskelion',
#   'noun'): {'gloss': 'triskelion; a figure composed of three interlocked spirals (or three bent human legs), with threefold rotational symmetry', 'lev_distance': 111},
#  ('chauffeur',
#   'noun'): {'gloss': 'driver (person who drives a motorized vehicle, such as a car or a bus; usually to transport others or in a professional capacity, often both)', 'lev_distance': 134},
#  ('yell',
#   'noun'): {'gloss': 'yell, a slogan to be shouted, especially in sports or games (e.g. by players, cheerleaders or the audience)', 'lev_distance': 103},
#  ('patina',
#   'noun'): {'gloss': 'patina: the color or incrustation which age gives to works of art; especially, the green oxidation which covers aging coppers, bronzes, coins and medals', 'lev_distance': 146},
#  ('spar',
#   'noun'): {'gloss': 'spruce; certain tree of the family Pinaceae, especially of the genus Picea, but also used for trees of the genera Abies, Tsuga and Pseudotsuga', 'lev_distance': 138},
#  ('logo',
#   'noun'): {'gloss': 'logo (visual symbol or emblem that acts as a trademark or a means of identification of a company or organization.)', 'lev_distance': 110},
#  ('interim',
#   'noun'): {'gloss': 'Someone temporarily performing a given task (replacing someone else for whom a definite successor has not yet been found).', 'lev_distance': 116},
#  ('atelier',
#   'noun'): {'gloss': 'workshop, studio; in particular in relation to artistic activities, the production of clothing or engineering', 'lev_distance': 102},
#  ('persona',
#   'noun'): {'gloss': 'an imaginary person representing a particular type of client or customer, considered when designing products and services that will appeal to them; a persona', 'lev_distance': 150},
#  ('-ier',
#   'suffix'): {'gloss': 'appended to a word, it yields a noun which signifies the subject who performs something related to that word', 'lev_distance': 105},
#  ('rayon',
#   'noun'): {'gloss': 'region, regional section or subdivision (e.g. of a city or local government, of the area of operation of a business)', 'lev_distance': 111},
#  ('crèche',
#   'noun'): {'gloss': 'a day nursery for small children until age 3 in Belgium (Flanders) or age 4 in the Netherlands, when the children begin kleuterschool (nursery school/kindergarten) or, in the Netherlands, basisschool (primary school, which, in the Netherlands, begins at age 4 since August 1985, when kleuterschool was abolished and became a compulsory part of the primary school)', 'lev_distance': 358},
#  ('marron',
#   'noun'): {'gloss': 'Maroon (a member of ethnic groups in the Americas descended from Africans who escaped slavery and established free communities; (Suriname) a member of a major Afro-Surinamese ethnic group that consists of several tribes and is based mostly in the hinterland; (historical) escaped slave)', 'lev_distance': 280},
#  ('rats',
#   'noun'): {'gloss': 'A dish consisting of a hodgepodge of (leftover) vegetables and mashed potatoes, associated with soldiers.', 'lev_distance': 101},
#  ('ranch',
#   'noun'): {'gloss': 'ranch, notably livestock breeding farm, especially in North America and in other English-speaking countries', 'lev_distance': 102},
#  ('ka',
#   'noun'): {'gloss': 'ka (ancient Egyptian notion of the soul, with raised arms, signfying an embrace(see Isis and Horus/Maria and Jesus)', 'lev_distance': 113},
#  ('toolbox',
#   'noun'): {'gloss': 'a set of auxiliary devices to tackle a set of related problems, e.g. a package of software for a target group or teaching - or marketing aids on a subject', 'lev_distance': 148},
#  ('napoleon',
#   'noun'): {'gloss': 'the 20-franc gold coin, the franc germinal, originally issued under Napoleon, but also used of subsequent gold coins of the same denomination', 'lev_distance': 133},
#  ('WMO',
#   'noun'): {'gloss': 'initialism of wet medisch-wetenschappelijk onderzoek met mensen (“Act on medical scientific research with human beings”)', 'lev_distance': 120},
#  ('zymase',
#   'noun'): {'gloss': 'zymase, enzymatic ferment functioning as a catalyst for converting carbohydrates to ethanol and carbon dioxide', 'lev_distance': 104},
#  ('supercontinent',
#   'noun'): {'gloss': "supercontinent (large landmass consisting of multiple continents or an extremely large continent in a planet's geologic past)", 'lev_distance': 111},
#  ('jingle',
#   'noun'): {'gloss': 'a jingle (song segment used in a commercial or radio program; also used for certain other sound samples used by radio DJs)', 'lev_distance': 116},
#  ('aerogram',
#   'noun'): {'gloss': 'aerogram (a thin piece of foldable and gummed paper for writing a letter and serving as its own envelope for transit via airmail)', 'lev_distance': 121},
#  ('bully',
#   'noun'): {'gloss': "bully (way of resuming the game with a standoff between two opposing players who repeatedly hit each other's sticks, then try to gain possession of the ball)", 'lev_distance': 152},
#  ('basilect',
#   'noun'): {'gloss': 'the basilect; the low-prestige register of a language, divergent from the standard language, mainly used in informal settings', 'lev_distance': 117},
#  ('sas',
#   'noun'): {'gloss': 'an explosive or highly flammable compound used in various explosives such as early artillery projectiles', 'lev_distance': 101},
#  ('coromandel',
#   'noun'): {'gloss': 'calamander, striped ebony (a heavy wood, brown in color with deep black streaks, yielded by a limited number of species in the genus Diospyros)', 'lev_distance': 135},
#  ('wijn',
#   'noun'): {'gloss': 'wine (an alcoholic beverage produced by a certain fermentation procedure; unless otherwise specified or indicated by context, made from grapes)', 'lev_distance': 140},
#  ('gevangenis',
#   'noun'): {'gloss': 'a jail, a prison; especially an institution where convicts are incarcerated, but sometimes used more generally', 'lev_distance': 103},
#  ('ster',
#   'noun'): {'gloss': 'a symbol used to rate restaurants, hotels, films, etc. with a higher number of stars denoting better quality', 'lev_distance': 104},
#  ('binnen',
#   'adj'): {'gloss': 'set for life (having obtained such success professionally and having been able to save enough money that one does not need to work any longer)', 'lev_distance': 136},
#  ('-ling',
#   'suffix'): {'gloss': 'a suffix that describes a person (or other creature) in terms of a place of origin or a quality, as defined by the root to which it is added', 'lev_distance': 137},
#  ('lotus',
#   'noun'): {'gloss': 'patient actor, simulated patient, standardized participant (a lay person person trained to portray medical conditions)', 'lev_distance': 114},
#  ('-ant',
#   'suffix'): {'gloss': 'appended to the stem of a verb, it yields a noun which signifies the subject who performs the action of that verb (see agent noun)', 'lev_distance': 127},
#  ('rei',
#   'noun'): {'gloss': 'circle dance, dance in which the participants form a circle, walk or dance rhythmically and sing or chant', 'lev_distance': 102},
#  ('spiritualist',
#   'noun'): {'gloss': 'Spiritualist (dissident Christian stressing communion with the Holy Spirit and moral improvement through sanctification while rejecting the outwardly church, without necessarily separating from the Roman Catholic Church)', 'lev_distance': 208},
#  ('schaak',
#   'intj'): {'gloss': "check; said when one can strike the opponent's king in chess, but the opponent can still make moves to prevent the king from being taken.", 'lev_distance': 131},
#  ('hoppa',
#   'intj'): {'gloss': "Exclamation of encouragement or excitement, often said during the coordination or completion of a physical activity: let's go! alley-oop! there we go! hey presto!", 'lev_distance': 157},
#  ('ratatouille',
#   'noun'): {'gloss': 'ratatouille: a traditional French Provençal stewed vegetable dish consisting primarily of tomatoes, zucchini and eggplant, with other ingredients', 'lev_distance': 134},
#  ('jerrycan',
#   'noun'): {'gloss': 'a jerrycan or similar container, used for fuel or other liquids (especially drinking water) and made of plastic or metal', 'lev_distance': 112},
#  ('abeel',
#   'noun'): {'gloss': 'abele; term used of certain poplars, mainly the white poplar (Populus alba), grey poplar (Populus × canescens) or black poplar (Populus nigra)', 'lev_distance': 137},
#  ('ribbenboog',
#   'noun'): {'gloss': 'costal arch, the medial ends of the seventh to tenth costal cartilages that join to form a cartilaginous costal margin on each side (arcus costalis)', 'lev_distance': 141},
#  ('BEF',
#   'noun'): {'gloss': "Belgische frank, the Belgian franc, Belgium's national currency before the introduction of the Euro as founding member of the monetary union", 'lev_distance': 138},
#  ('concilie',
#   'noun'): {'gloss': 'a church council in which bishops and eminent theologians are assembled to decide issues, esp. in Catholicism and Orthodoxy', 'lev_distance': 115},
#  ('kers',
#   'noun'): {'gloss': 'cress: a term used of various plants, chiefly but not solely of the family Brassicaceae (crucifers), particularly of the genus Rorippa', 'lev_distance': 131},
#  ('stik',
#   'intj'): {'gloss': "drat, darn; Used as an expression of frustration, if something doesn't work out as expected. It is a rather innocent, child-friendly curse.", 'lev_distance': 135},
#  ('tabletop',
#   'noun'): {'gloss': 'tabletop exercise (An emergency exercise where participants come together in an informal setting in, for example, a meeting room, to discuss their roles during a disaster or crisis and to review relevant procedures based on one or more scenarios)', 'lev_distance': 238},
#  ('personalia',
#   'noun'): {'gloss': 'general personal information (such as would be listed on e.g. a curriculum vitae), such as full name, age, place and date of birth, e-mail address, and telephone number', 'lev_distance': 158},
#  ('singlet',
#   'noun'): {'gloss': 'a singlet, short, sleeveless type of shirt, worn alone (as in sports) or as undershirt; originally only for men', 'lev_distance': 104},
#  ('advocaat',
#   'noun'): {'gloss': 'an alcoholic beverage made of liquor or pure alcohol, egg yolks and sugar or honey, similar to eggnog; advocaat', 'lev_distance': 103},
#  ('koekhappen',
#   'noun'): {'gloss': 'bite-the-cake; a game, especially for children, in which piece(s) of cake are hung from a rope, and the children, being blindfolded, attempt to bite the piece(s) of cake', 'lev_distance': 160},
#  ('idioom',
#   'noun'): {'gloss': 'idiom, expression or a combination of words used in a language in a way which is typical for that particular language', 'lev_distance': 111},
#  ('verkeersinformatie',
#   'noun'): {'gloss': 'traffic information, traffic news, traffic updates, traffic report (reporting about current road traffic conditions in public broadcasts or on the Internet, esp. during radio broadcasts)', 'lev_distance': 173},
#  ('zelfmoordaanslag',
#   'noun'): {'gloss': "suicide attack (attempt on people's lives in which the attacker commits suicide, usually done by certain terrorist groups)", 'lev_distance': 111},
#  ('classis',
#   'noun'): {'gloss': 'a supracongregational, regional executive body, intermediate in size or rank between the consistory of an individual congregation and a provincial synod', 'lev_distance': 145},
#  ('overheid',
#   'noun'): {'gloss': 'the government, the authorities (the state and its administration; governmental administration in the widest sense)', 'lev_distance': 107},
#  ('buffel',
#   'noun'): {'gloss': 'a buffalo, one of some mammals of the subfamily Bovinae, especially of the genus Bubalus or species Syncerus caffer', 'lev_distance': 109},
#  ('-sel',
#   'suffix'): {'gloss': '-age, -ion; Creates nouns indicating something which performs or has undergone an action, or something which results from the action.', 'lev_distance': 129},
#  ('-matig',
#   'suffix'): {'gloss': 'appended to a noun, this suffix yields an adjective whose meaning is "relating to the thing or concept referred to (by the stem)"', 'lev_distance': 124},
#  ('punker',
#   'noun'): {'gloss': 'punk (a fan of punk rock, member of the punk subculture); (by extension) anyone with a mohawk or a similar distinct hairstyle', 'lev_distance': 119},
#  ('baai',
#   'noun'): {'gloss': 'wine (in recent texts only used of red wine, and in earlier texts also of wines from the German Rhineland)', 'lev_distance': 103},
#  ('alternativo',
#   'noun'): {'gloss': 'someone who participates in an alternative subculture (e.g. a hipster, emo or punk) and typically has leftist opinions', 'lev_distance': 107},
#  ('tosti',
#   'noun'): {'gloss': 'a toasted sandwich containing cheese, usually ham and optionally other ingredients and condiments; a toastie', 'lev_distance': 103},
#  ('weeksluiting',
#   'noun'): {'gloss': "closing event for the previous week(s), during which the participants display or perform things or activities which they have worked during the past week(s): for example, several classes of the same level in a grammar school perform a weeksluiting at the end of a week, to close off a theme that had been worked on up to that point (with the teacher's guidance, of course)", 'lev_distance': 360},
#  ('middenbouw',
#   'noun'): {'gloss': 'the middle-level classes of a school, e.g. the 3rd, 4th, and 5th grades of a grammar school in the Netherlands', 'lev_distance': 103},
#  ('regiolect',
#   'noun'): {'gloss': 'a colloquial variety of a standard language spoken in a particular region and influenced by the native dialect (thus an intermediate form between standard and dialect)', 'lev_distance': 158},
#  ('Amsterdams pond',
#   'noun'): {'gloss': 'Amsterdam pound: one of many locally defined weight measures called pound before the introduction of the metric system, important because of its use in the thriving Dutch maritime commerce; equivalent to 0.4941 kilograms', 'lev_distance': 205},
#  ('adenovirus',
#   'noun'): {'gloss': 'adenovirus (any virus of the family Adenoviridae, many of which are responsible for respiratory infections in humans)', 'lev_distance': 107},
#  ('miljoenennota',
#   'noun'): {'gloss': 'annual budget of the kingdom of the Netherlands, as presented in the miljoenenrede (a formal speech in the Tweede Kamer by the Dutch Minister of Finance)', 'lev_distance': 141},
#  ('Prinsjesdag',
#   'noun'): {'gloss': "the third Tuesday of September, when the Dutch monarch rides ceremoniously in a golden (i.e. gilded) coach to the Staten-Generaal to hold the troonrede ('throne speech'), announcing government policy and budget priorities for the coming parliamentary session", 'lev_distance': 250},
#  ('biochemie',
#   'noun'): {'gloss': 'biochemistry, the branch of chemistry studying compounds that occur in living organisms and the processes occurring in their metabolism and catabolism', 'lev_distance': 141},
#  ('façadisme',
#   'noun'): {'gloss': 'the practice in urbanism to renovate a building (especially one enjoying conservation protection) thoroughly inside, but leave the façade unaltered, so the view is preserved even if the function changes', 'lev_distance': 194},
#  ('viooltje',
#   'noun'): {'gloss': 'the common appellation, regardless of size, for any violet, an ornamental fragrant plant genus (including the pansy)', 'lev_distance': 109},
#  ('rangaku',
#   'noun'): {'gloss': 'study of Western knowledge. Dutch authorities from Deshima passed on Western knowledge and history of the world outside Japan onto the Japanese court in annual tea-sessions', 'lev_distance': 166},
#  ('metonymia',
#   'noun'): {'gloss': 'a metaphor by which an inclusive term stands for something included, or vice versa; a metaphor in which a part is spoken of as the whole (hand for laborer) or vice-versa (the court for the judge)', 'lev_distance': 187},
#  ('hondsdolheid',
#   'noun'): {'gloss': 'rabies, a very contagious disease cause by species of Lyssavirus, spread from canines (including foxes), and certain other animals to humans', 'lev_distance': 130},
#  ('-waarts',
#   'suffix'): {'gloss': 'in or towards the direction referred to by the stem onto which this suffix has been appended; the resulting word is an adverb or adjective', 'lev_distance': 132},
#  ('mardijker',
#   'noun'): {'gloss': 'former slave (especially Portuguese or Dutch), who was converted to Christianity. Mostly used in the time of the VOC presence in Indonesia', 'lev_distance': 131},
#  ('-ante',
#   'suffix'): {'gloss': 'appended to the stem of a verb, it yields a noun which signifies a female subject who performs the action of that verb (see agent noun)', 'lev_distance': 131},
#  ('odol',
#   'noun'): {'gloss': 'a morning wood (erection upon waking up, nocturnal penile tumescence). acronym of ontzettend dikke ochtendlul', 'lev_distance': 105},
#  ('inktvis',
#   'noun'): {'gloss': 'a squid, marine mollusk of the superorder Decabrachia or Decapodiformes or more generally (including octopuses) of the class Cephalopoda', 'lev_distance': 130},
#  ('zweefvliegen',
#   'verb'): {'gloss': "to glide in the air; to fly an unpowered sailplane, (of animals) to fly while holding one's wings still, to fly without engines on", 'lev_distance': 120},
#  ('gewei',
#   'noun'): {'gloss': 'an antler or a set of antlers, the bony structure(s) on the head of deer, moose or other antilope species', 'lev_distance': 102},
#  ('romanisatie',
#   'noun'): {'gloss': 'romanization, process of either acculturation to the Romance culture or of phonetic notation and transliteration to Roman script', 'lev_distance': 117},
#  ('behartigen',
#   'verb'): {'gloss': "to look after, serve, study, promote, be watchful of [a person's interests], have [a person's interests] at heart, take to heart", 'lev_distance': 120},
#  ('knolraap',
#   'noun'): {'gloss': 'turnip (the white root of a yellow-flowered plant, Brassica rapa, grown as a vegetable and as fodder for cattle)', 'lev_distance': 105},
#  ('onderbroek',
#   'noun'): {'gloss': 'a pair of undershorts, underpants or pants (underwear for any sex or gender), short or long johns which can be worn under trousers and directly on the skin of lower limbs and private parts', 'lev_distance': 178},
#  ('kwast',
#   'noun'): {'gloss': 'lemonade or another citrus-based beverage; a drink made of lemon juice, water and optionally sugar (can denote both cold and hot drinks)', 'lev_distance': 131},
#  ('melaatsheid',
#   'noun'): {'gloss': 'skin disease; either leprosy (the infectious skin-disease caused by the bacteria Mycobacterium leprae) or (historical) another disease historically conflated with leprosy', 'lev_distance': 160},
#  ('onanie',
#   'noun'): {'gloss': "masturbation, onanism; usually referring to historical contexts where it's regarded as a dangerous pathology", 'lev_distance': 102},
#  ('fuif',
#   'noun'): {'gloss': 'party, festive gathering as celebration (often named in compounds, e.g. kerstfuif for Christmas) or just for fun', 'lev_distance': 108},
#  ('leefloon',
#   'noun'): {'gloss': "official term in Belgian law since 2002 for the former bestaansminimum, a minimal 'subsistence' income, guaranteed to all citizens and other legal residents, regardless of professional activity or history, meant as a bottom on poverty", 'lev_distance': 226},
#  ('korren',
#   'verb'): {'gloss': 'to fish by pulling a small funnel-shaped dragnet by a long rope over the sea floor close to the shoreline or near shallows', 'lev_distance': 117},
#  ('-ma',
#   'suffix'): {'gloss': "occurring in Dutch surnames of Frisian origin, ma is probably a shortened form of the old Frisian genitive plural -monna, 'the men's'. After this suffix had fallen into disuse in the Frisian language, it came to be considered as a suffix to form family names", 'lev_distance': 255},
#  ('muildier',
#   'noun'): {'gloss': 'mule (the sterile hybrid offspring of a male donkey or ass (he-ass, jackass, jack) and a female horse (mare))', 'lev_distance': 101},
#  ('-lings',
#   'suffix'): {'gloss': 'describes a manner in which an action proceeds as defined by root to which it is added, both as adverb and as adjective', 'lev_distance': 116},
#  ('-linge',
#   'suffix'): {'gloss': 'a suffix that describes a female person in terms of a place of origin or a quality, as defined by the root to which it is added', 'lev_distance': 122},
#  ('astronaute',
#   'noun'): {'gloss': 'a female astronaut (a female member of the crew of a spaceship or other spacecraft, or someone trained for that purpose)', 'lev_distance': 110},
#  ('Tadzjieks',
#   'adj'): {'gloss': 'Tajik (Of, from, or pertaining to Tajikistan, the Tajik people (living in Tajikistan and Afghanistan) or the Tajiki dialect of Persian.)', 'lev_distance': 129},
#  ('bijgeloof',
#   'noun'): {'gloss': "superstition (a set of unscientific beliefs that future events may be influenced by one's behaviour in some magical or mystical way)", 'lev_distance': 126},
#  ('maatschap',
#   'noun'): {'gloss': 'partnership, venture (a legal partnership of two or more natural or legal persons for the purpose of sharing costs and distributing jointly generated profits, mainly entered into by certain self-employed professions, such as doctors, dentists, lawyers, and accountants, in which the partners may be held individually and privately liable in case of debts)', 'lev_distance': 346},
#  ('duurte',
#   'noun'): {'gloss': 'dearth, scarcity; a period in which basic necessities such as food are scarce and therefore overly expensive', 'lev_distance': 103},
#  ('vreemdgaan',
#   'verb'): {'gloss': "to cheat; to wander (have sexual or romantic relations with another than one's stable partner, typically in secrecy)", 'lev_distance': 109},
#  ('passaat',
#   'noun'): {'gloss': 'a trade wind in the Atlantic or Indian Ocean; usually an easterly in the tropics when not qualified otherwise', 'lev_distance': 104},
#  ('fusiegemeente',
#   'noun'): {'gloss': 'a municipality arisen by fusion of municipalities (mainly in Belgium; a former municipality is called a deelgemeente)', 'lev_distance': 104},
#  ('loekoe',
#   'noun'): {'gloss': 'a consultation given by a spirit-possessed shaman in which he provides a diagnosis of personal problems or disease', 'lev_distance': 109},
#  ('klop',
#   'noun'): {'gloss': 'an unmarried woman who has dedicated her life to service to the Roman Catholic Church without entering a monastery, now especially denoting a laywoman in the Netherlands before the Roman Catholic emancipation', 'lev_distance': 205},
#  ('bouw',
#   'noun'): {'gloss': 'a unit of measure for area on Java, equivalent to about 0.7 hectare; a portion of agricultural land of this size', 'lev_distance': 109},
#  ('rijsttafel',
#   'noun'): {'gloss': 'a rijsttafel, an elaborate meal or banquet with many colonial Indonesia, specifically Chinese-Indonesian, rice dishes', 'lev_distance': 107},
#  ('monografie',
#   'noun'): {'gloss': 'monograph (scholarly book or a treatise on a single subject or a group of related subjects, usually written by one person)', 'lev_distance': 112},
#  ('zachte g',
#   'noun'): {'gloss': 'the phoneme /ɣ/ pronounced with a more palatal articulation. This pronunciation is characteristic of the southern Dutch-speaking areas: Noord-Brabant, Limburg, and Belgium', 'lev_distance': 164},
#  ('harde g',
#   'noun'): {'gloss': 'the phoneme /ɣ/ pronounced with a more velar or uvular articulation, often also voiceless. This pronunciation is characteristic of the northern Dutch-speaking areas', 'lev_distance': 158},
#  ('overdragen',
#   'verb'): {'gloss': 'to convey, hand over, transfer (note: this can be either voluntary, as of some property, or involuntary, as of a contagious disease)', 'lev_distance': 124},
#  ('lichting',
#   'noun'): {'gloss': 'generation, wave, batch (said of people, such as a class of a given year or a group of people drafted for military service in a given year)', 'lev_distance': 132},
#  ('dweilorkest',
#   'noun'): {'gloss': 'marching band or small band orchestra of wind and percussive instruments, especially at Carnival or other celebrations', 'lev_distance': 109},
#  ('voorzetselbijwoord',
#   'noun'): {'gloss': 'a word with the form of a preposition but the function of an adverb. For example, in a separable verb, the prepositional part functions as an adverb', 'lev_distance': 135},
#  ('bleekgezicht',
#   'noun'): {'gloss': 'paleface, an ethnic European as opposed to a native redskin (typically used in fiction as a stereotypical native American idiom)', 'lev_distance': 120},
#  ('tussenletter',
#   'noun'): {'gloss': 'intermediary letter, notably a genitive suffix forming the joint in a compound, e.g. -s- in levenseinde (“end of life”)', 'lev_distance': 111},
#  ('kapen',
#   'verb'): {'gloss': 'to hijack, to privateer, to (illegally) seize control of something - especially ships or vehicles - by force', 'lev_distance': 104},
#  ('homeopathie',
#   'noun'): {'gloss': 'Homeopathy: a pseudomedical method invented by Hahnemann based on analogies between symptoms and remedies, using extremely diluted doses', 'lev_distance': 126},
#  ('kinderdagverblijf',
#   'noun'): {'gloss': 'a day nursery for small children until age 3 in Belgium (Flanders) or age 4 in the Netherlands, when the children begin kleuterschool (nursery school/kindergarten) or, in the Netherlands, basisschool (primary school, which, in the Netherlands, begins at age 4 since August 1985, when kleuterschool was abolished and became a compulsory part of the primary school)', 'lev_distance': 348},
#  ('tompoes',
#   'noun'): {'gloss': 'tompouce: a Dutch version of mille-feuille, having a thick layer of pastry cream sandwiched between two thin layers of puff pastry, with on top a layer of icing', 'lev_distance': 153},
#  ('wielrenner',
#   'noun'): {'gloss': 'a sports or fitness cyclist, someone who races bicycles, as opposed to a person riding a bike for any other purpose', 'lev_distance': 106},
#  ('muilezel',
#   'noun'): {'gloss': 'hinny (the sterile hybrid offspring of a male horse (stallion) and a female donkey or ass (jennyass, jenny))', 'lev_distance': 103},
#  ('noorderbreedte',
#   'noun'): {'gloss': 'northern latitude - The angular distance north from the equator, measured along the meridian at a particular point', 'lev_distance': 102},
#  ('zuiderbreedte',
#   'noun'): {'gloss': 'southern latitude - The angular distance south from the equator, measured along the meridian at a particular point', 'lev_distance': 103},
#  ('laboratorium',
#   'noun'): {'gloss': 'laboratory, room, building or institution equipped for scientific research or similarly specialised operations, such as production', 'lev_distance': 118},
#  ('ketterij',
#   'noun'): {'gloss': 'heresy; dissension from religious dogma, or by extension from another (e.g. ideological or scientific) doctrine', 'lev_distance': 105},
#  ('gebarentaal',
#   'noun'): {'gloss': 'a sign language, either in general (without article) or any codified medium for communication with the (nearly) deaf', 'lev_distance': 107},
#  ('hypocrisie',
#   'noun'): {'gloss': 'the fake quality hypocrisy (claim, pretense, or false representation of holding beliefs, feelings, or virtues that one does not actually possess)', 'lev_distance': 135},
#  ('geuzennaam',
#   'noun'): {'gloss': 'a nickname or title, originally intended as an insult, which has been reclaimed for use in a positive way by its addressee(s) as a means of linguistic reappropriation', 'lev_distance': 157},
#  ('peranakan',
#   'noun'): {'gloss': 'a person of Chinese ethnicity who is born in the country (notably Indonesia, the former Dutch East Indies), not immigrated', 'lev_distance': 114},
#  ('schuit',
#   'noun'): {'gloss': 'a boat or small ship, usually a flat-bottomed one used for inland navigation or less commonly for coastal navigation; a barge', 'lev_distance': 120},
#  ('biechtvader',
#   'noun'): {'gloss': 'father confessor, confessor (priest who administers the sacrament of confession, ad hoc or on a more regular basis with specific believers (e.g. his parishioners))', 'lev_distance': 154},
#  ('formulier',
#   'noun'): {'gloss': 'a form, a formally standardized (often printed) document to fill out in order to file a specific request, declaration etc.', 'lev_distance': 113},
#  ('Koninginnedag',
#   'noun'): {'gloss': "a former national holiday in the Netherlands, occurring on April 30th (or April 29th, if it would otherwise fall on a Sunday) as an official celebration of its current queen's birthday", 'lev_distance': 173},
#  ('zakgeld',
#   'noun'): {'gloss': 'pocket money, a limited allowance of money for discretionary spending, now especially that given to children by parents or carers', 'lev_distance': 124},
#  ('ondervoorzitter',
#   'noun'): {'gloss': 'a dignitary ranking below the voorzitter (president or chairman), and if their is/are one/more also below the vice-voorzitter(s)', 'lev_distance': 113},
#  ('maagdenvlies',
#   'noun'): {'gloss': 'the hymen, a membrane which occludes the vagina and is in traditional thinking supposed to remain intact only in virgin females', 'lev_distance': 116},
#  ('collectivisme',
#   'noun'): {'gloss': 'collectivism, an ideological system in which the means (of production) must be owned and controlled by people collectively', 'lev_distance': 109},
#  ('stokbewaarder',
#   'noun'): {'gloss': 'a jailer, notably one which carries a cane‐like instrument to prod or discipline prisoners, as usual in Antiquity and feudal era', 'lev_distance': 118},
#  ('fregat',
#   'noun'): {'gloss': 'a frigate, a type of (once sailing, small but fast three-mast) warship, applied to progressively larger types in time, since 1943 mainly escort ships', 'lev_distance': 143},
#  ('-n-',
#   'interfix'): {'gloss': 'Interfix used to link elements in some compounds, sometimes short for -en-. Often used for compounds whose first word is ending in a schwa (spelt with a final e).', 'lev_distance': 159},
#  ('stationsroman',
#   'noun'): {'gloss': 'a light novel without literary ambition, strictly for entertainment, usually romantic and/or adventurous, often chosen as a pastime by travelers', 'lev_distance': 132},
#  ('stamoudste',
#   'noun'): {'gloss': 'a tribal elder, senior tribesman by age and/or rank, typically member of a tribal council which may counsel or even supervise the tribal chief(s)', 'lev_distance': 136},
#  ('opcentiem',
#   'noun'): {'gloss': '(generally in the plural: opcentiemen) An addition of 1 percent to a tax, which is imposed by another public authority, e.g. by way of municipal or provincial supplement to the Belgian income tax', 'lev_distance': 186},
#  ('interrex',
#   'noun'): {'gloss': 'an interrex, temporary head of state during the interregnum between two Roman consulates or from the death of a Polish king till the election and enthronement of his successor', 'lev_distance': 167},
#  ('dagschotel',
#   'noun'): {'gloss': 'plat du jour, special (dish which is promoted on the menu of the day in a restaurant, cafeteria etc., as opposed to the à la carte items)', 'lev_distance': 128},
#  ('dagloner',
#   'noun'): {'gloss': 'a dayworker, day-labourer; one who works for daily wages, and is employed on daily basis, without mid- or long-term job security', 'lev_distance': 120},
#  ('majesteitsschennis',
#   'noun'): {'gloss': "a lese majesty, high crime against the person of a monarch, or the monarchy or crown; by extension even against any sovereign state (which in Roman law was the original holder of 'majesty', only later a ruler's title)", 'lev_distance': 200},
#  ('rijdier',
#   'noun'): {'gloss': 'a riding-animal or mount, a domesticated animal used to carry a rider on its back, as opposed to pets, draught animals and wild animals', 'lev_distance': 129},
#  ('derde stand',
#   'noun'): {'gloss': 'the third estate, the commoners as a represented (mainly bourgeoisie and/or cities as such) feudal estate below the privileged nobility and clergy; often excluding an even lowlier fourth estate, which is denied representation', 'lev_distance': 214},
#  ('eetappel',
#   'noun'): {'gloss': 'an apple (of a) variety best fit to be eaten whole and raw, peeled or not, rather than used in recipes (cooked, fried etc.); an eating apple or table apple', 'lev_distance': 147},
#  ('kookappel',
#   'noun'): {'gloss': 'an apple (of a) variety best fit to be used in the kitchen for relatively elaborate recipes (cooked, fried etc.), rather than wholly eaten in its natural state (raw, but possibly peeled); a cooking apple', 'lev_distance': 194},
#  ('lijfeigene',
#   'noun'): {'gloss': 'serf (person whose very bodily person is legally owned by a master, yet enjoying some legal (and religious-moral) protection)', 'lev_distance': 117},
#  ('damastroos',
#   'noun'): {'gloss': 'a damask rose (Rosa × damascena), a source of attar and major rose breeding ancestor, notably of hybrid perpetual roses', 'lev_distance': 109},
#  ('lotgenoot',
#   'noun'): {'gloss': 'a fellow, companion, mate or partner in some form of fate, being subject to a shared risk, condition or adversity, regardless of mutual attitude; a peer', 'lev_distance': 143},
#  ('ereloon',
#   'noun'): {'gloss': "an honorarium, a customary ('honorary') or often regulated fee for the highly qualified services of doctors, lawyers, architects, surveyors etc.", 'lev_distance': 138},
#  ('ballenjongen',
#   'noun'): {'gloss': 'a ball boy, who fetches balls and may perform other menial services to ball game players, notably at a tournament or luxurious club', 'lev_distance': 120},
#  ('rijksambtenaar',
#   'noun'): {'gloss': 'a public servant working for a national government, usually one working in the Netherlands or another unitary monarchy', 'lev_distance': 107},
#  ('triftong',
#   'noun'): {'gloss': 'a triphthong, monosyllabic three vowel combination, usually involving a quick but smooth movement from one vowel to another that passes over a third one', 'lev_distance': 145},
#  ('pleegkind',
#   'noun'): {'gloss': 'a foster child, which is neither biological nor adoptive offspring but raised rather as if, temporarily or indefinitely', 'lev_distance': 112},
#  ('maanzaad',
#   'noun'): {'gloss': 'poppy seed, the tiny seed(s) of a member of the genus Papaver, especially of the intoxicating poppy which produces opium', 'lev_distance': 114},
#  ('gebeft',
#   'adj'): {'gloss': "fitted with a bef (senses collar etc.), said of wearer or (especially formal) dress, notably in the expression gemanteld en gebeft, i.e. wearing a protestant minister's liturgic outfit", 'lev_distance': 178},
#  ('considerans',
#   'noun'): {'gloss': 'a consideration, something taken into account to reach a decision, notably a legal one, such as a verdict or deed', 'lev_distance': 102},
#  ('breekijzer',
#   'noun'): {'gloss': 'a crowbar, metal bar used as a lever to manually force things apart, fit or extering force to breaking point', 'lev_distance': 101},
#  ('benedenhuis',
#   'noun'): {'gloss': 'the downstairs or lower portion of a house, sometimes a residence separate (i.e. with separate inhabitants) from the upstairs or upper portion', 'lev_distance': 132},
#  ('aanschouwend',
#   'adj'): {'gloss': 'capable of being directly observed by the mind without dependence on the senses, in philosophical systems that suppose something like a Platonist world of ideal forms', 'lev_distance': 155},
#  ('Vogelaartje',
#   'noun'): {'gloss': 'gaffe; an embarrassing mistake made by a politician, especially a minister, when confronted with critical journalists', 'lev_distance': 109},
#  ('tenenkaas',
#   'noun'): {'gloss': "sticky, smegma-like substance that accumulates between one's toes in case of insufficient hygiene; toe cheese; toe jam", 'lev_distance': 111},
#  ('denkrimpel',
#   'noun'): {'gloss': 'a wrinkle that becomes visible when a person is deep in thought and furrows their forehead, brow in concentration', 'lev_distance': 107},
#  ('vertrossing',
#   'noun'): {'gloss': 'a process in which public broadcasting organisations increasingly focus on entertainment over educative television and radio and lose their distinctive (ideological or religious) character, considered a symptom of semi-commercialism and degenerate mass culture by critics', 'lev_distance': 260},
#  ('huisraad',
#   'noun'): {'gloss': 'a collective term used to refer to all furniture, appliances and other housewares in a household (except for grocery items); household items, household goods, household inventory', 'lev_distance': 171},
#  ('egodocument',
#   'noun'): {'gloss': 'any text in which the personal life and experiences of the author play an important and central role, including, but not limited to, diaries, travel logs, autobiographies and memoirs', 'lev_distance': 173},
#  ('-waardig',
#   'suffix'): {'gloss': 'appended to verb stems, adjectives or nouns to express their capacity to complete the action specified in the said elements; -able, -ible, ...worthy', 'lev_distance': 144},
#  ('zulle',
#   'noun'): {'gloss': 'a horizontal structural member of a building near ground level bearing the upright portion of a frame, like for a door or gate; a sill', 'lev_distance': 129},
#  ('Galliër',
#   'noun'): {'gloss': 'Gaul (native or inhabitant of the historical region of Gaul, or poetically the modern nation of France) (usually male)', 'lev_distance': 112},
#  ('stads',
#   'adj'): {'gloss': 'typical of cities or urbanites, especially in origin, mindset or customs, as opposed to villages or the countryside', 'lev_distance': 110},
#  ('gezagsdrager',
#   'noun'): {'gloss': 'an authority figure, someone who represents the authority (e.g. someone acting on behalf of government, like a policeman)', 'lev_distance': 112},
#  ('verhang',
#   'noun'): {'gloss': 'relative measure for the vertical distance in proportion to horizontal distance between two points of a watercourse (in units of gradient or as a proportion)', 'lev_distance': 150},
#  ('hbo',
#   'noun'): {'gloss': 'initialism of hoger beroepsonderwijs (“higher vocational education/training”), i.e. vocational school, (US) ± community college', 'lev_distance': 124},
#  ('omafiets',
#   'noun'): {'gloss': 'a Dutch roadster bicycle (a type of bicycle often seen in the Netherlands), often denoting a bicycle for ladies', 'lev_distance': 104},
#  ('schot',
#   'noun'): {'gloss': 'a divider that partitions a larger space into smaller ones (traditionally wooden planks, but could be made of any materials)', 'lev_distance': 120},
#  ('loverboy',
#   'noun'): {'gloss': 'a pimp who pretends to be in love with a girl or young woman and makes her dependent on him in order to force her into prostitution', 'lev_distance': 124},
#  ('conciërge',
#   'noun'): {'gloss': 'concierge, janitor (one who attends to the maintenance of a building and provides services to its tenants and guests)', 'lev_distance': 109},
#  ('comazuipen',
#   'verb'): {'gloss': 'to binge drink to an excess leading to (normally unintentional) loss of consciousness (though not actual coma)', 'lev_distance': 102},
#  ('sinterklaasavond',
#   'noun'): {'gloss': 'the evening with presents, which is on the day of Sinterklaas, 6 December (in Belgium) or the day before (in the Netherlands)', 'lev_distance': 110},
#  ('verpleeghuis',
#   'noun'): {'gloss': 'rest home, nursing home (place of residence that provides on-site specialist medical care to people who require high-dependency, long-term care)', 'lev_distance': 135},
#  ('MMT',
#   'noun'): {'gloss': 'abbreviation of mobiel medisch team (“aeromedical rapid response team; air ambulance medical personnel”)', 'lev_distance': 104},
#  ('wachtgeld',
#   'noun'): {'gloss': 'an allowance paid to someone who is involuntarily unemployed in their field of expertise which equates to about 70% of the expected salary at their experience level in the Netherlands', 'lev_distance': 175},
#  ('hutspot',
#   'noun'): {'gloss': 'A traditional Dutch dish made from mashed potatoes, carrots and onions, seasoned with pepper, laurel, and cloves a.o.', 'lev_distance': 111},
#  ('-jarig',
#   'suffix'): {'gloss': '-year-old, -year, -yearly; suffixed to numerals to create an adjective that indicates something of a certain age or something that happens at a certain interval.', 'lev_distance': 155},
#  ('-daags',
#   'suffix'): {'gloss': '-day, -daily; suffixed to numerals to create an adjective that indicates something that happens at a certain interval.', 'lev_distance': 112},
#  ('poldermodel',
#   'noun'): {'gloss': "polder model; a form of economic decision making by consensus, including the government and the social partners, that is the trade unions and employers' organisations", 'lev_distance': 155},
#  ('nu eenmaal',
#   'adv'): {'gloss': 'just, as a matter of fact; (a modal particle indicating a certain fact that the speaker accepts is unlikely to change.)', 'lev_distance': 111},
#  ('strooigoed',
#   'noun'): {'gloss': 'a mixture of confectionery that is often strewn around rooms during Sinterklaas celebrations, for children to pick up. The main ingredient is typically kruidnoten', 'lev_distance': 152},
#  ('pakjesavond',
#   'noun'): {'gloss': 'the evening before 5 December, when Sinterklaas brings presents to children (in Belgium the gift-giving is the morning after)', 'lev_distance': 119},
#  ('-teit',
#   'suffix'): {'gloss': 'a productive suffix that forms a noun (especially an abstract noun) from an adjective, akin to the English suffixes -ity and -ty', 'lev_distance': 124},
#  ('soigneur',
#   'noun'): {'gloss': 'a non-competing member of a sports team whose role is to provide support (such as psychological and medical care as well as supplies) for the athletes', 'lev_distance': 142},
#  ('chauffeuse',
#   'noun'): {'gloss': 'female driver (woman who drives a motorized vehicle, such as a car or a bus; usually to transport others or in a professional capacity, often both)', 'lev_distance': 139},
#  ('futurisme',
#   'noun'): {'gloss': 'futurism (Italian and Russian iconoclastic, future-oriented avant-garde art movement, in Italy aligned with fascism)', 'lev_distance': 107},
#  ('gedoogsteun',
#   'noun'): {'gloss': 'support for the governing coalition from an opposition party (which is not officially a member of that coalition), typically to allow formation of a minority government', 'lev_distance': 160},
#  ('trouwambtenaar',
#   'noun'): {'gloss': 'registrar, civil marriage officiant, marriage commissioner (a municipal civil servant who performs civil marriages)', 'lev_distance': 105},
#  ('rijkswacht',
#   'noun'): {'gloss': 'a (former) Belgian military body charged with police duties among the civilian population, the Belgian Dutch / Flemish gendarmerie', 'lev_distance': 123},
#  ('SOSCASTOA',
#   'noun'): {'gloss': 'SOHCAHTOA; sinus is overstaande gedeeld door schuine, cosinus is aanliggende gedeeld door schuine, tangens is overstaande gedeeld door aanliggende', 'lev_distance': 139},
#  ('moffenzeef',
#   'noun'): {'gloss': 'a directional loop antenna designed to block out Nazi jamming signals while receiving radio stations from the Allies', 'lev_distance': 109},
#  ('biechtspiegel',
#   'noun'): {'gloss': 'manual of confession (a list of common sins which can be consulted to examine whether one has some of them to confess)', 'lev_distance': 110},
#  ('beurtbalk',
#   'noun'): {'gloss': 'a checkout divider, a separator to put between the products of different customers on the conveyor belt in a supermarket', 'lev_distance': 112},
#  ('Goudlokjesgebied',
#   'noun'): {'gloss': 'the habitable zone for a planet; the planetary area that is neither too warm nor too cold to sustain life; the Goldilocks zone', 'lev_distance': 118},
#  ('statenbond',
#   'noun'): {'gloss': 'a political union or alliance of independent states or political organizations; a confederacy or confederation', 'lev_distance': 101},
#  ('plebaan',
#   'noun'): {'gloss': 'a priest (in the Roman Catholic Church or the Old Catholic Church) who serves the parish attached to a cathedral (in the bishop’s stead); dean', 'lev_distance': 135},
#  ('-en-',
#   'interfix'): {'gloss': 'genitival interfix indicating that the former element is a characteristic of the latter; sometimes connotes countability or plurality', 'lev_distance': 131},
#  ('APK',
#   'noun'): {'gloss': 'initialism of Algemene Periodieke Keuring, a periodic check on the roadworthiness of a motor vehicle. The Dutch equivalent of the British MOT', 'lev_distance': 138},
#  ('katvanger',
# ...
#  ('beroepsmisvorming',
#   'noun'): {'gloss': 'behavior one regularly performs professionally and which one therefore cannot resist performing in everyday life, sometimes inappropriately', 'lev_distance': 124},
#  ('sociaal domein',
#   'noun'): {'gloss': 'all the government agencies and quangos implementing laws regulating unemployment benefits, disability, labour market participation, healthcare, and youth welfare', 'lev_distance': 149},
#  ('midwinterhoorn',
#   'noun'): {'gloss': 'midwinter horn, a type of wooden trumpet blown around midwinter in certain areas of the eastern Netherlands and the adjacent parts of Germany', 'lev_distance': 127},
#  ('radslag',
#   'noun'): {'gloss': 'cartwheel (A gymnastic maneuver whereby the gymnast rotates to one side or the other while keeping arms and legs outstretched, spinning for one or more revolutions.)', 'lev_distance': 159},
#  ('doopsuiker',
#   'noun'): {'gloss': 'candy, typically sugar beans, offered to friends and relatives on the birth of a child (in Belgium and in parts of the Dutch provinces Limburg, Noord-Brabant and Zeeland)', 'lev_distance': 161},
#  ('ov-chipkaart',
#   'noun'): {'gloss': 'A nationwide contactless smart card used to pay for journeys on all public transport systems in the Netherlands', 'lev_distance': 104},
#  ('surinamisering',
#   'noun'): {'gloss': "the replacement of Dutch officials, managers, specialist staff, regulations, law, investments, etc, by Surinamese nationals or Surinamese equivalents, especially in the run-up to and following Suriname's independence in 1975", 'lev_distance': 210},
#  ('calpol',
#   'noun'): {'gloss': 'paracetamol, acetaminophen (white crystalline compound used in medicine as an anodyne to relieve pain and reduce fever)', 'lev_distance': 113},
#  ('onder de rivieren',
#   'prep_phrase'): {'gloss': 'in the southern Netherlands or southern Low Countries in general; to the south of the Rhine and Meuse and their distributaries, which separate the Catholic southern provinces from the northern, largely Protestant parts of the Low Countries', 'lev_distance': 222},
#  ('boven de rivieren',
#   'prep_phrase'): {'gloss': 'in the northern Netherlands: to the north of the Rhine and Meuse and their distributaries, which separate the Catholic southern provinces from the northern, largely Protestant parts of the Low Countries', 'lev_distance': 187},
#  ('naaktbeeld',
#   'noun'): {'gloss': 'nude (painting, sculpture or photograph depicting one or more human figure(s) in a state of near or total undress)', 'lev_distance': 106},
#  ('zachte oever',
#   'noun'): {'gloss': 'a bank or shore that is not (artificially) too steep and that gradually transitions from the natural incline of the land into shallow water', 'lev_distance': 129},
#  ('erflatersserie',
#   'noun'): {'gloss': 'one of two series of Dutch banknotes issued in the 1950s–70s, designed by Eppo Doeve and Ootje Oxenaar, respectively, featuring portraits of prominent characters from Dutch history', 'lev_distance': 168},
#  ('zingzeggen',
#   'verb'): {'gloss': 'to recite accompanied by music or to sing in a manner close to regular speech, similar to recitativo or rap', 'lev_distance': 101},
#  ('spagaat',
#   'noun'): {'gloss': 'splits (move in dance or gymnastics in which the legs are extended straight out and perpendicular to the body)', 'lev_distance': 103},
#  ('betekenisholisme',
#   'noun'): {'gloss': 'semantic holism (thesis that the meaning of a word or statement can only be understood in the context of the whole)', 'lev_distance': 104},
#  ('de week doormidden zagen',
#   'verb'): {'gloss': 'to celebrate the halfway point of the working week on Wednesday, for example by having lunch or going for drinks after work', 'lev_distance': 107},
#  ('vakantiegeld',
#   'noun'): {'gloss': "a yearly bonus of one's salary or social security with a payout that typically occurs shortly before summer; holiday pay", 'lev_distance': 112},
#  ('de meubels redden',
#   'verb'): {'gloss': "to salvage what can be salvaged, to save as much as possible, to do damage control, to cut one's losses, to minimize one's losses", 'lev_distance': 117},
#  ('onvolprezen',
#   'adj'): {'gloss': 'not praised as fully as deserved (due to great merit); truly excellent, but underrated (even in spite of widespread recognition)', 'lev_distance': 119},
#  ('beleidsadviseur',
#   'noun'): {'gloss': 'policy officer (an expert employed by the government, a non-governmental organisation (such as hospitals, educational institutions and other large civil society organisations), or a (large) company, who helps to formulate and implement the policies or the strategy of their employer, often in a specific focus area)', 'lev_distance': 301},
#  ('stadskasteel',
#   'noun'): {'gloss': 'a type of large urban patrician house, found particularly in the medieval center of Utrecht, that has a fortified and somewhat castle-like appearance', 'lev_distance': 139},
#  ('studiehuis',
#   'noun'): {'gloss': 'independent study centre; educational innovation in the Netherlands to allow students to study more independently', 'lev_distance': 104},
#  ('weledele heer',
#   'noun'): {'gloss': 'dear Sir; used as an honorific and a salutation at the beginning of a formal letter when addressing a male person who cannot claim a specific administrative, ecclesiastical, academic, or noble title, or whose entitlement to such a title is unknown', 'lev_distance': 235},
#  ('weledelgeleerde heer',
#   'noun'): {'gloss': "Used as an honorific and a salutation at the beginning of a formal letter when addressing a male doctorandus, Master of Science, Master of Arts or holder of any other master's degree", 'lev_distance': 165},
#  ('weledelzeergeleerde heer',
#   'noun'): {'gloss': 'Used as an honorific and a salutation at the beginning of a formal letter when addressing a male holder of a doctorate and/or a lecturer at a university of applied sciences', 'lev_distance': 153},
#  ('hooggeleerde heer',
#   'noun'): {'gloss': 'Used as an honorific and a salutation at the beginning of a formal letter when addressing a male university professor', 'lev_distance': 102},
#  ('weledelgestrenge heer',
#   'noun'): {'gloss': 'Used as an honorific and a salutation at the beginning of a formal letter when addressing a male alderman, vice-consul, consul, attaché, clerk to a court of administrative law, lawyer, candidate notary, notary, holder of a university engineering degree (ir.), holder of a university law degree (mr.), tax inspector, inspector of secondary education, member of the Provincial Estates, (chief) police inspector, police commissioner, mid-ranking civil servant, head of a secondary school, junior military officer, or knight of the Military William Order of enlisted or non-commissioned officer rank', 'lev_distance': 574},
#  ('verkleutering',
#   'noun'): {'gloss': 'the act or process of becoming (or rendering something) more superficial and appealing to the lowest common denominator; dumbing down', 'lev_distance': 123},
#  ('hooggeboren heer',
#   'noun'): {'gloss': 'Used as an honorific and a salutation at the beginning of a formal letter when addressing a duke, marquis, count, or viscount', 'lev_distance': 112},
#  ('hoogwelgeboren heer',
#   'noun'): {'gloss': 'Used as an honorific and a salutation at the beginning of a formal letter when addressing a baron, knight, or jonkheer', 'lev_distance': 103},
#  ('edelhoogachtbare heer',
#   'noun'): {'gloss': 'Used as an honorific and a salutation at the beginning of a formal letter when addressing a judge on, clerk of court to, or prosecutor-general at the Supreme Court of the Netherlands', 'lev_distance': 164},
#  ('edelgrootachtbare heer',
#   'noun'): {'gloss': 'Used as an honorific and a salutation at the beginning of a formal letter when addressing a prosecutor-general, a judge on or clerk of court to an appellate court, or an advocate general', 'lev_distance': 168},
#  ('hoogedelgestrenge heer',
#   'noun'): {'gloss': "Used as an honorific and a salutation at the beginning of a formal letter when addressing a male King's commissioner; member of the Council of State, Council of the Judiciary, Court of Audit, Parliament, or provincial executive council; high-ranking civil servant, chief tax inspector, chief commissioner of police, inspector of higher education, ex-minister, consul-general, envoy, a senior commissioned officer or flag officer up to and including the rank of major general or rear admiral", 'lev_distance': 468},
#  ('edelmogende heer',
#   'noun'): {'gloss': 'Used as an honorific and a salutation when addressing a member of the provincial Estates and the States General of the Netherlands', 'lev_distance': 116},
#  ('automatie',
#   'noun'): {'gloss': 'automation (the act or process of converting the controlling of a machine or device to a more automatic system, such as computer or electronic controls)', 'lev_distance': 143},
#  ('geveltuin',
#   'noun'): {'gloss': 'a microgarden consisting of a narrow strip of vegetation close to the façade, wall or fence of a house or building within the built-up area, often located on the street side on publicly-owned land, often created by removing paving, often maintained by the occupant of the property in question; often employed as a measure to reduce rainwater run-off, to counter urban heat stress, to increase biodiversity and/or to beautify the streetscape', 'lev_distance': 431},
#  ('kruiskruid',
#   'noun'): {'gloss': 'a senecio; any plant of genus Senecio, or that was previously counted as part of that genus (such as the plants of genus Jacobaea)', 'lev_distance': 124},
#  ('het hele eiereneten',
#   'noun'): {'gloss': 'everything, the whole thing, all there is to it (especially when emphasizing that something is less daunting or complex than assumed)', 'lev_distance': 116},
#  ('meiler',
#   'noun'): {'gloss': 'A clamp or earthen kiln (pile or pit containing material to be heated in a controlled manner; esp. for charcoaling wood).', 'lev_distance': 115},
#  ('vlakbijl',
#   'noun'): {'gloss': 'flat axe, an axe type with a flat axe head that was embedded in the wood of the handle, in use from the Neolithic until the early Iron Age', 'lev_distance': 133},
#  ('maatjesharing',
#   'noun'): {'gloss': 'Herring caught during late spring and early summer, having had time to fatten up after winter but before having produced any milt or roe, eaten (raw) as a delicacy.', 'lev_distance': 153},
#  ('Hollandse Nieuwe',
#   'noun'): {'gloss': 'Maatjesharing (fat herring caught before having spawned) that, being a TSG product, must be prepared using traditional Hollandic methods in addition to being subject to other specific quality criteria.', 'lev_distance': 188},
#  ('boegroe',
#   'noun'): {'gloss': 'a bead inserted permanently under the skin of the penis, supposedly in order to increase pleasure during vaginal or anal intercourse', 'lev_distance': 125},
#  ('waan van de dag',
#   'noun'): {'gloss': 'Fashionable but ultimately trivial ideas and preoccupations that dominate public discourse (as contrasted with larger, more long-term issues); the discourse du jour.', 'lev_distance': 152},
#  ('toetjesmaag',
#   'noun'): {'gloss': 'A supposed additional stomach reserved for desserts, in which someone who claims to otherwise have eaten their fill of regular food can always nonetheless fit a dessert.', 'lev_distance': 160},
#  ('kapoeweri',
#   'noun'): {'gloss': 'second-growth forest; thicket, shrubland, brushwood (vegetation that regenerates after the clearing of primary forests)', 'lev_distance': 112},
#  ('meergezinswoning',
#   'noun'): {'gloss': 'A residential building built to house multiple families in separate housing units, such as an apartment building.', 'lev_distance': 101},
#  ('Indische Nederlander',
#   'noun'): {'gloss': 'a Dutch citizen with family roots in colonial-era Indonesia (the former Dutch East Indies); either a person with mixed Dutch and Indonesian ancestry (also called Indo) or a person of European ancestry who is born in colonial-era Indonesia and/or who is descended from Europeans who lived there for several generations (also called totok)', 'lev_distance': 318},
#  ('nontonnen',
#   'verb'): {'gloss': 'to look on and/or listen in during an event, often from outside the event premises, in the colonial period chiefly by a native Indonesian person during an event reserved for Europeans', 'lev_distance': 174},
#  ('hoefblad',
#   'noun'): {'gloss': 'Any of various plants of the tribe Senecioneae, particularly of the genera Petasites (butterbur) and Tussilago (coltsfoot).', 'lev_distance': 116},
#  ('moordstrook',
#   'noun'): {'gloss': 'a bike lane that is not separated from car traffic and leaves cyclists particularly vulnerable to accidents (e.g. due to the lane being too narrow, or traffic being too dangerous)', 'lev_distance': 170},
#  ('TikTokrij',
#   'noun'): {'gloss': 'A kind of persistent and often obstructive queue present on some streets of major cities due to social media-induced hype surrounding specific food joints.', 'lev_distance': 150},
#  ('marginale toetsing',
#   'noun'): {'gloss': 'marginal review (a type of limited review by a judge in which a decision is examined only in terms of procedural soundness and reasonableness, without revisiting the argumentation underlying the decision)', 'lev_distance': 186},
#  ('bagagekar',
#   'noun'): {'gloss': 'A cart, typically with two walls, used within a hotel to move the luggage belonging to a guest between the parking lot or entrance and the room where the guest is staying, a bell cart.', 'lev_distance': 176},
#  ('geboortezorg',
#   'noun'): {'gloss': 'healthcare provided to pregnant women in the antenatal, natal and postnatal phases, including care provided by a general practitioner, midwife, obstetrician-gynecologist, and/or maternity nurse (kraamverzorgster), up to six weeks after childbirth', 'lev_distance': 234},
#  ('pretecho',
#   'noun'): {'gloss': 'An ultrasound scan of a pregnant woman which is done for non-medical reasons (for example out of anticipation or simple curiosity).', 'lev_distance': 124},
#  ('londa ke naach',
#   'noun'): {'gloss': 'the Indo-Surinamese version of launda naach; a dance performed by a cross-dressing male professional dancer called nachaniya during wedding celebrations in the Indo-Surinamese community', 'lev_distance': 172},
#  ('leesboek',
#   'noun'): {'gloss': 'A book one is reading, generally recreationally, as opposed to for example a reference work or a study book.', 'lev_distance': 101},
#  ('keurteken',
#   'noun'): {'gloss': 'hallmark (official marking made by a trusted party, usually an assay office, on items made of precious metals)', 'lev_distance': 103},
#  ('beeldmerk',
#   'noun'): {'gloss': 'logo (visual symbol or emblem that acts as a trademark or a means of identification of a company or organization.)', 'lev_distance': 107},
#  ('bepakking',
#   'noun'): {'gloss': "pack, equipment, gear; that which one has packed for travel, generally referring only to that which is carried on one's person, such as a backpack", 'lev_distance': 139},
#  ('dossiervreter',
#   'noun'): {'gloss': 'A politician or public servant who is known to dig deep into specific issues or dossiers, similar to a policy wonk.', 'lev_distance': 106},
#  ('kwari',
#   'noun'): {'gloss': 'collective name for several species of shrubs and trees in the family Vochysiaceae, notably Vochysia surinamensis', 'lev_distance': 110},
#  ('vorstenland',
#   'noun'): {'gloss': 'princely state; (Indonesia) one of four nominally autonomous territories in Central Java administered by native rulers', 'lev_distance': 108},
#  ('ver-van-mijn-bedshow',
#   'noun'): {'gloss': "a usually important event (or events) that the speaker considers irrelevant because they aren't affected by it personally, often because they happen far away from home.", 'lev_distance': 154},
#  ('verzorgingshuis',
#   'noun'): {'gloss': 'rest home, nursing home (small-scale, home-like place of residence that provides assistance with daily activities and GP-type medical care to people who require low-dependency care)', 'lev_distance': 171}}

# %%
list_lev = list(lev_counts.items())
list_lev.sort()

# %%
list_lev
# Out:
# [(0, 1091),
#  (1, 787),
#  (2, 1642),
#  (3, 1137),
#  (4, 1087),
#  (5, 1123),
#  (6, 1465),
#  (7, 1545),
#  (8, 1568),
#  (9, 1549),
#  (10, 1581),
#  (11, 15921),
#  (12, 10201),
#  (13, 5941),
#  (14, 1641),
#  (15, 1497),
#  (16, 5078),
#  (17, 4192),
#  (18, 1243),
#  (19, 1242),
#  (20, 1712),
#  (21, 2593),
#  (22, 1590),
#  (23, 4665),
#  (24, 1894),
#  (25, 853),
#  (26, 613),
#  (27, 583),
#  (28, 604),
#  (29, 685),
#  (30, 732),
#  (31, 1074),
#  (32, 920),
#  (33, 3132),
#  (34, 706),
#  (35, 640),
#  (36, 402),
#  (37, 345),
#  (38, 324),
#  (39, 280),
#  (40, 272),
#  (41, 297),
#  (42, 275),
#  (43, 277),
#  (44, 245),
#  (45, 276),
#  (46, 274),
#  (47, 352),
#  (48, 636),
#  (49, 674),
#  (50, 1201),
#  (51, 340),
#  (52, 268),
#  (53, 171),
#  (54, 148),
#  (55, 133),
#  (56, 157),
#  (57, 132),
#  (58, 123),
#  (59, 132),
#  (60, 126),
#  (61, 105),
#  (62, 152),
#  (63, 550),
#  (64, 354),
#  (65, 104),
#  (66, 140),
#  (67, 163),
#  (68, 220),
#  (69, 252),
#  (70, 495),
#  (71, 320),
#  (72, 55),
#  (73, 92),
#  (74, 65),
#  (75, 72),
#  (76, 126),
#  (77, 100),
#  (78, 71),
#  (79, 62),
#  (80, 58),
#  (81, 55),
#  (82, 44),
#  (83, 40),
#  (84, 55),
#  (85, 39),
#  (86, 48),
#  (87, 37),
#  (88, 48),
#  (89, 27),
#  (90, 43),
#  (91, 45),
#  (92, 26),
#  (93, 33),
#  (94, 35),
#  (95, 33),
#  (96, 47),
#  (97, 26),
#  (98, 28),
#  (99, 16),
#  (100, 19),
#  (101, 22),
#  (102, 24),
#  (103, 22),
#  (104, 19),
#  (105, 20),
#  (106, 21),
#  (107, 30),
#  (108, 16),
#  (109, 21),
#  (110, 15),
#  (111, 22),
#  (112, 23),
#  (113, 23),
#  (114, 13),
#  (115, 8),
#  (116, 16),
#  (117, 13),
#  (118, 13),
#  (119, 8),
#  (120, 17),
#  (121, 10),
#  (122, 9),
#  (123, 9),
#  (124, 20),
#  (125, 10),
#  (126, 11),
#  (127, 15),
#  (128, 5),
#  (129, 15),
#  (130, 5),
#  (131, 12),
#  (132, 6),
#  (133, 4),
#  (134, 6),
#  (135, 9),
#  (136, 8),
#  (137, 10),
#  (138, 8),
#  (139, 8),
#  (140, 7),
#  (141, 3),
#  (142, 2),
#  (143, 4),
#  (144, 5),
#  (145, 6),
#  (146, 5),
#  (147, 3),
#  (148, 5),
#  (149, 5),
#  (150, 7),
#  (152, 8),
#  (153, 6),
#  (154, 4),
#  (155, 5),
#  (156, 2),
#  (157, 4),
#  (158, 9),
#  (159, 3),
#  (160, 4),
#  (161, 2),
#  (162, 2),
#  (163, 5),
#  (164, 3),
#  (165, 3),
#  (166, 1),
#  (167, 2),
#  (168, 5),
#  (169, 2),
#  (170, 2),
#  (171, 5),
#  (172, 1),
#  (173, 3),
#  (174, 2),
#  (175, 2),
#  (176, 2),
#  (177, 2),
#  (178, 3),
#  (180, 1),
#  (181, 3),
#  (182, 1),
#  (184, 1),
#  (185, 3),
#  (186, 2),
#  (187, 6),
#  (188, 3),
#  (189, 1),
#  (190, 1),
#  (193, 2),
#  (194, 5),
#  (197, 1),
#  (198, 1),
#  (200, 1),
#  (204, 1),
#  (205, 4),
#  (207, 2),
#  (208, 2),
#  (210, 2),
#  (211, 1),
#  (212, 1),
#  (214, 1),
#  (218, 1),
#  (222, 1),
#  (223, 1),
#  (225, 1),
#  (226, 1),
#  (227, 1),
#  (230, 1),
#  (234, 2),
#  (235, 1),
#  (236, 1),
#  (238, 1),
#  (240, 2),
#  (241, 1),
#  (248, 1),
#  (250, 2),
#  (251, 1),
#  (252, 2),
#  (255, 2),
#  (260, 2),
#  (261, 1),
#  (269, 1),
#  (280, 1),
#  (301, 1),
#  (315, 1),
#  (318, 1),
#  (346, 1),
#  (348, 1),
#  (358, 1),
#  (360, 1),
#  (431, 1),
#  (468, 1),
#  (574, 1)]

# %% [markdown]
# ## Form Of Pairing

# %%
def is_likely_form_of_def(gloss):
    """ 
    returns a bool and the word it is a form of probably this word
    """
    form_keywords = ['plural', 'subjunctive', 'second-person', 'indicative', 'first-person', 'third-person', 'singular', 'present', 'participle']

    isform = False
    if 'of' in gloss:
        if any(word in gloss for word in form_keywords):
            word = gloss.split(' ')[-1]
            return True, word
    print('is form of')
    return False

# %%
def get_first_word(gloss):
    isform, likely = is_likely_form_of_def(gloss)
    if isform: 
        return likely
    if ',' in gloss:
        gloss_parts = gloss.split(',')

    if gloss.startswith():
        return 'form'
